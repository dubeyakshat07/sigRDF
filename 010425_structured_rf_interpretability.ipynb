# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import networkx as nx
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import _tree
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import AgglomerativeClustering
import plotly.express as px
from pulp import LpProblem, LpVariable, LpMaximize, lpSum, LpStatus, value
from sklearn.decomposition import PCA

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.tree import plot_tree

# Load the breast cancer dataset
data = load_breast_cancer()
X = data.data
y = data.target
feature_names = data.feature_names
target_names = data.target_names

X = pd.DataFrame(X, columns = feature_names)
# Train RandomForestClassifier
rf = RandomForestClassifier(n_estimators=10, random_state=42)
rf.fit(X, y)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=42)

# %% [markdown]
# ## Calculating feature usage in decision paths and feature importance based on impurity reduction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import plot_tree

def get_decision_paths(model, X):
    decision_paths = []
    
    # Iterate over each tree in the forest
    for tree in model.estimators_:
        tree_paths = extract_tree_paths(tree, X)
        decision_paths.append(tree_paths)
    
    return decision_paths

def extract_tree_paths(tree, X):
    # Get the decision tree structure
    children_left = tree.tree_.children_left
    children_right = tree.tree_.children_right
    feature = tree.tree_.feature
    threshold = tree.tree_.threshold
    value = tree.tree_.value
    
    paths = []
    
    # For each sample in X, trace the path from root to leaf
    for _, sample in X.iterrows():
        path = []
        node = 0  # Start from the root node
        
        while children_left[node] != children_right[node]:  # Not a leaf node
            feature_index = feature[node]
            threshold_value = threshold[node]
            feature_name = X.columns[feature_index]
            
            # Record the decision (feature, threshold, direction)
            if sample[feature_name] <= threshold_value:
                path.append((feature_name, threshold_value, "left"))
                node = children_left[node]
            else:
                path.append((feature_name, threshold_value, "right"))
                node = children_right[node]
        
        # At the leaf node, record the leaf prediction
        leaf_prediction = np.argmax(value[node])
        paths.append((path, leaf_prediction))
    
    return paths

def calculate_split_importance(model):
    importance_weights = []
    
    for tree in model.estimators_:
        tree_importance = extract_split_importance(tree)
        importance_weights.append(tree_importance)
    
    return importance_weights

def extract_split_importance(tree):
    # Get the decision tree structure
    children_left = tree.tree_.children_left
    children_right = tree.tree_.children_right
    feature = tree.tree_.feature
    impurity = tree.tree_.impurity
    
    importance_weights = []
    
    for node in range(tree.tree_.node_count):
        if children_left[node] != children_right[node]:  # Not a leaf node
            feature_index = feature[node]
            left_impurity = impurity[children_left[node]]
            right_impurity = impurity[children_right[node]]
            current_impurity = impurity[node]
            
            # Calculate the impurity reduction (importance weight)
            impurity_reduction = current_impurity - (left_impurity + right_impurity) / 2
            importance_weights.append((feature_index, impurity_reduction))
    
    return importance_weights

def visualize_decision_paths(decision_paths, feature_names):
    feature_count = {feature: 0 for feature in feature_names}
    
    # Count feature usage across all decision paths
    for tree_paths in decision_paths:
        for path, _ in tree_paths:
            for feature, _, _ in path:
                feature_count[feature] += 1

    # Create a bar plot for feature usage count
    feature_usage = list(feature_count.items())
    feature_usage.sort(key=lambda x: x[1], reverse=True)

    features, counts = zip(*feature_usage)

    plt.figure(figsize=(10, 6))
    sns.barplot(x=counts, y=features, palette='viridis')
    plt.title('Feature Usage in Decision Paths', fontsize=16)
    plt.xlabel('Number of Times Feature Appears', fontsize=14)
    plt.ylabel('Feature', fontsize=14)
    plt.show()

def visualize_feature_importance(importance_weights, feature_names):
    avg_importance = {feature: [] for feature in feature_names}
    
    # Aggregate importance across all trees
    for tree_importance in importance_weights:
        for feature_index, imp in tree_importance:
            feature_name = feature_names[feature_index]
            avg_importance[feature_name].append(imp)
    
    avg_importance = {feature: np.mean(imp) for feature, imp in avg_importance.items() if imp}
    
    # Sort by importance
    sorted_importance = sorted(avg_importance.items(), key=lambda x: x[1], reverse=True)
    features, importance = zip(*sorted_importance)

    # Plot feature importance
    plt.figure(figsize=(10, 6))
    sns.barplot(x=importance, y=features, palette='viridis')
    plt.title('Feature Importance Based on Impurity Reduction', fontsize=16)
    plt.xlabel('Average Impurity Reduction', fontsize=14)
    plt.ylabel('Feature', fontsize=14)
    plt.show()

def visualize_decision_trees(model, feature_names, target_names):
    for i, tree in enumerate(model.estimators_):
        plt.figure(figsize=(20, 10))
        plot_tree(tree, feature_names=feature_names, class_names=target_names, filled=True)
        plt.title(f"Decision Tree {i + 1}")
        plt.show()

# Get decision paths and importance weights
decision_paths = get_decision_paths(rf, X)
importance_weights = calculate_split_importance(rf)

# Visualize decision paths
visualize_decision_paths(decision_paths, X.columns)

# Visualize feature importance
visualize_feature_importance(importance_weights, X.columns)

# Visualize decision trees
# visualize_decision_trees(rf, X.columns, target_names)
# Out:
# /var/folders/tk/qh_5gfz51996p7zxwjyl8r140000gp/T/ipykernel_14585/2676868043.py:98: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# /var/folders/tk/qh_5gfz51996p7zxwjyl8r140000gp/T/ipykernel_14585/2676868043.py:121: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
# 2. Extract Detailed Decision Paths/Rules

def extract_rule_paths(tree, feature_names):
    tree_ = tree.tree_
    feature = tree_.feature
    threshold = tree_.threshold
    rules = []

    def recurse(node, current_rule):
        if tree_.children_left[node] == _tree.TREE_LEAF:
            rule_str = " AND ".join(current_rule)
            rules.append(rule_str)
        else:
            rule_left = f"({feature_names[feature[node]]} <= {threshold[node]:.2f})"
            current_rule.append(rule_left)
            recurse(tree_.children_left[node], current_rule)
            current_rule.pop()

            rule_right = f"({feature_names[feature[node]]} > {threshold[node]:.2f})"
            current_rule.append(rule_right)
            recurse(tree_.children_right[node], current_rule)
            current_rule.pop()

    recurse(0, [])
    return rules

# %%
all_rule_texts = []
for est in rf.estimators_:
    rules = extract_rule_paths(est, X.columns)
    all_rule_texts.extend(rules)

# 3. Represent Rules with TF-IDF
vectorizer = TfidfVectorizer()
rule_vectors = vectorizer.fit_transform(all_rule_texts)

# %%
# 4. Hierarchical Clustering of the Extracted Rules
n_clusters = 5
clustering = AgglomerativeClustering(n_clusters=n_clusters, metric='cosine', linkage='average')
labels = clustering.fit_predict(rule_vectors.toarray())

clustered_rules = {i: [] for i in range(n_clusters)}
for rule_text, label in zip(all_rule_texts, labels):
    clustered_rules[label].append(rule_text)

# %%
# 5. Visualize the clusters
# Create a DataFrame for the clusters and rules
cluster_df = pd.DataFrame({
    'Cluster': labels,
    'Rule': all_rule_texts
})

# %%
# Visualize the clusters with PCA for dimensionality reduction (to 2D)
pca = PCA(n_components=3)
reduced_vectors = pca.fit_transform(rule_vectors.toarray())

# Plot the clusters with different colors
plt.figure(figsize=(10, 7))
plt.scatter(reduced_vectors[:, 0], reduced_vectors[:, 1], c=labels, cmap='viridis')
plt.colorbar(label='Cluster')
plt.title("PCA of Clusters with Corresponding Rules")
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")

# Add the rules as labels
for i, rule in enumerate(all_rule_texts):
    plt.annotate(rule[:30], (reduced_vectors[i, 0], reduced_vectors[i, 1]), fontsize=2, alpha=0.8)
plt.show()

# %%
# 6. Print out the clustered rules
print("\nClustered Rules:")
for cluster, rules in clustered_rules.items():
    print(f"\nCluster {cluster}:")
    for rule in rules:
        print(f" - {rule[:100]}...")  # Print the first 100 characters of each rule for brevity
# Out:
# Clustered Rules:
#
# Cluster 0:
#  - (worst concave points <= 0.14) AND (mean texture <= 21.31) AND (worst area <= 947.60) AND (perimeter...
#  - (worst concave points <= 0.14) AND (mean texture <= 21.31) AND (worst area <= 947.60) AND (perimeter...
#  - (worst concave points <= 0.14) AND (mean texture <= 21.31) AND (worst area <= 947.60) AND (perimeter...
#  - (worst concave points <= 0.14) AND (mean texture <= 21.31) AND (worst area <= 947.60) AND (perimeter...
#  - (worst concave points <= 0.14) AND (mean texture <= 21.31) AND (worst area <= 947.60) AND (perimeter...
#  - (worst concave points <= 0.14) AND (mean texture <= 21.31) AND (worst area > 947.60) AND (worst conc...
#  - (worst concave points <= 0.14) AND (mean texture <= 21.31) AND (worst area > 947.60) AND (worst conc...
#  - (worst concave points <= 0.14) AND (mean texture > 21.31) AND (worst perimeter <= 101.30) AND (mean ...
#  - (worst concave points <= 0.14) AND (mean texture > 21.31) AND (worst perimeter <= 101.30) AND (mean ...
#  - (worst concave points <= 0.14) AND (mean texture > 21.31) AND (worst perimeter <= 101.30) AND (mean ...
#  - (worst concave points <= 0.14) AND (mean texture > 21.31) AND (worst perimeter <= 101.30) AND (mean ...
#  - (worst concave points <= 0.14) AND (mean texture > 21.31) AND (worst perimeter <= 101.30) AND (mean ...
#  - (worst concave points <= 0.14) AND (mean texture > 21.31) AND (worst perimeter > 101.30) AND (worst ...
#  - (worst concave points <= 0.14) AND (mean texture > 21.31) AND (worst perimeter > 101.30) AND (worst ...
#  - (worst concave points <= 0.14) AND (mean texture > 21.31) AND (worst perimeter > 101.30) AND (worst ...
#  - (worst concavity <= 0.26) AND (worst concave points <= 0.16) AND (worst area <= 1058.00) AND (worst ...
#  - (worst concavity <= 0.26) AND (worst concave points <= 0.16) AND (worst area <= 1058.00) AND (worst ...
#  - (worst concavity <= 0.26) AND (worst concave points <= 0.16) AND (worst area <= 1058.00) AND (worst ...
#  - (worst concavity <= 0.26) AND (worst concave points <= 0.16) AND (worst area <= 1058.00) AND (worst ...
#  - (worst concavity <= 0.26) AND (worst concave points <= 0.16) AND (worst area <= 1058.00) AND (worst ...
#  - (worst concavity <= 0.26) AND (worst concave points <= 0.16) AND (worst area <= 1058.00) AND (worst ...
#  - (worst concavity <= 0.26) AND (worst concave points <= 0.16) AND (worst area <= 1058.00) AND (worst ...
#  - (worst concavity <= 0.26) AND (worst concave points <= 0.16) AND (worst area > 1058.00)...
#  - (worst concavity <= 0.26) AND (worst concave points > 0.16)...
#  - (worst concave points > 0.14) AND (worst radius <= 16.29) AND (worst fractal dimension <= 0.12) AND ...
#  - (worst concave points > 0.14) AND (worst radius <= 16.29) AND (worst fractal dimension <= 0.12) AND ...
#  - (worst concave points > 0.14) AND (worst radius <= 16.29) AND (worst fractal dimension <= 0.12) AND ...
#  - (worst concave points > 0.14) AND (worst radius <= 16.29) AND (worst fractal dimension > 0.12)...
#  - (worst concave points > 0.14) AND (worst radius > 16.29) AND (worst concave points <= 0.15) AND (rad...
#  - (worst concave points > 0.14) AND (worst radius > 16.29) AND (worst concave points <= 0.15) AND (rad...
#  - (worst concave points > 0.14) AND (worst radius > 16.29) AND (worst concave points > 0.15)...
#  - (worst radius <= 16.80) AND (worst concave points <= 0.14) AND (radius error <= 0.64) AND (worst per...
#  - (worst radius <= 16.80) AND (worst concave points <= 0.14) AND (radius error <= 0.64) AND (worst per...
#  - (worst radius <= 16.80) AND (worst concave points <= 0.14) AND (radius error <= 0.64) AND (worst per...
#  - (worst radius <= 16.80) AND (worst concave points <= 0.14) AND (radius error > 0.64) AND (mean smoot...
#  - (worst radius <= 16.80) AND (worst concave points <= 0.14) AND (radius error > 0.64) AND (mean smoot...
#  - (worst radius <= 16.80) AND (worst concave points <= 0.14) AND (radius error > 0.64) AND (mean smoot...
#  - (worst radius <= 16.80) AND (worst concave points > 0.14) AND (mean smoothness <= 0.12) AND (worst t...
#  - (worst radius <= 16.80) AND (worst concave points > 0.14) AND (mean smoothness <= 0.12) AND (worst t...
#  - (worst radius <= 16.80) AND (worst concave points > 0.14) AND (mean smoothness <= 0.12) AND (worst t...
#  - (worst radius <= 16.80) AND (worst concave points > 0.14) AND (mean smoothness <= 0.12) AND (worst t...
#  - (worst radius <= 16.80) AND (worst concave points > 0.14) AND (mean smoothness <= 0.12) AND (worst t...
#  - (worst radius <= 16.80) AND (worst concave points > 0.14) AND (mean smoothness <= 0.12) AND (worst t...
#  - (worst radius <= 16.80) AND (worst concave points > 0.14) AND (mean smoothness <= 0.12) AND (worst t...
#  - (worst radius <= 16.80) AND (worst concave points > 0.14) AND (mean smoothness > 0.12)...
#  - (worst compactness <= 0.28) AND (mean perimeter <= 97.92) AND (worst radius <= 16.88) AND (mean conc...
#  - (worst compactness <= 0.28) AND (mean perimeter <= 97.92) AND (worst radius <= 16.88) AND (mean conc...
#  - (worst compactness <= 0.28) AND (mean perimeter <= 97.92) AND (worst radius <= 16.88) AND (mean conc...
#  - (worst compactness <= 0.28) AND (mean perimeter <= 97.92) AND (worst radius <= 16.88) AND (mean conc...
#  - (worst compactness <= 0.28) AND (mean perimeter <= 97.92) AND (worst radius <= 16.88) AND (mean conc...
#  - (worst compactness <= 0.28) AND (mean perimeter <= 97.92) AND (worst radius <= 16.88) AND (mean conc...
#  - (worst compactness <= 0.28) AND (mean perimeter <= 97.92) AND (worst radius <= 16.88) AND (mean conc...
#  - (worst compactness <= 0.28) AND (mean perimeter <= 97.92) AND (worst radius <= 16.88) AND (mean conc...
#  - (worst compactness <= 0.28) AND (mean perimeter <= 97.92) AND (worst radius <= 16.88) AND (mean conc...
#  - (worst compactness <= 0.28) AND (mean perimeter <= 97.92) AND (worst radius <= 16.88) AND (mean conc...
#  - (worst compactness <= 0.28) AND (mean perimeter <= 97.92) AND (worst radius <= 16.88) AND (mean conc...
#  - (worst compactness <= 0.28) AND (mean perimeter <= 97.92) AND (worst radius > 16.88)...
#  - (worst compactness <= 0.28) AND (mean perimeter > 97.92) AND (worst texture <= 21.14) AND (worst con...
#  - (worst compactness <= 0.28) AND (mean perimeter > 97.92) AND (worst texture <= 21.14) AND (worst con...
#  - (worst compactness <= 0.28) AND (mean perimeter > 97.92) AND (worst texture > 21.14)...
#  - (worst compactness > 0.28) AND (mean concave points <= 0.05) AND (worst radius <= 16.82)...
#  - (worst compactness > 0.28) AND (mean concave points <= 0.05) AND (worst radius > 16.82)...
#  - (worst compactness > 0.28) AND (mean concave points > 0.05) AND (worst radius <= 15.39) AND (mean te...
#  - (worst compactness > 0.28) AND (mean concave points > 0.05) AND (worst radius <= 15.39) AND (mean te...
#  - (worst compactness > 0.28) AND (mean concave points > 0.05) AND (worst radius > 15.39) AND (area err...
#  - (worst compactness > 0.28) AND (mean concave points > 0.05) AND (worst radius > 15.39) AND (area err...
#  - (worst compactness > 0.28) AND (mean concave points > 0.05) AND (worst radius > 15.39) AND (area err...
#  - (worst compactness > 0.28) AND (mean concave points > 0.05) AND (worst radius > 15.39) AND (area err...
#  - (worst compactness > 0.28) AND (mean concave points > 0.05) AND (worst radius > 15.39) AND (area err...
#  - (worst compactness > 0.28) AND (mean concave points > 0.05) AND (worst radius > 15.39) AND (area err...
#  - (mean perimeter <= 98.76) AND (mean concave points <= 0.05) AND (worst radius <= 16.83) AND (perimet...
#  - (mean perimeter <= 98.76) AND (mean concave points <= 0.05) AND (worst radius <= 16.83) AND (perimet...
#  - (mean perimeter <= 98.76) AND (mean concave points <= 0.05) AND (worst radius <= 16.83) AND (perimet...
#  - (mean perimeter <= 98.76) AND (mean concave points <= 0.05) AND (worst radius <= 16.83) AND (perimet...
#  - (mean perimeter <= 98.76) AND (mean concave points <= 0.05) AND (worst radius <= 16.83) AND (perimet...
#  - (mean perimeter <= 98.76) AND (mean concave points <= 0.05) AND (worst radius > 16.83) AND (mean are...
#  - (mean perimeter <= 98.76) AND (mean concave points <= 0.05) AND (worst radius > 16.83) AND (mean are...
#  - (mean perimeter <= 98.76) AND (mean concave points <= 0.05) AND (worst radius > 16.83) AND (mean are...
#  - (mean perimeter <= 98.76) AND (mean concave points > 0.05) AND (worst compactness <= 0.37) AND (wors...
#  - (mean perimeter <= 98.76) AND (mean concave points > 0.05) AND (worst compactness <= 0.37) AND (wors...
#  - (mean perimeter <= 98.76) AND (mean concave points > 0.05) AND (worst compactness <= 0.37) AND (wors...
#  - (mean perimeter <= 98.76) AND (mean concave points > 0.05) AND (worst compactness <= 0.37) AND (wors...
#  - (mean perimeter <= 98.76) AND (mean concave points > 0.05) AND (worst compactness <= 0.37) AND (wors...
#  - (mean perimeter <= 98.76) AND (mean concave points > 0.05) AND (worst compactness <= 0.37) AND (wors...
#  - (mean perimeter <= 98.76) AND (mean concave points > 0.05) AND (worst compactness <= 0.37) AND (wors...
#  - (mean perimeter <= 98.76) AND (mean concave points > 0.05) AND (worst compactness > 0.37) AND (worst...
#  - (mean perimeter <= 98.76) AND (mean concave points > 0.05) AND (worst compactness > 0.37) AND (worst...
#  - (mean perimeter > 98.76) AND (mean texture <= 14.10)...
#  - (mean perimeter > 98.76) AND (mean texture > 14.10) AND (fractal dimension error <= 0.00) AND (compa...
#  - (mean perimeter > 98.76) AND (mean texture > 14.10) AND (fractal dimension error <= 0.00) AND (compa...
#  - (mean perimeter > 98.76) AND (mean texture > 14.10) AND (fractal dimension error > 0.00)...
#
# Cluster 1:
#  - (worst concave points > 0.14) AND (worst area <= 492.25)...
#  - (worst concave points > 0.14) AND (worst area > 492.25) AND (perimeter error <= 1.54)...
#  - (worst concave points > 0.14) AND (worst area > 492.25) AND (perimeter error > 1.54) AND (mean compa...
#  - (worst concave points > 0.14) AND (worst area > 492.25) AND (perimeter error > 1.54) AND (mean compa...
#  - (worst concave points > 0.14) AND (worst area > 492.25) AND (perimeter error > 1.54) AND (mean compa...
#  - (worst concave points <= 0.14) AND (mean area <= 694.10) AND (worst area <= 727.10) AND (area error ...
#  - (worst concave points <= 0.14) AND (mean area <= 694.10) AND (worst area <= 727.10) AND (area error ...
#  - (worst concave points <= 0.14) AND (mean area <= 694.10) AND (worst area <= 727.10) AND (area error ...
#  - (worst concave points <= 0.14) AND (mean area <= 694.10) AND (worst area <= 727.10) AND (area error ...
#  - (worst concave points <= 0.14) AND (mean area <= 694.10) AND (worst area <= 727.10) AND (area error ...
#  - (worst concave points <= 0.14) AND (mean area <= 694.10) AND (worst area > 727.10) AND (worst textur...
#  - (worst concave points <= 0.14) AND (mean area <= 694.10) AND (worst area > 727.10) AND (worst textur...
#  - (worst concave points <= 0.14) AND (mean area <= 694.10) AND (worst area > 727.10) AND (worst textur...
#  - (worst concave points <= 0.14) AND (mean area <= 694.10) AND (worst area > 727.10) AND (worst textur...
#  - (worst concave points <= 0.14) AND (mean area <= 694.10) AND (worst area > 727.10) AND (worst textur...
#  - (worst concave points <= 0.14) AND (mean area <= 694.10) AND (worst area > 727.10) AND (worst textur...
#  - (worst concave points <= 0.14) AND (mean area > 694.10) AND (worst texture <= 19.74)...
#  - (worst concave points <= 0.14) AND (mean area > 694.10) AND (worst texture > 19.74) AND (texture err...
#  - (worst concave points <= 0.14) AND (mean area > 694.10) AND (worst texture > 19.74) AND (texture err...
#  - (worst concave points <= 0.14) AND (mean area > 694.10) AND (worst texture > 19.74) AND (texture err...
#  - (area error <= 34.85) AND (worst perimeter <= 104.10) AND (worst symmetry <= 0.50) AND (mean area <=...
#  - (area error <= 34.85) AND (worst perimeter <= 104.10) AND (worst symmetry <= 0.50) AND (mean area <=...
#  - (area error <= 34.85) AND (worst perimeter <= 104.10) AND (worst symmetry <= 0.50) AND (mean area <=...
#  - (area error <= 34.85) AND (worst perimeter <= 104.10) AND (worst symmetry <= 0.50) AND (mean area > ...
#  - (area error <= 34.85) AND (worst perimeter <= 104.10) AND (worst symmetry <= 0.50) AND (mean area > ...
#  - (area error <= 34.85) AND (worst perimeter <= 104.10) AND (worst symmetry <= 0.50) AND (mean area > ...
#  - (area error <= 34.85) AND (worst perimeter <= 104.10) AND (worst symmetry <= 0.50) AND (mean area > ...
#  - (area error <= 34.85) AND (worst perimeter <= 104.10) AND (worst symmetry <= 0.50) AND (mean area > ...
#  - (area error <= 34.85) AND (worst perimeter <= 104.10) AND (worst symmetry > 0.50)...
#  - (area error <= 34.85) AND (worst perimeter > 104.10) AND (worst concave points <= 0.14) AND (mean te...
#  - (area error <= 34.85) AND (worst perimeter > 104.10) AND (worst concave points <= 0.14) AND (mean te...
#  - (area error <= 34.85) AND (worst perimeter > 104.10) AND (worst concave points <= 0.14) AND (mean te...
#  - (area error <= 34.85) AND (worst perimeter > 104.10) AND (worst concave points > 0.14) AND (mean per...
#  - (area error <= 34.85) AND (worst perimeter > 104.10) AND (worst concave points > 0.14) AND (mean per...
#  - (area error > 34.85) AND (mean concave points <= 0.05) AND (perimeter error <= 4.12) AND (worst smoo...
#  - (area error > 34.85) AND (mean concave points <= 0.05) AND (perimeter error <= 4.12) AND (worst smoo...
#  - (area error > 34.85) AND (mean concave points <= 0.05) AND (perimeter error > 4.12) AND (concave poi...
#  - (area error > 34.85) AND (mean concave points <= 0.05) AND (perimeter error > 4.12) AND (concave poi...
#  - (area error > 34.85) AND (mean concave points > 0.05) AND (worst texture <= 19.03) AND (worst area <...
#  - (area error > 34.85) AND (mean concave points > 0.05) AND (worst texture <= 19.03) AND (worst area >...
#  - (area error > 34.85) AND (mean concave points > 0.05) AND (worst texture > 19.03)...
#
# Cluster 2:
#  - (worst concavity > 0.26) AND (worst perimeter <= 100.59) AND (worst concave points <= 0.18) AND (wor...
#  - (worst concavity > 0.26) AND (worst perimeter <= 100.59) AND (worst concave points <= 0.18) AND (wor...
#  - (worst concavity > 0.26) AND (worst perimeter <= 100.59) AND (worst concave points <= 0.18) AND (wor...
#  - (worst concavity > 0.26) AND (worst perimeter <= 100.59) AND (worst concave points > 0.18)...
#  - (worst concavity > 0.26) AND (worst perimeter > 100.59) AND (mean concave points <= 0.04) AND (conca...
#  - (worst concavity > 0.26) AND (worst perimeter > 100.59) AND (mean concave points <= 0.04) AND (conca...
#  - (worst concavity > 0.26) AND (worst perimeter > 100.59) AND (mean concave points <= 0.04) AND (conca...
#  - (worst concavity > 0.26) AND (worst perimeter > 100.59) AND (mean concave points > 0.04) AND (mean a...
#  - (worst concavity > 0.26) AND (worst perimeter > 100.59) AND (mean concave points > 0.04) AND (mean a...
#  - (worst concavity > 0.26) AND (worst perimeter > 100.59) AND (mean concave points > 0.04) AND (mean a...
#  - (worst concavity > 0.26) AND (worst perimeter > 100.59) AND (mean concave points > 0.04) AND (mean a...
#
# Cluster 3:
#  - (worst radius > 16.80) AND (mean texture <= 15.82) AND (mean fractal dimension <= 0.06)...
#  - (worst radius > 16.80) AND (mean texture <= 15.82) AND (mean fractal dimension > 0.06)...
#  - (worst radius > 16.80) AND (mean texture > 15.82) AND (mean symmetry <= 0.15) AND (mean symmetry <= ...
#  - (worst radius > 16.80) AND (mean texture > 15.82) AND (mean symmetry <= 0.15) AND (mean symmetry > 0...
#  - (worst radius > 16.80) AND (mean texture > 15.82) AND (mean symmetry > 0.15)...
#  - (worst perimeter <= 105.15) AND (worst symmetry <= 0.41) AND (worst concave points <= 0.13)...
#  - (worst perimeter <= 105.15) AND (worst symmetry <= 0.41) AND (worst concave points > 0.13) AND (conc...
#  - (worst perimeter <= 105.15) AND (worst symmetry <= 0.41) AND (worst concave points > 0.13) AND (conc...
#  - (worst perimeter <= 105.15) AND (worst symmetry <= 0.41) AND (worst concave points > 0.13) AND (conc...
#  - (worst perimeter <= 105.15) AND (worst symmetry > 0.41)...
#  - (worst perimeter > 105.15) AND (mean concave points <= 0.05) AND (worst area <= 957.45) AND (texture...
#  - (worst perimeter > 105.15) AND (mean concave points <= 0.05) AND (worst area <= 957.45) AND (texture...
#  - (worst perimeter > 105.15) AND (mean concave points <= 0.05) AND (worst area <= 957.45) AND (texture...
#  - (worst perimeter > 105.15) AND (mean concave points <= 0.05) AND (worst area > 957.45) AND (mean rad...
#  - (worst perimeter > 105.15) AND (mean concave points <= 0.05) AND (worst area > 957.45) AND (mean rad...
#  - (worst perimeter > 105.15) AND (mean concave points <= 0.05) AND (worst area > 957.45) AND (mean rad...
#  - (worst perimeter > 105.15) AND (mean concave points <= 0.05) AND (worst area > 957.45) AND (mean rad...
#  - (worst perimeter > 105.15) AND (mean concave points > 0.05) AND (mean texture <= 16.53) AND (mean ra...
#  - (worst perimeter > 105.15) AND (mean concave points > 0.05) AND (mean texture <= 16.53) AND (mean ra...
#  - (worst perimeter > 105.15) AND (mean concave points > 0.05) AND (mean texture <= 16.53) AND (mean ra...
#  - (worst perimeter > 105.15) AND (mean concave points > 0.05) AND (mean texture > 16.53)...
#
# Cluster 4:
#  - (mean radius <= 14.98) AND (worst concavity <= 0.36) AND (perimeter error <= 2.56)...
#  - (mean radius <= 14.98) AND (worst concavity <= 0.36) AND (perimeter error > 2.56) AND (smoothness er...
#  - (mean radius <= 14.98) AND (worst concavity <= 0.36) AND (perimeter error > 2.56) AND (smoothness er...
#  - (mean radius <= 14.98) AND (worst concavity <= 0.36) AND (perimeter error > 2.56) AND (smoothness er...
#  - (mean radius <= 14.98) AND (worst concavity <= 0.36) AND (perimeter error > 2.56) AND (smoothness er...
#  - (mean radius <= 14.98) AND (worst concavity <= 0.36) AND (perimeter error > 2.56) AND (smoothness er...
#  - (mean radius <= 14.98) AND (worst concavity <= 0.36) AND (perimeter error > 2.56) AND (smoothness er...
#  - (mean radius <= 14.98) AND (worst concavity > 0.36) AND (worst area <= 493.45)...
#  - (mean radius <= 14.98) AND (worst concavity > 0.36) AND (worst area > 493.45) AND (worst texture <= ...
#  - (mean radius <= 14.98) AND (worst concavity > 0.36) AND (worst area > 493.45) AND (worst texture <= ...
#  - (mean radius <= 14.98) AND (worst concavity > 0.36) AND (worst area > 493.45) AND (worst texture > 2...
#  - (mean radius > 14.98) AND (worst concavity <= 0.22) AND (mean smoothness <= 0.09) AND (concavity err...
#  - (mean radius > 14.98) AND (worst concavity <= 0.22) AND (mean smoothness <= 0.09) AND (concavity err...
#  - (mean radius > 14.98) AND (worst concavity <= 0.22) AND (mean smoothness > 0.09)...
#  - (mean radius > 14.98) AND (worst concavity > 0.22) AND (worst perimeter <= 111.10)...
#  - (mean radius > 14.98) AND (worst concavity > 0.22) AND (worst perimeter > 111.10) AND (radius error ...
#  - (mean radius > 14.98) AND (worst concavity > 0.22) AND (worst perimeter > 111.10) AND (radius error ...
#  - (mean radius > 14.98) AND (worst concavity > 0.22) AND (worst perimeter > 111.10) AND (radius error ...
#  - (mean concavity <= 0.09) AND (worst radius <= 18.64) AND (worst area <= 957.45) AND (mean compactnes...
#  - (mean concavity <= 0.09) AND (worst radius <= 18.64) AND (worst area <= 957.45) AND (mean compactnes...
#  - (mean concavity <= 0.09) AND (worst radius <= 18.64) AND (worst area <= 957.45) AND (mean compactnes...
#  - (mean concavity <= 0.09) AND (worst radius <= 18.64) AND (worst area <= 957.45) AND (mean compactnes...
#  - (mean concavity <= 0.09) AND (worst radius <= 18.64) AND (worst area <= 957.45) AND (mean compactnes...
#  - (mean concavity <= 0.09) AND (worst radius <= 18.64) AND (worst area <= 957.45) AND (mean compactnes...
#  - (mean concavity <= 0.09) AND (worst radius <= 18.64) AND (worst area > 957.45) AND (symmetry error <...
#  - (mean concavity <= 0.09) AND (worst radius <= 18.64) AND (worst area > 957.45) AND (symmetry error >...
#  - (mean concavity <= 0.09) AND (worst radius > 18.64)...
#  - (mean concavity > 0.09) AND (worst perimeter <= 102.25) AND (worst compactness <= 0.45) AND (concavi...
#  - (mean concavity > 0.09) AND (worst perimeter <= 102.25) AND (worst compactness <= 0.45) AND (concavi...
#  - (mean concavity > 0.09) AND (worst perimeter <= 102.25) AND (worst compactness <= 0.45) AND (concavi...
#  - (mean concavity > 0.09) AND (worst perimeter <= 102.25) AND (worst compactness > 0.45) AND (texture ...
#  - (mean concavity > 0.09) AND (worst perimeter <= 102.25) AND (worst compactness > 0.45) AND (texture ...
#  - (mean concavity > 0.09) AND (worst perimeter > 102.25) AND (mean concave points <= 0.04)...
#  - (mean concavity > 0.09) AND (worst perimeter > 102.25) AND (mean concave points > 0.04) AND (mean te...
#  - (mean concavity > 0.09) AND (worst perimeter > 102.25) AND (mean concave points > 0.04) AND (mean te...
#  - (mean concavity > 0.09) AND (worst perimeter > 102.25) AND (mean concave points > 0.04) AND (mean te...

# %%
# 7. Build and Sparsify the Weighted Directed Feature Graph (Optional)
edge_weights = {}

for rule_text in all_rule_texts:
    conditions = re.findall(r'\((.*?)\s*(<=|>)\s*([\d\.]+)\)', rule_text)
    features_in_rule = [cond[0].strip() for cond in conditions if cond[0].strip() in X.columns]
    for i in range(len(features_in_rule)-1):
        edge = (features_in_rule[i], features_in_rule[i+1])
        edge_weights[edge] = edge_weights.get(edge, 0) + 1

G = nx.DiGraph()
for (f_from, f_to), weight in edge_weights.items():
    G.add_edge(f_from, f_to, weight=weight)

H = nx.DiGraph()
for u, v, d in G.edges(data=True):
    H.add_edge(u, v, weight=-d['weight'])

if len(list(H.nodes())) > 0:
    root = list(H.nodes())[0]
    msa = nx.minimum_spanning_arborescence(H)
    for u, v, d in msa.edges(data=True):
        d['weight'] = -d['weight']
    plt.figure(figsize=(20, 20))
    pos = nx.circular_layout(msa)
    edge_labels = nx.get_edge_attributes(msa, 'weight')
    nx.draw(msa, pos, with_labels=True, node_size=200, node_color="lightcoral", arrowsize=10)
    nx.draw_networkx_edge_labels(msa, pos, edge_labels=edge_labels)
    plt.title("Surrogate Interpretable Graph (MSA) [Un-optimized]")
    plt.show()
else:
    print("Graph H is empty. No feature transitions were detected.")

# %% [markdown]
# ## Plolty version of the Surrogate Interpretable Graph Classifier

# %%
import plotly.graph_objects as go


if len(list(H.nodes())) > 0:
    root = list(H.nodes())[0]
    msa = nx.minimum_spanning_arborescence(H)
    for u, v, d in msa.edges(data=True):
        d['weight'] = -d['weight']
    
    # Generate node positions using circular layout
    pos = nx.circular_layout(msa)
    
    # Create Plotly figure
    fig = go.Figure()
    
    # Prepare node coordinates
    node_x = [pos[node][0] for node in msa.nodes()]
    node_y = [pos[node][1] for node in msa.nodes()]
    
    # Add nodes as a scatter trace
    fig.add_trace(go.Scatter(
        x=node_x,
        y=node_y,
        mode='markers+text',
        text=list(msa.nodes()),
        textposition='middle center',
        marker=dict(
            size=25,
            color='lightcoral',
            line=dict(width=2, color='darkred')
        ,
        # textfont=dict(
        #     size=14,
        #     color='black'
        # ),
        # hoverinfo='text'
    )))
    
    # Create annotations for edges and labels
    annotations = []
    for u, v, d in msa.edges(data=True):
        x0, y0 = pos[u]
        x1, y1 = pos[v]
        
        # Add directional arrow
        annotations.append(dict(
            ax=x0,
            ay=y0,
            x=x1,
            y=y1,
            xref='x',
            yref='y',
            axref='x',
            ayref='y',
            showarrow=True,
            arrowhead=3,
            arrowsize=1.5,
            arrowwidth=2,
            arrowcolor='#666'
        ))
        
        # Add edge weight label
        annotations.append(dict(
            x=(x0 + x1)/2,
            y=(y0 + y1)/2,
            xref='x',
            yref='y',
            text=str(d['weight']),
            showarrow=False,
            font=dict(size=12, color='black'),
            bgcolor='white',
            bordercolor='black',
            borderwidth=1,
            borderpad=4
        ))
    
    # Configure layout
    fig.update_layout(
        title='Surrogate Interpretable Graph (MSA) [Un-optimized]',
        title_x=0.5,
        # titlefont_size=20,
        showlegend=False,
        annotations=annotations,
        template='plotly_white',
        xaxis=dict(showgrid=False, zeroline=False, visible=False),
        yaxis=dict(showgrid=False, zeroline=False, visible=False),
        margin=dict(l=50, r=50, b=50, t=100),
        hovermode='closest',
        height=1200,
        width=1200
    )
    fig.add_trace(go.Scatter(
    x=node_x,
    y=node_y,
    mode='markers+text',
    # text=list(msa.nodes()),
    textposition='bottom right',
    textfont=dict(  # Moved outside marker dict
        size=14,
        color='black'
    ),
    # hoverinfo='text',  # Moved outside marker dict
    # marker=dict(
    #     size=25,
    #     color='lightcoral',
    #     line=dict(width=2, color='darkred')
    # )
    ))
    
    # Display the interactive plot
    fig.show()
else:
    print("Graph H is empty. No feature transitions were detected.")

# %% [markdown]
# ### MILP Optimization of the Surrogate Interpretable Graph of the RF Classifier

# %% [markdown]
# ##### Simple Linear Optimizer

# %%
# For simplicity, we select a subset of edges that maximize total weight under a constraint on the number of edges.
# Define maximum number of edges to select (surrogate graph size)
max_edges = 15

edge_dict = edge_weights
# Create MILP problem: maximize sum of weights of selected edges subject to selecting <= max_edges.
prob = LpProblem("Surrogate_Graph_Selection", LpMaximize)

# Create a binary variable for each edge in edge_dict
edge_vars = {edge: LpVariable(f"edge_{edge[0]}_{edge[1]}", cat='Binary')
             for edge in edge_dict.keys()}

# Objective: maximize total weight of selected edges
prob += lpSum([edge_dict[edge] * edge_vars[edge] for edge in edge_vars]), "Total_Weight"

# Constraint: number of selected edges <= max_edges
prob += lpSum([edge_vars[edge] for edge in edge_vars]) <= max_edges, "EdgeCountConstraint"

# Solve the MILP
prob.solve()

print("MILP Status:", LpStatus[prob.status])
selected_edges = [edge for edge in edge_vars if value(edge_vars[edge]) == 1]
print("Selected edges for surrogate graph:", selected_edges)

# Build surrogate graph from selected edges
G_surrogate = nx.DiGraph()
for edge in selected_edges:
    G_surrogate.add_edge(edge[0], edge[1], weight=edge_dict[edge])

# Visualize the surrogate graph
plt.figure(figsize=(10, 10))
pos = nx.circular_layout(G_surrogate)
edge_labels = nx.get_edge_attributes(G_surrogate, 'weight')
nx.draw(G_surrogate, pos, with_labels=True, node_size=800, node_color="lightgreen", arrowsize=10)
nx.draw_networkx_edge_labels(G_surrogate, pos, edge_labels=edge_labels)
plt.title("Surrogate Interpretable Graph")
plt.show()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/DubeyA-Dev/miniconda3/envs/taylor/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/tk/qh_5gfz51996p7zxwjyl8r140000gp/T/62cebb31d90642ffbb1a4ea430c45242-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/tk/qh_5gfz51996p7zxwjyl8r140000gp/T/62cebb31d90642ffbb1a4ea430c45242-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 6 COLUMNS
# At line 599 RHS
# At line 601 BOUNDS
# At line 750 ENDATA
# Problem MODEL has 1 rows, 148 columns and 148 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 235 - 0.00 seconds
# Cgl0004I processed model has 1 rows, 127 columns (127 integer (111 of which binary)) and 127 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -235
# Cbc0038I Cleaned solution of -235
# Cbc0038I Before mini branch and bound, 127 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -235 - took 0.00 seconds
# Cbc0012I Integer solution of -235 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective -235, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -235 to -235
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                235.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.02
#
# MILP Status: Optimal
# Selected edges for surrogate graph: [('worst concave points', 'mean texture'), ('worst concave points', 'worst area'), ('worst concave points', 'worst radius'), ('worst concavity', 'worst perimeter'), ('worst perimeter', 'mean concave points'), ('worst concave points', 'mean area'), ('area error', 'worst perimeter'), ('worst radius', 'worst concave points'), ('worst perimeter', 'worst symmetry'), ('worst compactness', 'mean perimeter'), ('mean perimeter', 'worst radius'), ('worst radius', 'mean concavity'), ('mean concave points', 'worst radius'), ('mean radius', 'worst concavity'), ('mean perimeter', 'mean concave points')]

# %% [markdown]
# ### Advanced MILP Solver for producing multiple surrogate interpretable graphs

# %%
import pulp
import networkx as nx
import plotly.graph_objects as go
from pulp import LpProblem, LpMaximize, LpVariable, lpSum, LpStatus, value

def optimize_surrogate_graph(edge_weights, max_edges=15, solver='COIN', 
                            time_limit=None, mip_gap=None, visualization=True):
    """
    Advanced MILP-based edge selection with multiple solver support and interactive visualization
    
    Parameters:
    edge_weights (dict): Edge weights as {(source, target): weight}
    max_edges (int): Maximum number of edges to select
    solver (str): Solver choice ['COIN', 'GUROBI', 'CPLEX', 'SCIP']
    time_limit (int): Time limit in seconds for optimization
    mip_gap (float): Relative MIP gap tolerance
    visualization (bool): Whether to generate interactive Plotly visualization
    
    Returns:
    tuple: (selected_edges, surrogate_graph, optimization_status)
    """
    
    # Initialize MILP problem
    prob = LpProblem("Surrogate_Graph_Optimization", LpMaximize)
    
    # Create edge variables
    edge_vars = LpVariable.dicts("Edge", edge_weights.keys(), cat='Binary')
    
    # Objective function: maximize total edge weight
    prob += lpSum([edge_weights[edge] * edge_vars[edge] for edge in edge_weights])
    
    # Edge count constraint
    prob += lpSum([edge_vars[edge] for edge in edge_weights]) <= max_edges
    
    # Configure solver parameters
    solver_config = {
        'COIN': {
            'solver': pulp.COIN_CMD,
            'params': {
                'options': ['sec={}'.format(time_limit)] if time_limit else None,
                'msg': 0
            }
        },
        'GUROBI': {
            'solver': pulp.GUROBI,
            'params': {
                'timeLimit': time_limit,
                'MIPGap': mip_gap,
                'LogToConsole': 0
            }
        },
        'CPLEX': {
            'solver': pulp.CPLEX_PY,
            'params': {
                'timelimit': time_limit,
                'mip_tolerances_mipgap': mip_gap,
                'threads': 1
            }
        },
        'SCIP': {
            'solver': pulp.SCIP_CMD,
            'params': {
                'time_limit': time_limit,
                'gap': mip_gap
            }
        }
    }
    
    try:
        # Solve the MILP problem
        solver_obj = solver_config[solver]['solver'](**{k:v for k,v in solver_config[solver]['params'].items() if v})
        prob.solve(solver_obj)
    except KeyError:
        raise ValueError(f"Unsupported solver: {solver}. Choose from {list(solver_config.keys())}")
    except pulp.PulpSolverError:
        raise RuntimeError(f"Solver {solver} not available. Please check installation.")
    
    # Process results
    status = LpStatus[prob.status]
    selected_edges = [edge for edge in edge_weights if edge_vars[edge].value() == 1]
    
    # Create surrogate graph
    G = nx.DiGraph()
    for edge in selected_edges:
        G.add_edge(edge[0], edge[1], weight=edge_weights[edge])
    
    # Generate visualization if requested
    if visualization and selected_edges:
        fig = go.Figure()
        pos = nx.spring_layout(G)
        
        # Add edges
        edge_trace = []
        for edge in G.edges():
            x0, y0 = pos[edge[0]]
            x1, y1 = pos[edge[1]]
            fig.add_trace(go.Scatter(
                x=[x0, x1, None], y=[y0, y1, None],
                line=dict(width=G[edge[0]][edge[1]]['weight']/5, color='#888'),
                hoverinfo='none',
                mode='lines'))
            
        # Add nodes
        node_x = [pos[node][0] for node in G.nodes()]
        node_y = [pos[node][1] for node in G.nodes()]
        fig.add_trace(go.Scatter(
            x=node_x, y=node_y,
            mode='markers+text',
            text=list(G.nodes()),
            textposition="middle center",
            hoverinfo='text',
            marker=dict(
                size=20,
                color='lightblue',
                line=dict(width=2, color='darkblue')
            )
        ))
        
        # Layout configuration
        fig.update_layout(
            title=f"Optimized Surrogate Graph (Status: {status})",
            title_x=0.5,
            showlegend=False,
            hovermode='closest',
            margin=dict(b=20,l=5,r=5,t=40),
            xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
            yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)
        )
        
        fig.show()
    
    return selected_edges, G, status

# Example usage:
# edges, graph, status = optimize_surrogate_graph(
#     edge_weights,
#     max_edges=15,
#     solver='GUROBI',
#     time_limit=300,
#     mip_gap=0.01
# )

# %%
pulp.listSolvers(onlyAvailable=True)
# Out:
# ['PULP_CBC_CMD']

# %%
# optimize_surrogate_graph(edge_weights, solver='COIN', time_limit=60)
# optimize_surrogate_graph(edge_weights, solver='GUROBI', mip_gap=0.001)
# optimize_surrogate_graph(edge_weights, solver='CPLEX', time_limit=120)
# optimize_surrogate_graph(edge_weights, solver='SCIP')

# %% [markdown]
# ## Analyzing conuterfactual for each of the tree within the search limit parameters

# %% [markdown]
# **What the Function Does:**
# 1. For each feature, tries to find the smallest perturbation (±step size) needed to flip the model's prediction
# 2. Tests both positive and negative directions for each feature
# 3. Stops searching when either:
#    - Prediction flips (found counterfactual)
#    - Reaches maximum iterations without flipping (no counterfactual)
#
# **Why No Counterfactuals Are Produced:**
# 1. **Model Robustness**: The model might be too confident in its prediction (needs larger perturbations)
# 2. **Feature Interactions**: Real decisions often require coordinated changes in multiple features
# 3. **Search Limitations**:
#    - Step size (0.05) might be too small
#    - Max iterations (50) might be insufficient (max change = 50×0.05 = 2.5 units)
# 4. **Data Distribution**: Changes might need to stay within valid feature ranges
# 5. **Binary Search Limitation**: Only modifies one feature at a time
#
# **Enhanced Version with Visualization and Improvements:**
#
#
# 1. **Probability Tracking**: Monitors class probability evolution instead of just class labels
# 2. **Visualization**: Shows how probabilities evolve with positive/negative perturbations
# 3. **Directional Analysis**: Separate tracking of increase/decrease directions
# 4. **Adaptive Step Size**: Larger default step (0.1) for faster exploration
# 5. **Target Class Specification**: Explicit target class control
# 6. **Diagnostic Plotting**: Reveals:
#    - Probability trajectories
#    - Decision boundary (0.5 line)
#    - Relative feature sensitivity
#
# **Interpretation Guide:**
# 1. **No Counterfactuals Indicate**:
#    - Flat lines: Feature changes don't affect predictions
#    - Non-crossing curves: Changes insufficient to flip class
# 2. **Steep Curves**: Sensitive features that impact predictions
# 3. **Crossing 0.5 Line**: Successful counterfactual found
#
# **Common Reasons for No Results:**
# 1. **Insufficient Perturbation Space**: Try:
#    ```python
#    counterfactual_analysis(..., step=0.5, max_iter=200)
#    ```
# 2. **Need Multi-Feature Changes**: Combine features showing partial probability shifts
# 3. **Model Linearity Issues**: Try non-uniform step sizes or optimization-based methods
# 4. **Data Constraints**: Add range checks for valid feature values
#
# This enhanced version helps diagnose why counterfactuals might not be found while providing visual insights into feature sensitivity.

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# def counterfactual_analysis(instance, model, feature_names, step=0.1, max_iter=100, 
#                            target_class=None, plot=True):
#     """
#     Enhanced counterfactual search with probability tracking and visualization
    
#     Returns:
#     - (dict) Counterfactual directions and magnitudes
#     - (matplotlib.figure) Probability evolution plots
#     """
#     instance_df = pd.DataFrame([instance], columns=feature_names)
#     orig_prob = model.predict_proba(instance_df)[0]
#     orig_class = model.predict(instance_df)[0]
#     target_class = 1 - orig_class if target_class is None else target_class
    
#     results = {}
#     prob_curves = {}

#     for feat_idx, feat_name in enumerate(feature_names):
#         perturbations = []
#         probabilities = []
        
#         # Test both directions
#         for direction in [-1, 1]:
#             perturbed = instance.copy()
#             prob_trace = []
            
#             for i in range(max_iter):
#                 perturbed[feat_idx] += direction * step
#                 prob = model.predict_proba(pd.DataFrame([perturbed], 
#                                      columns=feature_names))[0][target_class]
#                 prob_trace.append(prob)
                
#                 if (prob > 0.5) != (orig_prob[target_class] > 0.5):
#                     results[feat_name] = {
#                         'direction': 'decrease' if direction == -1 else 'increase',
#                         'magnitude': (i+1)*step,
#                         'final_prob': prob
#                     }
#                     break
#             else:
#                 prob_trace = [orig_prob[target_class]] * max_iter
            
#             perturbations.append(np.array(prob_trace))
#             probabilities.append(prob_trace)
        
#         prob_curves[feat_name] = (probabilities[0], probabilities[1])

#     if plot:
#         plt.figure(figsize=(12, 6))
#         colors = plt.cm.viridis(np.linspace(0, 1, len(feature_names)))
        
#         for idx, (feat, (neg_probs, pos_probs)) in enumerate(prob_curves.items()):
#             plt.subplot(2, 1, 1)
#             plt.plot(neg_probs, color=colors[idx], linestyle='--', 
#                     label=f'{feat} (-)' if idx == 0 else None)
#             plt.subplot(2, 1, 2)
#             plt.plot(pos_probs, color=colors[idx], linestyle='-',
#                     label=f'{feat} (+)')

#         # Formatting
#         for i in [1, 2]:
#             plt.subplot(2, 1, i)
#             plt.axhline(0.5, color='gray', linestyle=':')
#             plt.ylabel('Class Probability')
#             plt.xlabel('Iteration')
#             plt.title('Negative Perturbations' if i == 1 else 'Positive Perturbations')
#             plt.grid(alpha=0.3)
#             if i == 1: plt.legend(ncol=3, bbox_to_anchor=(1, 1.2))

#         plt.tight_layout()
#         plt.show()

#     return results

# # Usage
# instance = X.iloc[1].values
# cf_results = counterfactual_analysis(instance, rf, list(X.columns), 
#                    step=0.1, max_iter=1000)

# # Print results
# print("Counterfactual Analysis Report:")
# for feat, data in cf_results.items():
#     print(f"{feat}:")
#     print(f"  Required {data['direction']} of {data['magnitude']:.2f}")
#     print(f"  Final probability: {data['final_prob']:.2%}")
#     print("-"*40)

# %% [markdown]
# ## Counterfactual for each tree (aggregate analysis) of the RF Classifier

# %% [markdown]
# **Key Features:**
# 1. **Per-Tree Analysis**: Evaluates counterfactual effectiveness for each individual decision tree
# 2. **Four Diagnostic Visualizations**:
#    - Success rate heatmap across features
#    - Perturbation magnitude distribution
#    - Direction consistency plot
#    - Decision boundary projection for top feature
# 3. **Aggregate Statistics**:
#    - Success rates across the ensemble
#    - Required perturbation magnitudes
#    - Direction consistency metrics
#
# **Interpretation Guide:**
# 1. **No Counterfactuals Possible When**:
#    - Success rate heatmap shows all low values (0-0.2)
#    - Perturbation magnitude plot shows sparse/no points
#    - Decision boundary projection shows instance far from boundary
#
# 2. **Key Insights**:
#    - Features with high success rates are good candidate for intervention
#    - Consistent direction across trees indicates robust relationships
#    - Large required deltas suggest feature scaling issues or model robustness
#
# This analysis helps understand why counterfactuals might be hard to find by:
# - Revealing feature-specific effectiveness across the ensemble
# - Showing required intervention magnitudes
# - Visualizing decision boundaries for critical features
# - Identifying directional consistency in required perturbations

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.inspection import DecisionBoundaryDisplay

def ensemble_counterfactual_analysis(instance, rf_model, feature_names, 
                                    step=0.5, max_iter=500, target_class=None):
    """
    Advanced counterfactual analysis across Random Forest subtrees
    Returns:
    - (dict) Aggregate counterfactual statistics per feature
    - (dict) Individual tree counterfactual data
    - (matplotlib.figure) Visualizations
    """
    # Initialize data structures
    n_trees = len(rf_model.estimators_)
    n_features = len(feature_names)
    tree_data = []
    aggregate_results = {feat: {'deltas': [], 'success_rate': 0} 
                        for feat in feature_names}
    
    # Create progress bar for tree analysis
    with tqdm(total=n_trees, desc="Analyzing Subtrees") as pbar:
        for tree_idx, tree in enumerate(rf_model.estimators_):
            # Get original prediction from this subtree
            orig_pred = tree.predict(instance.reshape(1, -1))[0]
            target = 1 - orig_pred if target_class is None else target_class
            
            tree_results = {}
            
            # Analyze each feature
            for feat_idx, feat_name in enumerate(feature_names):
                found_cf = False
                # Try both perturbation directions
                for direction in [-1, 1]:
                    perturbed = instance.copy()
                    for i in range(max_iter):
                        perturbed[feat_idx] += direction * step * (i+1)
                        new_pred = tree.predict(perturbed.reshape(1, -1))[0]
                        if new_pred == target:
                            tree_results[feat_name] = {
                                'delta': direction * step * (i+1),
                                'iterations': i+1,
                                'direction': 'decrease' if direction == -1 else 'increase'
                            }
                            aggregate_results[feat_name]['deltas'].append(direction * step * (i+1))
                            found_cf = True
                            break
                    if found_cf:
                        break
                if not found_cf:
                    tree_results[feat_name] = {'delta': np.nan, 'iterations': max_iter}
            
            tree_data.append(tree_results)
            pbar.update(1)
    
    # Calculate success rates
    for feat in aggregate_results:
        successes = len([d for d in aggregate_results[feat]['deltas'] if not np.isnan(d)])
        aggregate_results[feat]['success_rate'] = successes / n_trees
    
    # Generate visualizations
    plt.figure(figsize=(30, 28))
    
    # 1. Feature Importance Heatmap
    plt.subplot(2, 2, 1)
    success_rates = [aggregate_results[feat]['success_rate'] for feat in feature_names]
    plt.imshow(np.array(success_rates).reshape(1, -1), cmap='viridis', aspect='auto')
    plt.colorbar(label='Success Rate')
    plt.yticks([])
    plt.xticks(np.arange(len(feature_names)), feature_names, rotation=90)
    plt.title('Counterfactual Success Rate Across Trees')
    
    # 2. Delta Distribution Swarm Plot
    plt.subplot(2, 2, 2)
    all_deltas = []
    for feat in feature_names:
        deltas = [d for d in aggregate_results[feat]['deltas'] if not np.isnan(d)]
        jitter = np.random.normal(loc=0, scale=0.1, size=len(deltas))
        plt.scatter(np.arange(len(deltas)) + jitter, deltas, 
                    alpha=0.3, label=feat)
    plt.axhline(0, color='gray', linestyle='--')
    plt.ylabel('Required Delta')
    plt.xlabel('Feature Index')
    plt.title('Perturbation Magnitude Distribution')
    
    # 3. Direction Consistency Plot
    plt.subplot(2, 2, 3)
    direction_counts = {feat: {'increase': 0, 'decrease': 0} 
                       for feat in feature_names}
    for tree in tree_data:
        for feat, res in tree.items():
            if 'direction' in res:
                direction_counts[feat][res['direction']] += 1
                
    width = 0.4
    for idx, feat in enumerate(feature_names):
        plt.bar(idx - width/2, direction_counts[feat]['increase'], 
               width=width, color='green')
        plt.bar(idx + width/2, direction_counts[feat]['decrease'], 
               width=width, color='red')
    plt.xticks(np.arange(len(feature_names)), feature_names, rotation=90)
    plt.ylabel('Count')
    plt.title('Direction Consistency Across Trees')
    plt.legend(['Increase', 'Decrease'])
    
    # 4. Decision Boundary Projection
    plt.subplot(2, 2, 4)
    top_feature = sorted(feature_names, 
                        key=lambda x: aggregate_results[x]['success_rate'])[-1]
    feat_idx = feature_names.index(top_feature)
    
    # Generate probability curve for top feature
    feat_values = np.linspace(instance[feat_idx] - 3*step*max_iter,
                            instance[feat_idx] + 3*step*max_iter, 100)
    probabilities = []
    
    for val in feat_values:
        modified = instance.copy()
        modified[feat_idx] = val
        # Get average probability across all trees
        avg_prob = np.mean([tree.predict_proba(modified.reshape(1, -1))[0][target_class] 
                          for tree in rf_model.estimators_])
        probabilities.append(avg_prob)
    
    plt.plot(feat_values, probabilities, color='navy', lw=2)
    plt.axvline(instance[feat_idx], color='red', linestyle='--', label='Original Value')
    plt.axhline(0.5, color='gray', linestyle=':', label='Decision Threshold')
    plt.xlabel(top_feature)
    plt.ylabel('Average Class Probability')
    plt.title(f'Probability Landscape for {top_feature}')
    plt.legend()
    
    plt.tight_layout()
    return aggregate_results, tree_data

# %%
# Assuming:
# - rf is your trained RandomForestClassifier
# - X is your feature matrix
# - instance is your sample to analyze (numpy array)

agg_results, tree_data = ensemble_counterfactual_analysis(
    instance=X.iloc[1].values,
    rf_model=rf,
    feature_names=list(X.columns),
    step=0.2,
    max_iter=500
)
# Out:
# Analyzing Subtrees: 100%|██████████| 10/10 [00:17<00:00,  1.75s/it]

# %% [markdown]
# #### This also enables directional consistency evaluations

# %%
# First get the global target class
instance = X.iloc[11].values
forest_pred = rf.predict(instance.reshape(1, -1))[0]
target_class = 1 - forest_pred  # Flip the prediction

agg_results, tree_data = ensemble_counterfactual_analysis(
    instance=instance,
    rf_model=rf,
    feature_names=list(X.columns),
    step=0.2,
    max_iter=50,
    target_class=target_class  # Explicit target class
)
# Out:
# /Users/DubeyA-Dev/miniconda3/envs/taylor/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#
# Analyzing Subtrees: 100%|██████████| 10/10 [00:01<00:00,  5.40it/s]

# %% [markdown]
# ---
#
# ### **1. Core Methodological Components Explained**
#
# #### **A. Per-Tree Analysis**
# - **What it means**: The analysis evaluates counterfactual effectiveness _individually_ for every decision tree in the random forest. Each tree acts as a "mini-model" with its own decision logic.
# - **Why it matters**:
#   - Identifies features that are universally important vs. those only significant in subsets of trees
#   - Reveals the diversity of decision logic within the ensemble
#   - Helps distinguish between *robust patterns* (agreed by most trees) and *idiosyncratic patterns* (specific to individual trees)
#
# ---
#
# #### **B. Four Diagnostic Visualizations**
# 1. **Success Rate Heatmap**
#    - **Purpose**: Shows the percentage of trees where perturbing a feature flipped the prediction
#    - **Interpretation**:
#      - Bright colors = High success rates (e.g., "mean radius" flips predictions in 80% of trees)
#      - Dark colors = Low success rates (e.g., "texture" only affects 10% of trees)
#    - **Analogy**: A "voting system" showing which features are most influential across the ensemble
#
# 2. **Perturbation Magnitude Distribution**
#    - **Purpose**: Visualizes the range of changes needed to flip predictions
#    - **Key Patterns**:
#      - Tight cluster = Consistent perturbation size across trees (e.g., "radius" always requires ~0.5 unit change)
#      - Wide spread = Context-dependent effectiveness (e.g., "area" needs 0.2-3.0 units depending on the tree)
#    - **Critical Insight**: Features with small required changes are "leverage points" for interventions
#
# 3. **Direction Consistency Plot**
#    - **Purpose**: Quantifies whether features require consistent increase/decrease across trees
#    - **Example**:
#      - "Concavity": 90% of trees require decreasing this feature
#      - "Smoothness": 50% increase / 50% decrease (no consensus)
#    - **Implications**: Consistent directions indicate stable relationships between features and outcomes
#
# 4. **Decision Boundary Projection**
#    - **Purpose**: Illustrates how the top feature's values relate to class probabilities
#    - **Key Observations**:
#      - Steep slope = Small changes dramatically affect predictions
#      - Flat region = Feature changes have minimal impact
#      - Distance from boundary = How "deep" the instance is in its predicted class
#
# ---
#
# #### **C. Aggregate Statistics**
# 1. **Success Rates**:
#    - "75% success rate for radius" = 3/4 trees would flip prediction if radius is perturbed
#    - Low rates (<20%) suggest the feature is either:
#      - Irrelevant to the classification
#      - Requires coordinated changes with other features
#
# 2. **Required Perturbation Magnitudes**:
#    - Mean/median values indicate "typical" intervention size
#    - Large standard deviation implies tree-to-tree variability in feature sensitivity
#
# 3. **Direction Consistency**:
#    - "85% consistency for decreasing radius" = Strong consensus on relationship direction
#    - 50/50 split = Ambiguous/noise in the feature's role
#
# ---
#
# ### **2. Interpretation Guide Deep Dive**
#
# #### **A. No Counterfactuals Detected**
# - **Scenario**: All features show success rates <20%, sparse perturbation points, and distant decision boundaries
# - **Implications**:
#   1. **Model Robustness**: The prediction is stable against single-feature perturbations
#   2. **Data Characteristics**:
#      - The instance is far from class boundaries in feature space
#      - True decision boundaries may be multi-dimensional (require combined feature changes)
#   3. **Practical Impact**:
#      - Single-feature interventions may be insufficient
#      - Need to consider *minimum viable combination* of changes
#
# ---
#
# #### **B. Key Insights**
# 1. **High Success Rate Features**
#    - **Example**: "Radius" with 80% success rate
#    - **Actionable Insight**: Medical diagnosis - Focus on reducing tumor radius
#    - **Technical Implication**: The feature is central to the model's decision logic
#
# 2. **Directional Consistency**
#    - **Example**: 90% of trees require decreasing "concavity"
#    - **Domain Significance**: Confirms biological understanding (less concave tumors are benign)
#    - **Validation**: Matches medical literature, increasing trust in the model
#
# 3. **Large Required Perturbations**
#    - **Example**: "Area" needing >5-unit changes
#    - **Possible Causes**:
#      - The feature is scaled poorly (e.g., range=0-1000 vs. 0-1 for others)
#      - The model uses it only in extreme cases (threshold effect)
#    - **Solution Path**:
#      - Re-examine feature engineering
#      - Check for nonlinear relationships (log-transform?)
#
# ---
#
# ### **3. Why This Matters for Explainability**
# 1. **Model Diagnostics**:
#    - Reveals whether the model uses features in medically/biologically plausible ways
#    - Detects over-reliance on non-actionable features (e.g., "patient ID")
#
# 2. **Actionable Interventions**:
#    - Identifies features where small changes yield prediction flips (practical for real-world use)
#    - Warns against futile single-feature interventions when success rates are low
#
# 3. **Trust & Validation**:
#    - Directional consistency with domain knowledge increases model credibility
#    - Inconsistencies flag potential data leakage or artifacts
#
# ---
#
# ### **Real-World Analogy: Medical Diagnosis**
# Imagine a tumor classifier where:
# - **High Success Rate**: "Radius" (easy to measure, clearly malignant if large)
# - **Directional Consistency**: All doctors agree "larger = worse"
# - **Large Deltas**: "Texture" requires extreme changes to matter (rare edge cases)
#
# This analysis helps clinicians:
# 1. Focus on measurable, impactful features
# 2. Avoid wasting time on ambiguous characteristics
# 3. Understand when combined factors must be addressed
#
# By linking model behavior to domain reality, it bridges the gap between ML outputs and practical decision-making.

# %% [markdown]
# ## First version of counterfactual analysis for RF Classifier

# %%
# # 6. Advanced Counterfactual Generation for Local Explanation
# def counterfactual_search(instance, model, feature_names, step=0.05, max_iter=50):
#     orig_pred = model.predict(pd.DataFrame([instance], columns=feature_names))[0]
#     counterfactuals = {}
#     for idx, feat in enumerate(feature_names):
#         modified = instance.copy()
#         for direction in [1, -1]:
#             temp_instance = modified.copy()
#             for i in range(max_iter):
#                 temp_instance[idx] += direction * step
#                 new_pred = model.predict(pd.DataFrame([temp_instance], columns=feature_names))[0]
#                 if new_pred != orig_pred:
#                     counterfactuals[feat] = (direction * step * (i+1), new_pred)
#                     break
#             else:
#                 counterfactuals[feat] = (None, orig_pred)
#     return counterfactuals

# instance = X.iloc[1].values
# y_label = y[1]
# cf_results = counterfactual_search(instance, rf, list(X.columns))
# print("\nCounterfactual adjustments to flip prediction:")
# for feat, (change, new_pred) in cf_results.items():
#     if change is not None:
#         print(f" - {feat}: adjust by {change:.2f} to yield prediction {new_pred}")
#     else:
#         print(f" - {feat}: no flip found within search limits.")

# %%
# 7. Explanation Aggregation and Visualization using Parallel Sets
def rules_to_dataframe(rule_texts, max_conditions=5):
    rows = []
    for rule in rule_texts:
        conditions = re.findall(r'\([^)]+\)', rule)
        row = conditions[:max_conditions] + ['None'] * (max_conditions - len(conditions))
        rows.append(row)
    cols = [f'Condition {i+1}' for i in range(max_conditions)]
    return pd.DataFrame(rows, columns=cols)

df_rules = rules_to_dataframe(all_rule_texts, max_conditions=5)

# %%
# To ensure the length of 'y' matches the number of rows in df_rules,
# let's create a mapping of rule to the majority class label of the trees
def get_majority_class_for_rule(rule):
    rule_idx = all_rule_texts.index(rule)
    # Get predictions from each tree in the ensemble
    predictions = [est.predict([X.iloc[rule_idx]])[0] for est in rf.estimators_]
    # Return the majority class
    return np.bincount(predictions).argmax()

# Assign the majority class of each rule
rule_classes = [get_majority_class_for_rule(rule) for rule in all_rule_texts]

# Sort the categories manually before plotting
for col in df_rules.columns:
    df_rules[col] = pd.Categorical(df_rules[col], categories=sorted(df_rules[col].unique()), ordered=True)

# %% [markdown]
# ##### Add aggreggated decision paths and conditions and combine different thresholds from the same feature to create a decision rule

# %%
# Global Explanation: Visualize all rules from the ensemble
fig_global = px.parallel_categories(
    df_rules,
    dimensions=df_rules.columns,
    color=rule_classes,  # Use the majority class for each rule
    color_continuous_scale=px.colors.sequential.Viridis,
    title="Global Parallel Sets of Decision Rules"
)
fig_global.update_layout(
height = 1200, width = 3200,    autosize=True
)
fig_global.show()

# %%
# Local Explanation: Filter rules that the given instance satisfies
def get_local_rules(instance, model, feature_names, threshold_margin=0.5):
    local_rules = []
    pattern = re.compile(r'\((.*?)\s*(<=|>)\s*([\d\.]+)\)')
    for rule in all_rule_texts:
        matches = pattern.findall(rule)
        satisfied = True
        for feat, op, thresh in matches:
            thresh_val = float(thresh)
            feat_index = list(feature_names).index(feat.strip())
            value = instance[feat_index]
            if op == "<=":
                if not (value <= thresh_val + threshold_margin):
                    satisfied = False
                    break
            elif op == ">":
                if not (value > thresh_val - threshold_margin):
                    satisfied = False
                    break
        if satisfied:
            local_rules.append(rule)
    return local_rules

# %%
df_local
# Out:
#                        Condition 1                     Condition 2  \
# 0   (worst concave points <= 0.14)         (mean texture <= 21.31)
# 1   (worst concave points <= 0.14)         (mean texture <= 21.31)
# 2    (worst concave points > 0.14)           (worst area > 492.25)
# 3    (worst concave points > 0.14)           (worst area > 492.25)
# 4    (worst concave points > 0.14)           (worst area > 492.25)
# 5        (worst concavity <= 0.26)  (worst concave points <= 0.16)
# 6        (worst concavity <= 0.26)   (worst concave points > 0.16)
# 7         (worst concavity > 0.26)      (worst perimeter > 100.59)
# 8         (worst concavity > 0.26)      (worst perimeter > 100.59)
# 9         (worst concavity > 0.26)      (worst perimeter > 100.59)
# 10        (worst concavity > 0.26)      (worst perimeter > 100.59)
# 11  (worst concave points <= 0.14)            (mean area > 694.10)
# 12  (worst concave points <= 0.14)            (mean area > 694.10)
# 13  (worst concave points <= 0.14)            (mean area > 694.10)
# 14   (worst concave points > 0.14)          (worst radius > 16.29)
# 15   (worst concave points > 0.14)          (worst radius > 16.29)
# 16   (worst concave points > 0.14)          (worst radius > 16.29)
# 17          (worst radius > 16.80)          (mean texture > 15.82)
# 18          (worst radius > 16.80)          (mean texture > 15.82)
# 19          (worst radius > 16.80)          (mean texture > 15.82)
# 20            (area error > 34.85)   (mean concave points <= 0.05)
# 21            (area error > 34.85)   (mean concave points <= 0.05)
# 22            (area error > 34.85)    (mean concave points > 0.05)
# 23     (worst compactness <= 0.28)        (mean perimeter > 97.92)
# 24      (worst compactness > 0.28)   (mean concave points <= 0.05)
# 25      (worst compactness > 0.28)    (mean concave points > 0.05)
# 26      (worst compactness > 0.28)    (mean concave points > 0.05)
# 27      (worst compactness > 0.28)    (mean concave points > 0.05)
# 28      (worst compactness > 0.28)    (mean concave points > 0.05)
# 29      (worst compactness > 0.28)    (mean concave points > 0.05)
# 30      (worst perimeter > 105.15)   (mean concave points <= 0.05)
# 31      (worst perimeter > 105.15)   (mean concave points <= 0.05)
# 32      (worst perimeter > 105.15)    (mean concave points > 0.05)
# 33           (mean radius > 14.98)       (worst concavity <= 0.22)
# 34           (mean radius > 14.98)       (worst concavity <= 0.22)
# 35           (mean radius > 14.98)       (worst concavity <= 0.22)
# 36           (mean radius > 14.98)        (worst concavity > 0.22)
# 37           (mean radius > 14.98)        (worst concavity > 0.22)
# 38           (mean radius > 14.98)        (worst concavity > 0.22)
# 39        (mean perimeter > 98.76)          (mean texture > 14.10)
# 40        (mean perimeter > 98.76)          (mean texture > 14.10)
# 41        (mean perimeter > 98.76)          (mean texture > 14.10)
# 42        (mean concavity <= 0.09)          (worst radius > 18.64)
# 43         (mean concavity > 0.09)      (worst perimeter > 102.25)
# 44         (mean concavity > 0.09)      (worst perimeter > 102.25)
#
#                           Condition 3                     Condition 4  \
# 0               (worst area > 947.60)       (worst concavity <= 0.19)
# 1               (worst area > 947.60)        (worst concavity > 0.19)
# 2            (perimeter error > 1.54)      (mean compactness <= 0.10)
# 3            (perimeter error > 1.54)      (mean compactness <= 0.10)
# 4            (perimeter error > 1.54)       (mean compactness > 0.10)
# 5              (worst area > 1058.00)                            None
# 6                                None                            None
# 7       (mean concave points <= 0.04)  (concave points error <= 0.01)
# 8       (mean concave points <= 0.04)   (concave points error > 0.01)
# 9       (mean concave points <= 0.04)   (concave points error > 0.01)
# 10       (mean concave points > 0.04)            (mean area > 656.50)
# 11            (worst texture > 19.74)         (texture error <= 1.44)
# 12            (worst texture > 19.74)          (texture error > 1.44)
# 13            (worst texture > 19.74)          (texture error > 1.44)
# 14     (worst concave points <= 0.15)          (radius error <= 0.43)
# 15     (worst concave points <= 0.15)           (radius error > 0.43)
# 16      (worst concave points > 0.15)                            None
# 17            (mean symmetry <= 0.15)         (mean symmetry <= 0.15)
# 18            (mean symmetry <= 0.15)          (mean symmetry > 0.15)
# 19             (mean symmetry > 0.15)                            None
# 20          (perimeter error <= 4.12)      (worst smoothness <= 0.14)
# 21          (perimeter error <= 4.12)       (worst smoothness > 0.14)
# 22            (worst texture > 19.03)                            None
# 23            (worst texture > 21.14)                            None
# 24             (worst radius > 16.82)                            None
# 25             (worst radius > 15.39)            (area error > 16.20)
# 26             (worst radius > 15.39)            (area error > 16.20)
# 27             (worst radius > 15.39)            (area error > 16.20)
# 28             (worst radius > 15.39)            (area error > 16.20)
# 29             (worst radius > 15.39)            (area error > 16.20)
# 30              (worst area > 957.45)          (mean radius <= 16.77)
# 31              (worst area > 957.45)          (mean radius <= 16.77)
# 32             (mean texture > 16.53)                            None
# 33          (mean smoothness <= 0.09)       (concavity error <= 0.03)
# 34          (mean smoothness <= 0.09)        (concavity error > 0.03)
# 35           (mean smoothness > 0.09)                            None
# 36         (worst perimeter > 111.10)          (radius error <= 0.24)
# 37         (worst perimeter > 111.10)          (radius error <= 0.24)
# 38         (worst perimeter > 111.10)           (radius error > 0.24)
# 39  (fractal dimension error <= 0.00)     (compactness error <= 0.02)
# 40  (fractal dimension error <= 0.00)      (compactness error > 0.02)
# 41   (fractal dimension error > 0.00)                            None
# 42                               None                            None
# 43      (mean concave points <= 0.04)                            None
# 44       (mean concave points > 0.04)          (mean texture > 14.12)
#
#                        Condition 5
# 0                             None
# 1                             None
# 2        (worst concavity <= 0.21)
# 3         (worst concavity > 0.21)
# 4                             None
# 5                             None
# 6                             None
# 7                             None
# 8        (worst concavity <= 0.26)
# 9         (worst concavity > 0.26)
# 10                            None
# 11                            None
# 12          (radius error <= 0.50)
# 13           (radius error > 0.50)
# 14                            None
# 15                            None
# 16                            None
# 17                            None
# 18                            None
# 19                            None
# 20                            None
# 21                            None
# 22                            None
# 23                            None
# 24                            None
# 25       (worst concavity <= 0.26)
# 26       (worst concavity <= 0.26)
# 27        (worst concavity > 0.26)
# 28        (worst concavity > 0.26)
# 29        (worst concavity > 0.26)
# 30       (mean smoothness <= 0.09)
# 31        (mean smoothness > 0.09)
# 32                            None
# 33                            None
# 34                            None
# 35                            None
# 36  (worst concave points <= 0.13)
# 37   (worst concave points > 0.13)
# 38                            None
# 39                            None
# 40                            None
# 41                            None
# 42                            None
# 43                            None
# 44                            None

# %%
local_rule_texts = get_local_rules(instance, rf, X.columns)
df_local = rules_to_dataframe(local_rule_texts, max_conditions=5)
# Local Parallel Sets Visualization
fig_local = px.parallel_categories(
    df_local,
    dimensions=df_local.columns,
    # color="class",  # Use the class label of the selected instance
    color_continuous_scale=px.colors.sequential.Plasma,
    title="Local Parallel Sets of Rules for the Selected Instance"
)
# fig_local.update_traces(categoryorders={col: "array" for col in df_local.columns})
fig_local.update_layout(
    margin=dict(t=50, b=50, l=50, r=50),
    autosize=True
)

fig_local.update_layout(width = 1500, height = 800)
fig_local.show()
