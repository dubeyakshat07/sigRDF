# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import networkx as nx
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import _tree
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import AgglomerativeClustering
import plotly.express as px
from pulp import LpProblem, LpVariable, LpMaximize, lpSum, LpStatus, value
from sklearn.decomposition import PCA

import seaborn as sns
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv("./data/diabetes.csv")

# %%
X = df.drop("Outcome", axis = 1)
y = df[["Outcome"]]

feature_names = X.columns
target_names = y.columns

# %%
# Load the breast cancer dataset
# data = load_breast_cancer()
# X = data.data
# y = data.target
# feature_names = data.feature_names
# target_names = data.target_names

X = pd.DataFrame(X, columns = feature_names)
# Train RandomForestClassifier
rf = RandomForestClassifier(n_estimators=10, random_state=42)
rf.fit(X, y)
# Out:
# /Users/DubeyA-Dev/miniconda3/envs/taylor/lib/python3.10/site-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(n_estimators=10, random_state=42)

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# ## Calculating feature usage in decision paths and feature importance based on impurity reduction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import plot_tree

def get_decision_paths(model, X):
    decision_paths = []
    
    # Iterate over each tree in the forest
    for tree in model.estimators_:
        tree_paths = extract_tree_paths(tree, X)
        decision_paths.append(tree_paths)
    
    return decision_paths

def extract_tree_paths(tree, X):
    # Get the decision tree structure
    children_left = tree.tree_.children_left
    children_right = tree.tree_.children_right
    feature = tree.tree_.feature
    threshold = tree.tree_.threshold
    value = tree.tree_.value
    
    paths = []
    
    # For each sample in X, trace the path from root to leaf
    for _, sample in X.iterrows():
        path = []
        node = 0  # Start from the root node
        
        while children_left[node] != children_right[node]:  # Not a leaf node
            feature_index = feature[node]
            threshold_value = threshold[node]
            feature_name = X.columns[feature_index]
            
            # Record the decision (feature, threshold, direction)
            if sample[feature_name] <= threshold_value:
                path.append((feature_name, threshold_value, "left"))
                node = children_left[node]
            else:
                path.append((feature_name, threshold_value, "right"))
                node = children_right[node]
        
        # At the leaf node, record the leaf prediction
        leaf_prediction = np.argmax(value[node])
        paths.append((path, leaf_prediction))
    
    return paths

def calculate_split_importance(model):
    importance_weights = []
    
    for tree in model.estimators_:
        tree_importance = extract_split_importance(tree)
        importance_weights.append(tree_importance)
    
    return importance_weights

def extract_split_importance(tree):
    # Get the decision tree structure
    children_left = tree.tree_.children_left
    children_right = tree.tree_.children_right
    feature = tree.tree_.feature
    impurity = tree.tree_.impurity
    
    importance_weights = []
    
    for node in range(tree.tree_.node_count):
        if children_left[node] != children_right[node]:  # Not a leaf node
            feature_index = feature[node]
            left_impurity = impurity[children_left[node]]
            right_impurity = impurity[children_right[node]]
            current_impurity = impurity[node]
            
            # Calculate the impurity reduction (importance weight)
            impurity_reduction = current_impurity - (left_impurity + right_impurity) / 2
            importance_weights.append((feature_index, impurity_reduction))
    
    return importance_weights

def visualize_decision_paths(decision_paths, feature_names):
    feature_count = {feature: 0 for feature in feature_names}
    
    # Count feature usage across all decision paths
    for tree_paths in decision_paths:
        for path, _ in tree_paths:
            for feature, _, _ in path:
                feature_count[feature] += 1

    # Create a bar plot for feature usage count
    feature_usage = list(feature_count.items())
    feature_usage.sort(key=lambda x: x[1], reverse=True)

    features, counts = zip(*feature_usage)

    plt.figure(figsize=(10, 6))
    sns.barplot(x=counts, y=features, palette='viridis')
    plt.title('Feature Usage in Decision Paths', fontsize=16)
    plt.xlabel('Number of Times Feature Appears', fontsize=14)
    plt.ylabel('Feature', fontsize=14)
    plt.show()

def visualize_feature_importance(importance_weights, feature_names):
    avg_importance = {feature: [] for feature in feature_names}
    
    # Aggregate importance across all trees
    for tree_importance in importance_weights:
        for feature_index, imp in tree_importance:
            feature_name = feature_names[feature_index]
            avg_importance[feature_name].append(imp)
    
    avg_importance = {feature: np.mean(imp) for feature, imp in avg_importance.items() if imp}
    
    # Sort by importance
    sorted_importance = sorted(avg_importance.items(), key=lambda x: x[1], reverse=True)
    features, importance = zip(*sorted_importance)

    # Plot feature importance
    plt.figure(figsize=(10, 6))
    sns.barplot(x=importance, y=features, palette='viridis')
    plt.title('Feature Importance Based on Impurity Reduction', fontsize=16)
    plt.xlabel('Average Impurity Reduction', fontsize=14)
    plt.ylabel('Feature', fontsize=14)
    plt.show()

def visualize_decision_trees(model, feature_names, target_names):
    for i, tree in enumerate(model.estimators_):
        plt.figure(figsize=(20, 10))
        plot_tree(tree, feature_names=feature_names, class_names=target_names, filled=True)
        plt.title(f"Decision Tree {i + 1}")
        plt.show()

# Get decision paths and importance weights
decision_paths = get_decision_paths(rf, X)
importance_weights = calculate_split_importance(rf)

# Visualize decision paths
visualize_decision_paths(decision_paths, X.columns)

# Visualize feature importance
visualize_feature_importance(importance_weights, X.columns)

# Visualize decision trees
# visualize_decision_trees(rf, X.columns, target_names)
# Out:
# /var/folders/tk/qh_5gfz51996p7zxwjyl8r140000gp/T/ipykernel_92580/2676868043.py:98: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=counts, y=features, palette='viridis')
# /var/folders/tk/qh_5gfz51996p7zxwjyl8r140000gp/T/ipykernel_92580/2676868043.py:121: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=importance, y=features, palette='viridis')

# %%
# Function to extract decision paths/rules

from sklearn.preprocessing import LabelEncoder
def extract_rule_paths(tree, feature_names):
    tree_ = tree.tree_
    feature = tree_.feature
    threshold = tree_.threshold
    rules = []

    def recurse(node, current_rule):
        if tree_.children_left[node] == _tree.TREE_LEAF:
            rule_str = " AND ".join(current_rule)
            rules.append(rule_str)
        else:
            rule_left = f"({feature_names[feature[node]]} <= {threshold[node]:.2f})"
            current_rule.append(rule_left)
            recurse(tree_.children_left[node], current_rule)
            current_rule.pop()

            rule_right = f"({feature_names[feature[node]]} > {threshold[node]:.2f})"
            current_rule.append(rule_right)
            recurse(tree_.children_right[node], current_rule)
            current_rule.pop()

    recurse(0, [])
    return rules

# Custom rule encoder that preserves the structure
def encode_rule_structure(rules):
    encoded_rules = []
    
    # Create a label encoder for feature names (make sure to fit it first)
    feature_encoder = LabelEncoder()
    feature_encoder.fit(feature_names)  # Fit encoder on all feature names
    
    for rule in rules:
        encoded_rule = []
        
        # Split the rule into components and encode
        components = rule.split(" AND ")
        for component in components:
            # Handle the comparison operators and extract feature names
            if "<=" in component:
                feature_name, threshold = component.split(" <= ")
                feature_name = feature_name.strip("()")  # Clean up extra characters
                encoded_rule.append(f"FEAT_{feature_encoder.transform([feature_name])[0]}_LTE_{threshold}")
            elif ">" in component:
                feature_name, threshold = component.split(" > ")
                feature_name = feature_name.strip("()")  # Clean up extra characters
                encoded_rule.append(f"FEAT_{feature_encoder.transform([feature_name])[0]}_GT_{threshold}")
        
        encoded_rules.append(" AND ".join(encoded_rule))
    
    return encoded_rules

# Extract all rules from Random Forest models
all_rule_texts = []
for est in rf.estimators_:
    rules = extract_rule_paths(est, feature_names)
    all_rule_texts.extend(rules)

# Encode the rules
encoded_rules = encode_rule_structure(all_rule_texts)

# Show some of the encoded rules
for i in range(10):
    print(encoded_rules[i])
# Out:
# FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_LTE_25.45) AND FEAT_4_LTE_132.00) AND FEAT_6_LTE_9.50) AND FEAT_3_LTE_0.67)
# FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_LTE_25.45) AND FEAT_4_LTE_132.00) AND FEAT_6_LTE_9.50) AND FEAT_3_GT_0.67) AND FEAT_4_LTE_107.50) AND FEAT_0_LTE_24.00)
# FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_LTE_25.45) AND FEAT_4_LTE_132.00) AND FEAT_6_LTE_9.50) AND FEAT_3_GT_0.67) AND FEAT_4_LTE_107.50) AND FEAT_0_GT_24.00)
# FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_LTE_25.45) AND FEAT_4_LTE_132.00) AND FEAT_6_LTE_9.50) AND FEAT_3_GT_0.67) AND FEAT_4_GT_107.50)
# FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_LTE_25.45) AND FEAT_4_LTE_132.00) AND FEAT_6_GT_9.50) AND FEAT_1_LTE_11.80)
# FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_LTE_25.45) AND FEAT_4_LTE_132.00) AND FEAT_6_GT_9.50) AND FEAT_1_GT_11.80)
# FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_LTE_25.45) AND FEAT_4_GT_132.00) AND FEAT_6_LTE_3.50)
# FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_LTE_25.45) AND FEAT_4_GT_132.00) AND FEAT_6_GT_3.50) AND FEAT_6_LTE_4.50)
# FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_LTE_25.45) AND FEAT_4_GT_132.00) AND FEAT_6_GT_3.50) AND FEAT_6_GT_4.50)
# FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_GT_25.45) AND FEAT_1_LTE_25.70) AND FEAT_6_LTE_7.50) AND FEAT_5_LTE_43.00) AND FEAT_3_LTE_0.30)

# %%
# Function to decode an encoded rule
def decode_rule_structure(encoded_rules):
    decoded_rules = []

    # Create a label encoder for feature names (must fit the same encoder used for encoding)
    feature_encoder = LabelEncoder()
    feature_encoder.fit(feature_names)  # Fit encoder on all feature names
    
    for encoded_rule in encoded_rules:
        decoded_rule = []
        
        # Split the encoded rule into components
        components = encoded_rule.split(" AND ")
        
        for component in components:
            # Extract the feature index and threshold from the encoded part
            if "_LTE_" in component:  # Handling "<="
                feature_index, threshold = component.split("_LTE_")
                feature_index = int(feature_index.replace("FEAT_", ""))
                decoded_feature = feature_encoder.inverse_transform([feature_index])[0]  # Decode feature name
                decoded_rule.append(f"({decoded_feature} <= {threshold})")
            elif "_GT_" in component:  # Handling ">"
                feature_index, threshold = component.split("_GT_")
                feature_index = int(feature_index.replace("FEAT_", ""))
                decoded_feature = feature_encoder.inverse_transform([feature_index])[0]  # Decode feature name
                decoded_rule.append(f"({decoded_feature} > {threshold})")
        
        decoded_rules.append(" AND ".join(decoded_rule))
    
    return decoded_rules

# Example of decoding the encoded rules
encoded_rule_example = ["FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_LTE_25.45) AND FEAT_4_LTE_132.00) AND FEAT_6_GT_9.50) AND FEAT_1_LTE_11.80)"]  # Example encoded rule
decoded_rule = decode_rule_structure(encoded_rule_example)

# Show the decoded rule
print(decoded_rule[0])  # Example output: (mean radius <= 15.5) AND (mean smoothness > 20.1)
# Out:
# (BMI <= 29.65)) AND (Insulin <= 325.50)) AND (Glucose <= 164.00)) AND (BMI <= 25.45)) AND (Glucose <= 132.00)) AND (Pregnancies > 9.50)) AND (BMI <= 11.80))

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import AgglomerativeClustering

# Step 1: Vectorize the encoded rules using CountVectorizer or TfidfVectorizer
vectorizer = CountVectorizer()  # You can also try TfidfVectorizer
encoded_rule_vectors = vectorizer.fit_transform(encoded_rules)

# Step 2: Perform hierarchical clustering on the vectorized encoded rules
n_clusters = 5
clustering = AgglomerativeClustering(n_clusters=n_clusters, metric='cosine', linkage='average')
labels = clustering.fit_predict(encoded_rule_vectors.toarray())

# Step 3: Group the rules by their clusters
clustered_rules = {i: [] for i in range(n_clusters)}
for encoded_rule, label in zip(encoded_rules, labels):
    clustered_rules[label].append(encoded_rule)

# Example: Print some clustered rules
for cluster_id, rules in clustered_rules.items():
    print(f"Cluster {cluster_id}:")
    for rule in rules[:5]:  # Show first 5 rules in each cluster
        print(f"  {rule}")
    print("\n")
# Out:
# Cluster 0:
#   FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_LTE_25.45) AND FEAT_4_LTE_132.00) AND FEAT_6_LTE_9.50) AND FEAT_3_LTE_0.67)
#   FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_LTE_25.45) AND FEAT_4_LTE_132.00) AND FEAT_6_LTE_9.50) AND FEAT_3_GT_0.67) AND FEAT_4_LTE_107.50) AND FEAT_0_LTE_24.00)
#   FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_LTE_25.45) AND FEAT_4_LTE_132.00) AND FEAT_6_LTE_9.50) AND FEAT_3_GT_0.67) AND FEAT_4_LTE_107.50) AND FEAT_0_GT_24.00)
#   FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_LTE_25.45) AND FEAT_4_LTE_132.00) AND FEAT_6_LTE_9.50) AND FEAT_3_GT_0.67) AND FEAT_4_GT_107.50)
#   FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_LTE_25.45) AND FEAT_4_LTE_132.00) AND FEAT_6_GT_9.50) AND FEAT_1_LTE_11.80)
#
#
# Cluster 1:
#   FEAT_0_LTE_24.50) AND FEAT_4_LTE_131.50) AND FEAT_1_GT_45.40)
#
#
# Cluster 2:
#   FEAT_1_GT_30.25) AND FEAT_2_GT_101.00)
#
#
# Cluster 3:
#   FEAT_1_LTE_29.65) AND FEAT_5_GT_325.50)
#
#
# Cluster 4:
#   FEAT_3_LTE_0.22) AND FEAT_1_GT_45.40)

# %%
# 5. Visualize the clusters
# Create a DataFrame for the clusters and rules
cluster_df = pd.DataFrame({
    'Cluster': labels,
    'Rule': all_rule_texts
})

# %%
# Mapping from encoded feature names to actual feature names
feature_mapping = {f"FEAT_{i}": feature for i, feature in enumerate(X.columns)}

# Initialize edge weights
edge_weights = {}

# Debug: Check rule extraction and feature matching
for rule_text in encoded_rules:
    # Extract the features and thresholds
    conditions = re.findall(r'FEAT_(\d+)_\w+_([\d\.]+)', rule_text)
    
    # Debug: Print the extracted features and thresholds
    print(f"Rule: {rule_text}")
    print(f"Extracted Conditions: {conditions}")

    # Map FEAT_0, FEAT_1, ... back to actual feature names in the dataset
    features_in_rule = [feature_mapping[f"FEAT_{cond[0]}"] for cond in conditions if f"FEAT_{cond[0]}" in feature_mapping]

    # Debug: Print the features that match the dataset
    print(f"Matching Features: {features_in_rule}")

    # If features are valid, build the edges
    if len(features_in_rule) > 1:
        for i in range(len(features_in_rule) - 1):
            edge = (features_in_rule[i], features_in_rule[i+1])
            edge_weights[edge] = edge_weights.get(edge, 0) + 1

# Create a directed graph using networkx
G = nx.DiGraph()

# Add edges and their weights to the graph
for (f_from, f_to), weight in edge_weights.items():
    G.add_edge(f_from, f_to, weight=weight)

# # Debug: Check the graph before proceeding
# print(f"Graph Nodes: {list(G.nodes())}")
# print(f"Graph Edges: {list(G.edges(data=True))}")

# Create a reversed graph (H) with negated weights for minimum spanning arborescence
H = nx.DiGraph()
for u, v, d in G.edges(data=True):
    H.add_edge(u, v, weight=-d['weight'])

# Compute the Minimum Spanning Arborescence (MSA)
if len(list(H.nodes())) > 0:
    root = list(H.nodes())[0]  # Choose an arbitrary root node
    msa = nx.minimum_spanning_arborescence(H)

    # Revert the edge weights to positive after the spanning tree computation
    for u, v, d in msa.edges(data=True):
        d['weight'] = -d['weight']
    
    # Plot the graph
    plt.figure(figsize=(15, 15))
    pos = nx.circular_layout(msa)  # Using circular layout for better visualization
    edge_labels = nx.get_edge_attributes(msa, 'weight')

    # Draw the nodes, edges, and edge labels
    nx.draw(msa, pos, with_labels=True, node_size=21000, node_color="lightcoral", arrowsize=20)
    nx.draw_networkx_edge_labels(msa, pos, edge_labels=edge_labels)

    plt.title("Surrogate Interpretable Graph (MSA) [Un-optimized]")
    plt.show()
else:
    print("Graph H is empty. No feature transitions were detected.")
# Out:
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_LTE_25.45) AND FEAT_4_LTE_132.00) AND FEAT_6_LTE_9.50) AND FEAT_3_LTE_0.67)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('4', '132.00'), ('6', '9.50'), ('3', '0.67')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Insulin', 'DiabetesPedigreeFunction', 'SkinThickness']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_LTE_25.45) AND FEAT_4_LTE_132.00) AND FEAT_6_LTE_9.50) AND FEAT_3_GT_0.67) AND FEAT_4_LTE_107.50) AND FEAT_0_LTE_24.00)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('4', '132.00'), ('6', '9.50'), ('3', '0.67'), ('4', '107.50'), ('0', '24.00')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Insulin', 'DiabetesPedigreeFunction', 'SkinThickness', 'Insulin', 'Pregnancies']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_LTE_25.45) AND FEAT_4_LTE_132.00) AND FEAT_6_LTE_9.50) AND FEAT_3_GT_0.67) AND FEAT_4_LTE_107.50) AND FEAT_0_GT_24.00)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('4', '132.00'), ('6', '9.50'), ('3', '0.67'), ('4', '107.50'), ('0', '24.00')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Insulin', 'DiabetesPedigreeFunction', 'SkinThickness', 'Insulin', 'Pregnancies']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_LTE_25.45) AND FEAT_4_LTE_132.00) AND FEAT_6_LTE_9.50) AND FEAT_3_GT_0.67) AND FEAT_4_GT_107.50)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('4', '132.00'), ('6', '9.50'), ('3', '0.67'), ('4', '107.50')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Insulin', 'DiabetesPedigreeFunction', 'SkinThickness', 'Insulin']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_LTE_25.45) AND FEAT_4_LTE_132.00) AND FEAT_6_GT_9.50) AND FEAT_1_LTE_11.80)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('4', '132.00'), ('6', '9.50'), ('1', '11.80')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Insulin', 'DiabetesPedigreeFunction', 'Glucose']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_LTE_25.45) AND FEAT_4_LTE_132.00) AND FEAT_6_GT_9.50) AND FEAT_1_GT_11.80)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('4', '132.00'), ('6', '9.50'), ('1', '11.80')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Insulin', 'DiabetesPedigreeFunction', 'Glucose']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_LTE_25.45) AND FEAT_4_GT_132.00) AND FEAT_6_LTE_3.50)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('4', '132.00'), ('6', '3.50')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Insulin', 'DiabetesPedigreeFunction']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_LTE_25.45) AND FEAT_4_GT_132.00) AND FEAT_6_GT_3.50) AND FEAT_6_LTE_4.50)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('4', '132.00'), ('6', '3.50'), ('6', '4.50')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Insulin', 'DiabetesPedigreeFunction', 'DiabetesPedigreeFunction']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_LTE_25.45) AND FEAT_4_GT_132.00) AND FEAT_6_GT_3.50) AND FEAT_6_GT_4.50)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('4', '132.00'), ('6', '3.50'), ('6', '4.50')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Insulin', 'DiabetesPedigreeFunction', 'DiabetesPedigreeFunction']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_GT_25.45) AND FEAT_1_LTE_25.70) AND FEAT_6_LTE_7.50) AND FEAT_5_LTE_43.00) AND FEAT_3_LTE_0.30)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('1', '25.70'), ('6', '7.50'), ('5', '43.00'), ('3', '0.30')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Glucose', 'DiabetesPedigreeFunction', 'BMI', 'SkinThickness']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_GT_25.45) AND FEAT_1_LTE_25.70) AND FEAT_6_LTE_7.50) AND FEAT_5_LTE_43.00) AND FEAT_3_GT_0.30)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('1', '25.70'), ('6', '7.50'), ('5', '43.00'), ('3', '0.30')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Glucose', 'DiabetesPedigreeFunction', 'BMI', 'SkinThickness']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_GT_25.45) AND FEAT_1_LTE_25.70) AND FEAT_6_LTE_7.50) AND FEAT_5_GT_43.00)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('1', '25.70'), ('6', '7.50'), ('5', '43.00')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Glucose', 'DiabetesPedigreeFunction', 'BMI']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_GT_25.45) AND FEAT_1_LTE_25.70) AND FEAT_6_GT_7.50)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('1', '25.70'), ('6', '7.50')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Glucose', 'DiabetesPedigreeFunction']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_GT_25.45) AND FEAT_1_GT_25.70) AND FEAT_3_LTE_0.88) AND FEAT_4_LTE_104.50)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('1', '25.70'), ('3', '0.88'), ('4', '104.50')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Glucose', 'SkinThickness', 'Insulin']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_GT_25.45) AND FEAT_1_GT_25.70) AND FEAT_3_LTE_0.88) AND FEAT_4_GT_104.50) AND FEAT_5_LTE_11.00) AND FEAT_2_LTE_79.00) AND FEAT_4_LTE_123.00)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('1', '25.70'), ('3', '0.88'), ('4', '104.50'), ('5', '11.00'), ('2', '79.00'), ('4', '123.00')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Glucose', 'SkinThickness', 'Insulin', 'BMI', 'BloodPressure', 'Insulin']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_GT_25.45) AND FEAT_1_GT_25.70) AND FEAT_3_LTE_0.88) AND FEAT_4_GT_104.50) AND FEAT_5_LTE_11.00) AND FEAT_2_LTE_79.00) AND FEAT_4_GT_123.00) AND FEAT_1_LTE_28.35) AND FEAT_4_LTE_128.50) AND FEAT_3_LTE_0.18)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('1', '25.70'), ('3', '0.88'), ('4', '104.50'), ('5', '11.00'), ('2', '79.00'), ('4', '123.00'), ('1', '28.35'), ('4', '128.50'), ('3', '0.18')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Glucose', 'SkinThickness', 'Insulin', 'BMI', 'BloodPressure', 'Insulin', 'Glucose', 'Insulin', 'SkinThickness']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_GT_25.45) AND FEAT_1_GT_25.70) AND FEAT_3_LTE_0.88) AND FEAT_4_GT_104.50) AND FEAT_5_LTE_11.00) AND FEAT_2_LTE_79.00) AND FEAT_4_GT_123.00) AND FEAT_1_LTE_28.35) AND FEAT_4_LTE_128.50) AND FEAT_3_GT_0.18)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('1', '25.70'), ('3', '0.88'), ('4', '104.50'), ('5', '11.00'), ('2', '79.00'), ('4', '123.00'), ('1', '28.35'), ('4', '128.50'), ('3', '0.18')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Glucose', 'SkinThickness', 'Insulin', 'BMI', 'BloodPressure', 'Insulin', 'Glucose', 'Insulin', 'SkinThickness']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_GT_25.45) AND FEAT_1_GT_25.70) AND FEAT_3_LTE_0.88) AND FEAT_4_GT_104.50) AND FEAT_5_LTE_11.00) AND FEAT_2_LTE_79.00) AND FEAT_4_GT_123.00) AND FEAT_1_LTE_28.35) AND FEAT_4_GT_128.50)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('1', '25.70'), ('3', '0.88'), ('4', '104.50'), ('5', '11.00'), ('2', '79.00'), ('4', '123.00'), ('1', '28.35'), ('4', '128.50')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Glucose', 'SkinThickness', 'Insulin', 'BMI', 'BloodPressure', 'Insulin', 'Glucose', 'Insulin']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_GT_25.45) AND FEAT_1_GT_25.70) AND FEAT_3_LTE_0.88) AND FEAT_4_GT_104.50) AND FEAT_5_LTE_11.00) AND FEAT_2_LTE_79.00) AND FEAT_4_GT_123.00) AND FEAT_1_GT_28.35)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('1', '25.70'), ('3', '0.88'), ('4', '104.50'), ('5', '11.00'), ('2', '79.00'), ('4', '123.00'), ('1', '28.35')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Glucose', 'SkinThickness', 'Insulin', 'BMI', 'BloodPressure', 'Insulin', 'Glucose']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_GT_25.45) AND FEAT_1_GT_25.70) AND FEAT_3_LTE_0.88) AND FEAT_4_GT_104.50) AND FEAT_5_LTE_11.00) AND FEAT_2_GT_79.00) AND FEAT_3_LTE_0.25) AND FEAT_2_LTE_82.00)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('1', '25.70'), ('3', '0.88'), ('4', '104.50'), ('5', '11.00'), ('2', '79.00'), ('3', '0.25'), ('2', '82.00')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Glucose', 'SkinThickness', 'Insulin', 'BMI', 'BloodPressure', 'SkinThickness', 'BloodPressure']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_GT_25.45) AND FEAT_1_GT_25.70) AND FEAT_3_LTE_0.88) AND FEAT_4_GT_104.50) AND FEAT_5_LTE_11.00) AND FEAT_2_GT_79.00) AND FEAT_3_LTE_0.25) AND FEAT_2_GT_82.00)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('1', '25.70'), ('3', '0.88'), ('4', '104.50'), ('5', '11.00'), ('2', '79.00'), ('3', '0.25'), ('2', '82.00')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Glucose', 'SkinThickness', 'Insulin', 'BMI', 'BloodPressure', 'SkinThickness', 'BloodPressure']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_GT_25.45) AND FEAT_1_GT_25.70) AND FEAT_3_LTE_0.88) AND FEAT_4_GT_104.50) AND FEAT_5_LTE_11.00) AND FEAT_2_GT_79.00) AND FEAT_3_GT_0.25) AND FEAT_7_LTE_15.50)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('1', '25.70'), ('3', '0.88'), ('4', '104.50'), ('5', '11.00'), ('2', '79.00'), ('3', '0.25'), ('7', '15.50')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Glucose', 'SkinThickness', 'Insulin', 'BMI', 'BloodPressure', 'SkinThickness', 'Age']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_GT_25.45) AND FEAT_1_GT_25.70) AND FEAT_3_LTE_0.88) AND FEAT_4_GT_104.50) AND FEAT_5_LTE_11.00) AND FEAT_2_GT_79.00) AND FEAT_3_GT_0.25) AND FEAT_7_GT_15.50) AND FEAT_4_LTE_125.50)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('1', '25.70'), ('3', '0.88'), ('4', '104.50'), ('5', '11.00'), ('2', '79.00'), ('3', '0.25'), ('7', '15.50'), ('4', '125.50')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Glucose', 'SkinThickness', 'Insulin', 'BMI', 'BloodPressure', 'SkinThickness', 'Age', 'Insulin']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_GT_25.45) AND FEAT_1_GT_25.70) AND FEAT_3_LTE_0.88) AND FEAT_4_GT_104.50) AND FEAT_5_LTE_11.00) AND FEAT_2_GT_79.00) AND FEAT_3_GT_0.25) AND FEAT_7_GT_15.50) AND FEAT_4_GT_125.50)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('1', '25.70'), ('3', '0.88'), ('4', '104.50'), ('5', '11.00'), ('2', '79.00'), ('3', '0.25'), ('7', '15.50'), ('4', '125.50')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Glucose', 'SkinThickness', 'Insulin', 'BMI', 'BloodPressure', 'SkinThickness', 'Age', 'Insulin']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_GT_25.45) AND FEAT_1_GT_25.70) AND FEAT_3_LTE_0.88) AND FEAT_4_GT_104.50) AND FEAT_5_GT_11.00) AND FEAT_4_LTE_110.00) AND FEAT_2_LTE_66.00)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('1', '25.70'), ('3', '0.88'), ('4', '104.50'), ('5', '11.00'), ('4', '110.00'), ('2', '66.00')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Glucose', 'SkinThickness', 'Insulin', 'BMI', 'Insulin', 'BloodPressure']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_GT_25.45) AND FEAT_1_GT_25.70) AND FEAT_3_LTE_0.88) AND FEAT_4_GT_104.50) AND FEAT_5_GT_11.00) AND FEAT_4_LTE_110.00) AND FEAT_2_GT_66.00)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('1', '25.70'), ('3', '0.88'), ('4', '104.50'), ('5', '11.00'), ('4', '110.00'), ('2', '66.00')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Glucose', 'SkinThickness', 'Insulin', 'BMI', 'Insulin', 'BloodPressure']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_GT_25.45) AND FEAT_1_GT_25.70) AND FEAT_3_LTE_0.88) AND FEAT_4_GT_104.50) AND FEAT_5_GT_11.00) AND FEAT_4_GT_110.00)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('1', '25.70'), ('3', '0.88'), ('4', '104.50'), ('5', '11.00'), ('4', '110.00')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Glucose', 'SkinThickness', 'Insulin', 'BMI', 'Insulin']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_GT_25.45) AND FEAT_1_GT_25.70) AND FEAT_3_GT_0.88) AND FEAT_4_LTE_126.00)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('1', '25.70'), ('3', '0.88'), ('4', '126.00')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Glucose', 'SkinThickness', 'Insulin']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_LTE_164.00) AND FEAT_1_GT_25.45) AND FEAT_1_GT_25.70) AND FEAT_3_GT_0.88) AND FEAT_4_GT_126.00)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('1', '25.45'), ('1', '25.70'), ('3', '0.88'), ('4', '126.00')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'Glucose', 'Glucose', 'SkinThickness', 'Insulin']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_GT_164.00) AND FEAT_2_LTE_79.00)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('2', '79.00')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'BloodPressure']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_LTE_325.50) AND FEAT_4_GT_164.00) AND FEAT_2_GT_79.00)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50'), ('4', '164.00'), ('2', '79.00')]
# Matching Features: ['Glucose', 'BMI', 'Insulin', 'BloodPressure']
# Rule: FEAT_1_LTE_29.65) AND FEAT_5_GT_325.50)
# Extracted Conditions: [('1', '29.65'), ('5', '325.50')]
# Matching Features: ['Glucose', 'BMI']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_LTE_127.50) AND FEAT_1_LTE_38.35) AND FEAT_7_LTE_35.00) AND FEAT_0_LTE_22.50)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '38.35'), ('7', '35.00'), ('0', '22.50')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose', 'Age', 'Pregnancies']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_LTE_127.50) AND FEAT_1_LTE_38.35) AND FEAT_7_LTE_35.00) AND FEAT_0_GT_22.50) AND FEAT_2_LTE_53.00) AND FEAT_0_LTE_28.00) AND FEAT_7_LTE_10.00)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '38.35'), ('7', '35.00'), ('0', '22.50'), ('2', '53.00'), ('0', '28.00'), ('7', '10.00')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose', 'Age', 'Pregnancies', 'BloodPressure', 'Pregnancies', 'Age']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_LTE_127.50) AND FEAT_1_LTE_38.35) AND FEAT_7_LTE_35.00) AND FEAT_0_GT_22.50) AND FEAT_2_LTE_53.00) AND FEAT_0_LTE_28.00) AND FEAT_7_GT_10.00) AND FEAT_1_LTE_30.90)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '38.35'), ('7', '35.00'), ('0', '22.50'), ('2', '53.00'), ('0', '28.00'), ('7', '10.00'), ('1', '30.90')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose', 'Age', 'Pregnancies', 'BloodPressure', 'Pregnancies', 'Age', 'Glucose']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_LTE_127.50) AND FEAT_1_LTE_38.35) AND FEAT_7_LTE_35.00) AND FEAT_0_GT_22.50) AND FEAT_2_LTE_53.00) AND FEAT_0_LTE_28.00) AND FEAT_7_GT_10.00) AND FEAT_1_GT_30.90)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '38.35'), ('7', '35.00'), ('0', '22.50'), ('2', '53.00'), ('0', '28.00'), ('7', '10.00'), ('1', '30.90')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose', 'Age', 'Pregnancies', 'BloodPressure', 'Pregnancies', 'Age', 'Glucose']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_LTE_127.50) AND FEAT_1_LTE_38.35) AND FEAT_7_LTE_35.00) AND FEAT_0_GT_22.50) AND FEAT_2_LTE_53.00) AND FEAT_0_GT_28.00)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '38.35'), ('7', '35.00'), ('0', '22.50'), ('2', '53.00'), ('0', '28.00')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose', 'Age', 'Pregnancies', 'BloodPressure', 'Pregnancies']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_LTE_127.50) AND FEAT_1_LTE_38.35) AND FEAT_7_LTE_35.00) AND FEAT_0_GT_22.50) AND FEAT_2_GT_53.00) AND FEAT_1_LTE_37.15) AND FEAT_6_LTE_3.50) AND FEAT_0_LTE_24.50)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '38.35'), ('7', '35.00'), ('0', '22.50'), ('2', '53.00'), ('1', '37.15'), ('6', '3.50'), ('0', '24.50')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose', 'Age', 'Pregnancies', 'BloodPressure', 'Glucose', 'DiabetesPedigreeFunction', 'Pregnancies']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_LTE_127.50) AND FEAT_1_LTE_38.35) AND FEAT_7_LTE_35.00) AND FEAT_0_GT_22.50) AND FEAT_2_GT_53.00) AND FEAT_1_LTE_37.15) AND FEAT_6_LTE_3.50) AND FEAT_0_GT_24.50) AND FEAT_4_LTE_154.50) AND FEAT_7_LTE_18.00)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '38.35'), ('7', '35.00'), ('0', '22.50'), ('2', '53.00'), ('1', '37.15'), ('6', '3.50'), ('0', '24.50'), ('4', '154.50'), ('7', '18.00')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose', 'Age', 'Pregnancies', 'BloodPressure', 'Glucose', 'DiabetesPedigreeFunction', 'Pregnancies', 'Insulin', 'Age']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_LTE_127.50) AND FEAT_1_LTE_38.35) AND FEAT_7_LTE_35.00) AND FEAT_0_GT_22.50) AND FEAT_2_GT_53.00) AND FEAT_1_LTE_37.15) AND FEAT_6_LTE_3.50) AND FEAT_0_GT_24.50) AND FEAT_4_LTE_154.50) AND FEAT_7_GT_18.00) AND FEAT_3_LTE_0.73)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '38.35'), ('7', '35.00'), ('0', '22.50'), ('2', '53.00'), ('1', '37.15'), ('6', '3.50'), ('0', '24.50'), ('4', '154.50'), ('7', '18.00'), ('3', '0.73')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose', 'Age', 'Pregnancies', 'BloodPressure', 'Glucose', 'DiabetesPedigreeFunction', 'Pregnancies', 'Insulin', 'Age', 'SkinThickness']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_LTE_127.50) AND FEAT_1_LTE_38.35) AND FEAT_7_LTE_35.00) AND FEAT_0_GT_22.50) AND FEAT_2_GT_53.00) AND FEAT_1_LTE_37.15) AND FEAT_6_LTE_3.50) AND FEAT_0_GT_24.50) AND FEAT_4_LTE_154.50) AND FEAT_7_GT_18.00) AND FEAT_3_GT_0.73) AND FEAT_3_LTE_0.91)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '38.35'), ('7', '35.00'), ('0', '22.50'), ('2', '53.00'), ('1', '37.15'), ('6', '3.50'), ('0', '24.50'), ('4', '154.50'), ('7', '18.00'), ('3', '0.73'), ('3', '0.91')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose', 'Age', 'Pregnancies', 'BloodPressure', 'Glucose', 'DiabetesPedigreeFunction', 'Pregnancies', 'Insulin', 'Age', 'SkinThickness', 'SkinThickness']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_LTE_127.50) AND FEAT_1_LTE_38.35) AND FEAT_7_LTE_35.00) AND FEAT_0_GT_22.50) AND FEAT_2_GT_53.00) AND FEAT_1_LTE_37.15) AND FEAT_6_LTE_3.50) AND FEAT_0_GT_24.50) AND FEAT_4_LTE_154.50) AND FEAT_7_GT_18.00) AND FEAT_3_GT_0.73) AND FEAT_3_GT_0.91)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '38.35'), ('7', '35.00'), ('0', '22.50'), ('2', '53.00'), ('1', '37.15'), ('6', '3.50'), ('0', '24.50'), ('4', '154.50'), ('7', '18.00'), ('3', '0.73'), ('3', '0.91')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose', 'Age', 'Pregnancies', 'BloodPressure', 'Glucose', 'DiabetesPedigreeFunction', 'Pregnancies', 'Insulin', 'Age', 'SkinThickness', 'SkinThickness']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_LTE_127.50) AND FEAT_1_LTE_38.35) AND FEAT_7_LTE_35.00) AND FEAT_0_GT_22.50) AND FEAT_2_GT_53.00) AND FEAT_1_LTE_37.15) AND FEAT_6_LTE_3.50) AND FEAT_0_GT_24.50) AND FEAT_4_GT_154.50)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '38.35'), ('7', '35.00'), ('0', '22.50'), ('2', '53.00'), ('1', '37.15'), ('6', '3.50'), ('0', '24.50'), ('4', '154.50')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose', 'Age', 'Pregnancies', 'BloodPressure', 'Glucose', 'DiabetesPedigreeFunction', 'Pregnancies', 'Insulin']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_LTE_127.50) AND FEAT_1_LTE_38.35) AND FEAT_7_LTE_35.00) AND FEAT_0_GT_22.50) AND FEAT_2_GT_53.00) AND FEAT_1_LTE_37.15) AND FEAT_6_GT_3.50)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '38.35'), ('7', '35.00'), ('0', '22.50'), ('2', '53.00'), ('1', '37.15'), ('6', '3.50')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose', 'Age', 'Pregnancies', 'BloodPressure', 'Glucose', 'DiabetesPedigreeFunction']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_LTE_127.50) AND FEAT_1_LTE_38.35) AND FEAT_7_LTE_35.00) AND FEAT_0_GT_22.50) AND FEAT_2_GT_53.00) AND FEAT_1_GT_37.15) AND FEAT_2_LTE_78.50)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '38.35'), ('7', '35.00'), ('0', '22.50'), ('2', '53.00'), ('1', '37.15'), ('2', '78.50')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose', 'Age', 'Pregnancies', 'BloodPressure', 'Glucose', 'BloodPressure']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_LTE_127.50) AND FEAT_1_LTE_38.35) AND FEAT_7_LTE_35.00) AND FEAT_0_GT_22.50) AND FEAT_2_GT_53.00) AND FEAT_1_GT_37.15) AND FEAT_2_GT_78.50)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '38.35'), ('7', '35.00'), ('0', '22.50'), ('2', '53.00'), ('1', '37.15'), ('2', '78.50')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose', 'Age', 'Pregnancies', 'BloodPressure', 'Glucose', 'BloodPressure']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_LTE_127.50) AND FEAT_1_LTE_38.35) AND FEAT_7_GT_35.00) AND FEAT_1_LTE_37.95) AND FEAT_3_LTE_0.47) AND FEAT_5_LTE_22.50) AND FEAT_7_LTE_39.50)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '38.35'), ('7', '35.00'), ('1', '37.95'), ('3', '0.47'), ('5', '22.50'), ('7', '39.50')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose', 'Age', 'Glucose', 'SkinThickness', 'BMI', 'Age']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_LTE_127.50) AND FEAT_1_LTE_38.35) AND FEAT_7_GT_35.00) AND FEAT_1_LTE_37.95) AND FEAT_3_LTE_0.47) AND FEAT_5_LTE_22.50) AND FEAT_7_GT_39.50)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '38.35'), ('7', '35.00'), ('1', '37.95'), ('3', '0.47'), ('5', '22.50'), ('7', '39.50')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose', 'Age', 'Glucose', 'SkinThickness', 'BMI', 'Age']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_LTE_127.50) AND FEAT_1_LTE_38.35) AND FEAT_7_GT_35.00) AND FEAT_1_LTE_37.95) AND FEAT_3_LTE_0.47) AND FEAT_5_GT_22.50)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '38.35'), ('7', '35.00'), ('1', '37.95'), ('3', '0.47'), ('5', '22.50')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose', 'Age', 'Glucose', 'SkinThickness', 'BMI']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_LTE_127.50) AND FEAT_1_LTE_38.35) AND FEAT_7_GT_35.00) AND FEAT_1_LTE_37.95) AND FEAT_3_GT_0.47)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '38.35'), ('7', '35.00'), ('1', '37.95'), ('3', '0.47')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose', 'Age', 'Glucose', 'SkinThickness']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_LTE_127.50) AND FEAT_1_LTE_38.35) AND FEAT_7_GT_35.00) AND FEAT_1_GT_37.95)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '38.35'), ('7', '35.00'), ('1', '37.95')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose', 'Age', 'Glucose']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_LTE_127.50) AND FEAT_1_GT_38.35)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '38.35')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_GT_127.50) AND FEAT_1_LTE_36.75) AND FEAT_2_LTE_76.00) AND FEAT_2_LTE_71.00) AND FEAT_7_LTE_25.50)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '36.75'), ('2', '76.00'), ('2', '71.00'), ('7', '25.50')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose', 'BloodPressure', 'BloodPressure', 'Age']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_GT_127.50) AND FEAT_1_LTE_36.75) AND FEAT_2_LTE_76.00) AND FEAT_2_LTE_71.00) AND FEAT_7_GT_25.50)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '36.75'), ('2', '76.00'), ('2', '71.00'), ('7', '25.50')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose', 'BloodPressure', 'BloodPressure', 'Age']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_GT_127.50) AND FEAT_1_LTE_36.75) AND FEAT_2_LTE_76.00) AND FEAT_2_GT_71.00)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '36.75'), ('2', '76.00'), ('2', '71.00')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose', 'BloodPressure', 'BloodPressure']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_GT_127.50) AND FEAT_1_LTE_36.75) AND FEAT_2_GT_76.00)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '36.75'), ('2', '76.00')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose', 'BloodPressure']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_LTE_41.75) AND FEAT_5_GT_127.50) AND FEAT_1_GT_36.75)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('5', '127.50'), ('1', '36.75')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'BMI', 'Glucose']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_GT_41.75) AND FEAT_1_LTE_47.70) AND FEAT_1_LTE_42.65)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('1', '47.70'), ('1', '42.65')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'Glucose', 'Glucose']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_GT_41.75) AND FEAT_1_LTE_47.70) AND FEAT_1_GT_42.65) AND FEAT_3_LTE_0.68) AND FEAT_3_LTE_0.31) AND FEAT_5_LTE_26.50)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('1', '47.70'), ('1', '42.65'), ('3', '0.68'), ('3', '0.31'), ('5', '26.50')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'Glucose', 'Glucose', 'SkinThickness', 'SkinThickness', 'BMI']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_GT_41.75) AND FEAT_1_LTE_47.70) AND FEAT_1_GT_42.65) AND FEAT_3_LTE_0.68) AND FEAT_3_LTE_0.31) AND FEAT_5_GT_26.50) AND FEAT_1_LTE_45.35)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('1', '47.70'), ('1', '42.65'), ('3', '0.68'), ('3', '0.31'), ('5', '26.50'), ('1', '45.35')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'Glucose', 'Glucose', 'SkinThickness', 'SkinThickness', 'BMI', 'Glucose']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_GT_41.75) AND FEAT_1_LTE_47.70) AND FEAT_1_GT_42.65) AND FEAT_3_LTE_0.68) AND FEAT_3_LTE_0.31) AND FEAT_5_GT_26.50) AND FEAT_1_GT_45.35)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('1', '47.70'), ('1', '42.65'), ('3', '0.68'), ('3', '0.31'), ('5', '26.50'), ('1', '45.35')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'Glucose', 'Glucose', 'SkinThickness', 'SkinThickness', 'BMI', 'Glucose']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_GT_41.75) AND FEAT_1_LTE_47.70) AND FEAT_1_GT_42.65) AND FEAT_3_LTE_0.68) AND FEAT_3_GT_0.31)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('1', '47.70'), ('1', '42.65'), ('3', '0.68'), ('3', '0.31')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'Glucose', 'Glucose', 'SkinThickness', 'SkinThickness']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_GT_41.75) AND FEAT_1_LTE_47.70) AND FEAT_1_GT_42.65) AND FEAT_3_GT_0.68) AND FEAT_3_LTE_0.80)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('1', '47.70'), ('1', '42.65'), ('3', '0.68'), ('3', '0.80')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'Glucose', 'Glucose', 'SkinThickness', 'SkinThickness']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_GT_41.75) AND FEAT_1_LTE_47.70) AND FEAT_1_GT_42.65) AND FEAT_3_GT_0.68) AND FEAT_3_GT_0.80)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('1', '47.70'), ('1', '42.65'), ('3', '0.68'), ('3', '0.80')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'Glucose', 'Glucose', 'SkinThickness', 'SkinThickness']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_LTE_29.50) AND FEAT_1_GT_41.75) AND FEAT_1_GT_47.70)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('1', '41.75'), ('1', '47.70')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Glucose', 'Glucose']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_LTE_134.00) AND FEAT_2_LTE_77.00) AND FEAT_5_LTE_117.50) AND FEAT_4_LTE_111.50) AND FEAT_6_LTE_7.50) AND FEAT_4_LTE_94.50)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('2', '77.00'), ('5', '117.50'), ('4', '111.50'), ('6', '7.50'), ('4', '94.50')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'BloodPressure', 'BMI', 'Insulin', 'DiabetesPedigreeFunction', 'Insulin']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_LTE_134.00) AND FEAT_2_LTE_77.00) AND FEAT_5_LTE_117.50) AND FEAT_4_LTE_111.50) AND FEAT_6_LTE_7.50) AND FEAT_4_GT_94.50) AND FEAT_7_LTE_9.00)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('2', '77.00'), ('5', '117.50'), ('4', '111.50'), ('6', '7.50'), ('4', '94.50'), ('7', '9.00')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'BloodPressure', 'BMI', 'Insulin', 'DiabetesPedigreeFunction', 'Insulin', 'Age']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_LTE_134.00) AND FEAT_2_LTE_77.00) AND FEAT_5_LTE_117.50) AND FEAT_4_LTE_111.50) AND FEAT_6_LTE_7.50) AND FEAT_4_GT_94.50) AND FEAT_7_GT_9.00) AND FEAT_1_LTE_37.55)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('2', '77.00'), ('5', '117.50'), ('4', '111.50'), ('6', '7.50'), ('4', '94.50'), ('7', '9.00'), ('1', '37.55')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'BloodPressure', 'BMI', 'Insulin', 'DiabetesPedigreeFunction', 'Insulin', 'Age', 'Glucose']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_LTE_134.00) AND FEAT_2_LTE_77.00) AND FEAT_5_LTE_117.50) AND FEAT_4_LTE_111.50) AND FEAT_6_LTE_7.50) AND FEAT_4_GT_94.50) AND FEAT_7_GT_9.00) AND FEAT_1_GT_37.55)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('2', '77.00'), ('5', '117.50'), ('4', '111.50'), ('6', '7.50'), ('4', '94.50'), ('7', '9.00'), ('1', '37.55')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'BloodPressure', 'BMI', 'Insulin', 'DiabetesPedigreeFunction', 'Insulin', 'Age', 'Glucose']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_LTE_134.00) AND FEAT_2_LTE_77.00) AND FEAT_5_LTE_117.50) AND FEAT_4_LTE_111.50) AND FEAT_6_GT_7.50) AND FEAT_1_LTE_29.90)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('2', '77.00'), ('5', '117.50'), ('4', '111.50'), ('6', '7.50'), ('1', '29.90')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'BloodPressure', 'BMI', 'Insulin', 'DiabetesPedigreeFunction', 'Glucose']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_LTE_134.00) AND FEAT_2_LTE_77.00) AND FEAT_5_LTE_117.50) AND FEAT_4_LTE_111.50) AND FEAT_6_GT_7.50) AND FEAT_1_GT_29.90)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('2', '77.00'), ('5', '117.50'), ('4', '111.50'), ('6', '7.50'), ('1', '29.90')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'BloodPressure', 'BMI', 'Insulin', 'DiabetesPedigreeFunction', 'Glucose']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_LTE_134.00) AND FEAT_2_LTE_77.00) AND FEAT_5_LTE_117.50) AND FEAT_4_GT_111.50) AND FEAT_3_LTE_0.79) AND FEAT_1_LTE_37.40)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('2', '77.00'), ('5', '117.50'), ('4', '111.50'), ('3', '0.79'), ('1', '37.40')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'BloodPressure', 'BMI', 'Insulin', 'SkinThickness', 'Glucose']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_LTE_134.00) AND FEAT_2_LTE_77.00) AND FEAT_5_LTE_117.50) AND FEAT_4_GT_111.50) AND FEAT_3_LTE_0.79) AND FEAT_1_GT_37.40) AND FEAT_1_LTE_39.20)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('2', '77.00'), ('5', '117.50'), ('4', '111.50'), ('3', '0.79'), ('1', '37.40'), ('1', '39.20')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'BloodPressure', 'BMI', 'Insulin', 'SkinThickness', 'Glucose', 'Glucose']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_LTE_134.00) AND FEAT_2_LTE_77.00) AND FEAT_5_LTE_117.50) AND FEAT_4_GT_111.50) AND FEAT_3_LTE_0.79) AND FEAT_1_GT_37.40) AND FEAT_1_GT_39.20)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('2', '77.00'), ('5', '117.50'), ('4', '111.50'), ('3', '0.79'), ('1', '37.40'), ('1', '39.20')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'BloodPressure', 'BMI', 'Insulin', 'SkinThickness', 'Glucose', 'Glucose']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_LTE_134.00) AND FEAT_2_LTE_77.00) AND FEAT_5_LTE_117.50) AND FEAT_4_GT_111.50) AND FEAT_3_GT_0.79) AND FEAT_4_LTE_119.50)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('2', '77.00'), ('5', '117.50'), ('4', '111.50'), ('3', '0.79'), ('4', '119.50')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'BloodPressure', 'BMI', 'Insulin', 'SkinThickness', 'Insulin']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_LTE_134.00) AND FEAT_2_LTE_77.00) AND FEAT_5_LTE_117.50) AND FEAT_4_GT_111.50) AND FEAT_3_GT_0.79) AND FEAT_4_GT_119.50)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('2', '77.00'), ('5', '117.50'), ('4', '111.50'), ('3', '0.79'), ('4', '119.50')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'BloodPressure', 'BMI', 'Insulin', 'SkinThickness', 'Insulin']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_LTE_134.00) AND FEAT_2_LTE_77.00) AND FEAT_5_GT_117.50)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('2', '77.00'), ('5', '117.50')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'BloodPressure', 'BMI']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_LTE_134.00) AND FEAT_2_GT_77.00) AND FEAT_1_LTE_33.05) AND FEAT_2_LTE_83.00)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('2', '77.00'), ('1', '33.05'), ('2', '83.00')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'BloodPressure', 'Glucose', 'BloodPressure']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_LTE_134.00) AND FEAT_2_GT_77.00) AND FEAT_1_LTE_33.05) AND FEAT_2_GT_83.00)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('2', '77.00'), ('1', '33.05'), ('2', '83.00')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'BloodPressure', 'Glucose', 'BloodPressure']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_LTE_134.00) AND FEAT_2_GT_77.00) AND FEAT_1_GT_33.05) AND FEAT_7_LTE_30.50) AND FEAT_4_LTE_125.50)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('2', '77.00'), ('1', '33.05'), ('7', '30.50'), ('4', '125.50')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'BloodPressure', 'Glucose', 'Age', 'Insulin']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_LTE_134.00) AND FEAT_2_GT_77.00) AND FEAT_1_GT_33.05) AND FEAT_7_LTE_30.50) AND FEAT_4_GT_125.50) AND FEAT_1_LTE_41.80)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('2', '77.00'), ('1', '33.05'), ('7', '30.50'), ('4', '125.50'), ('1', '41.80')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'BloodPressure', 'Glucose', 'Age', 'Insulin', 'Glucose']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_LTE_134.00) AND FEAT_2_GT_77.00) AND FEAT_1_GT_33.05) AND FEAT_7_LTE_30.50) AND FEAT_4_GT_125.50) AND FEAT_1_GT_41.80)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('2', '77.00'), ('1', '33.05'), ('7', '30.50'), ('4', '125.50'), ('1', '41.80')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'BloodPressure', 'Glucose', 'Age', 'Insulin', 'Glucose']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_LTE_134.00) AND FEAT_2_GT_77.00) AND FEAT_1_GT_33.05) AND FEAT_7_GT_30.50)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('2', '77.00'), ('1', '33.05'), ('7', '30.50')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'BloodPressure', 'Glucose', 'Age']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_GT_134.00) AND FEAT_3_LTE_1.34) AND FEAT_1_LTE_31.05) AND FEAT_7_LTE_7.50)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('3', '1.34'), ('1', '31.05'), ('7', '7.50')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'SkinThickness', 'Glucose', 'Age']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_GT_134.00) AND FEAT_3_LTE_1.34) AND FEAT_1_LTE_31.05) AND FEAT_7_GT_7.50) AND FEAT_3_LTE_0.22)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('3', '1.34'), ('1', '31.05'), ('7', '7.50'), ('3', '0.22')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'SkinThickness', 'Glucose', 'Age', 'SkinThickness']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_GT_134.00) AND FEAT_3_LTE_1.34) AND FEAT_1_LTE_31.05) AND FEAT_7_GT_7.50) AND FEAT_3_GT_0.22) AND FEAT_7_LTE_17.00) AND FEAT_3_LTE_0.76)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('3', '1.34'), ('1', '31.05'), ('7', '7.50'), ('3', '0.22'), ('7', '17.00'), ('3', '0.76')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'SkinThickness', 'Glucose', 'Age', 'SkinThickness', 'Age', 'SkinThickness']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_GT_134.00) AND FEAT_3_LTE_1.34) AND FEAT_1_LTE_31.05) AND FEAT_7_GT_7.50) AND FEAT_3_GT_0.22) AND FEAT_7_LTE_17.00) AND FEAT_3_GT_0.76)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('3', '1.34'), ('1', '31.05'), ('7', '7.50'), ('3', '0.22'), ('7', '17.00'), ('3', '0.76')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'SkinThickness', 'Glucose', 'Age', 'SkinThickness', 'Age', 'SkinThickness']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_GT_134.00) AND FEAT_3_LTE_1.34) AND FEAT_1_LTE_31.05) AND FEAT_7_GT_7.50) AND FEAT_3_GT_0.22) AND FEAT_7_GT_17.00)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('3', '1.34'), ('1', '31.05'), ('7', '7.50'), ('3', '0.22'), ('7', '17.00')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'SkinThickness', 'Glucose', 'Age', 'SkinThickness', 'Age']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_GT_134.00) AND FEAT_3_LTE_1.34) AND FEAT_1_GT_31.05) AND FEAT_1_LTE_33.05)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('3', '1.34'), ('1', '31.05'), ('1', '33.05')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'SkinThickness', 'Glucose', 'Glucose']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_GT_134.00) AND FEAT_3_LTE_1.34) AND FEAT_1_GT_31.05) AND FEAT_1_GT_33.05) AND FEAT_1_LTE_33.40)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('3', '1.34'), ('1', '31.05'), ('1', '33.05'), ('1', '33.40')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'SkinThickness', 'Glucose', 'Glucose', 'Glucose']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_GT_134.00) AND FEAT_3_LTE_1.34) AND FEAT_1_GT_31.05) AND FEAT_1_GT_33.05) AND FEAT_1_GT_33.40) AND FEAT_2_LTE_80.00) AND FEAT_6_LTE_4.50)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('3', '1.34'), ('1', '31.05'), ('1', '33.05'), ('1', '33.40'), ('2', '80.00'), ('6', '4.50')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'SkinThickness', 'Glucose', 'Glucose', 'Glucose', 'BloodPressure', 'DiabetesPedigreeFunction']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_GT_134.00) AND FEAT_3_LTE_1.34) AND FEAT_1_GT_31.05) AND FEAT_1_GT_33.05) AND FEAT_1_GT_33.40) AND FEAT_2_LTE_80.00) AND FEAT_6_GT_4.50) AND FEAT_3_LTE_0.21) AND FEAT_0_LTE_39.00)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('3', '1.34'), ('1', '31.05'), ('1', '33.05'), ('1', '33.40'), ('2', '80.00'), ('6', '4.50'), ('3', '0.21'), ('0', '39.00')]
# Matching Features: ['Glucose', 'BMI', 'Pregnancies', 'Age', 'Insulin', 'SkinThickness', 'Glucose', 'Glucose', 'Glucose', 'BloodPressure', 'DiabetesPedigreeFunction', 'SkinThickness', 'Pregnancies']
# Rule: FEAT_1_GT_29.65) AND FEAT_5_LTE_143.00) AND FEAT_0_GT_29.50) AND FEAT_7_LTE_32.50) AND FEAT_4_GT_134.00) AND FEAT_3_LTE_1.34) AND FEAT_1_GT_31.05) AND FEAT_1_GT_33.05) AND FEAT_1_GT_33.40) AND FEAT_2_LTE_80.00) AND FEAT_6_GT_4.50) AND FEAT_3_LTE_0.21) AND FEAT_0_GT_39.00) AND FEAT_5_LTE_55.00) AND FEAT_1_LTE_39.95)
# Extracted Conditions: [('1', '29.65'), ('5', '143.00'), ('0', '29.50'), ('7', '32.50'), ('4', '134.00'), ('3', '1.34'), ('1', '31.05'), ('1', '33.05'), ('1', '33.40'), ('2', '80.00'), ('6', '4.50'), ('3', '0.21'), ('0', '39.00'), ('5', '55.00'), ('1', '39.95')]
# ...
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Insulin', 'Insulin', 'Glucose', 'Insulin', 'Glucose', 'BMI', 'SkinThickness', 'Age']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_LTE_6.50) AND FEAT_4_GT_130.50) AND FEAT_4_LTE_166.50) AND FEAT_4_LTE_163.50) AND FEAT_1_GT_31.40) AND FEAT_4_LTE_154.50) AND FEAT_1_GT_32.00) AND FEAT_5_GT_187.00) AND FEAT_3_GT_0.25)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '130.50'), ('4', '166.50'), ('4', '163.50'), ('1', '31.40'), ('4', '154.50'), ('1', '32.00'), ('5', '187.00'), ('3', '0.25')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Insulin', 'Insulin', 'Glucose', 'Insulin', 'Glucose', 'BMI', 'SkinThickness']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_LTE_6.50) AND FEAT_4_GT_130.50) AND FEAT_4_LTE_166.50) AND FEAT_4_LTE_163.50) AND FEAT_1_GT_31.40) AND FEAT_4_GT_154.50)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '130.50'), ('4', '166.50'), ('4', '163.50'), ('1', '31.40'), ('4', '154.50')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Insulin', 'Insulin', 'Glucose', 'Insulin']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_LTE_6.50) AND FEAT_4_GT_130.50) AND FEAT_4_LTE_166.50) AND FEAT_4_GT_163.50)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '130.50'), ('4', '166.50'), ('4', '163.50')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Insulin', 'Insulin']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_LTE_6.50) AND FEAT_4_GT_130.50) AND FEAT_4_GT_166.50) AND FEAT_3_LTE_1.16) AND FEAT_2_LTE_101.00)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '130.50'), ('4', '166.50'), ('3', '1.16'), ('2', '101.00')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Insulin', 'SkinThickness', 'BloodPressure']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_LTE_6.50) AND FEAT_4_GT_130.50) AND FEAT_4_GT_166.50) AND FEAT_3_LTE_1.16) AND FEAT_2_GT_101.00)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '130.50'), ('4', '166.50'), ('3', '1.16'), ('2', '101.00')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Insulin', 'SkinThickness', 'BloodPressure']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_LTE_6.50) AND FEAT_4_GT_130.50) AND FEAT_4_GT_166.50) AND FEAT_3_GT_1.16) AND FEAT_7_LTE_40.50) AND FEAT_0_LTE_28.00)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '130.50'), ('4', '166.50'), ('3', '1.16'), ('7', '40.50'), ('0', '28.00')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Insulin', 'SkinThickness', 'Age', 'Pregnancies']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_LTE_6.50) AND FEAT_4_GT_130.50) AND FEAT_4_GT_166.50) AND FEAT_3_GT_1.16) AND FEAT_7_LTE_40.50) AND FEAT_0_GT_28.00)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '130.50'), ('4', '166.50'), ('3', '1.16'), ('7', '40.50'), ('0', '28.00')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Insulin', 'SkinThickness', 'Age', 'Pregnancies']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_LTE_6.50) AND FEAT_4_GT_130.50) AND FEAT_4_GT_166.50) AND FEAT_3_GT_1.16) AND FEAT_7_GT_40.50)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '130.50'), ('4', '166.50'), ('3', '1.16'), ('7', '40.50')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Insulin', 'SkinThickness', 'Age']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_LTE_142.50) AND FEAT_7_LTE_39.50) AND FEAT_1_LTE_28.75) AND FEAT_7_LTE_29.00)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('7', '39.50'), ('1', '28.75'), ('7', '29.00')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Age', 'Glucose', 'Age']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_LTE_142.50) AND FEAT_7_LTE_39.50) AND FEAT_1_LTE_28.75) AND FEAT_7_GT_29.00) AND FEAT_1_LTE_27.75)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('7', '39.50'), ('1', '28.75'), ('7', '29.00'), ('1', '27.75')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Age', 'Glucose', 'Age', 'Glucose']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_LTE_142.50) AND FEAT_7_LTE_39.50) AND FEAT_1_LTE_28.75) AND FEAT_7_GT_29.00) AND FEAT_1_GT_27.75)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('7', '39.50'), ('1', '28.75'), ('7', '29.00'), ('1', '27.75')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Age', 'Glucose', 'Age', 'Glucose']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_LTE_142.50) AND FEAT_7_LTE_39.50) AND FEAT_1_GT_28.75) AND FEAT_6_LTE_7.50) AND FEAT_3_LTE_0.26) AND FEAT_1_LTE_30.15)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('7', '39.50'), ('1', '28.75'), ('6', '7.50'), ('3', '0.26'), ('1', '30.15')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Age', 'Glucose', 'DiabetesPedigreeFunction', 'SkinThickness', 'Glucose']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_LTE_142.50) AND FEAT_7_LTE_39.50) AND FEAT_1_GT_28.75) AND FEAT_6_LTE_7.50) AND FEAT_3_LTE_0.26) AND FEAT_1_GT_30.15)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('7', '39.50'), ('1', '28.75'), ('6', '7.50'), ('3', '0.26'), ('1', '30.15')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Age', 'Glucose', 'DiabetesPedigreeFunction', 'SkinThickness', 'Glucose']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_LTE_142.50) AND FEAT_7_LTE_39.50) AND FEAT_1_GT_28.75) AND FEAT_6_LTE_7.50) AND FEAT_3_GT_0.26) AND FEAT_4_LTE_95.50)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('7', '39.50'), ('1', '28.75'), ('6', '7.50'), ('3', '0.26'), ('4', '95.50')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Age', 'Glucose', 'DiabetesPedigreeFunction', 'SkinThickness', 'Insulin']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_LTE_142.50) AND FEAT_7_LTE_39.50) AND FEAT_1_GT_28.75) AND FEAT_6_LTE_7.50) AND FEAT_3_GT_0.26) AND FEAT_4_GT_95.50) AND FEAT_4_LTE_112.50)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('7', '39.50'), ('1', '28.75'), ('6', '7.50'), ('3', '0.26'), ('4', '95.50'), ('4', '112.50')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Age', 'Glucose', 'DiabetesPedigreeFunction', 'SkinThickness', 'Insulin', 'Insulin']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_LTE_142.50) AND FEAT_7_LTE_39.50) AND FEAT_1_GT_28.75) AND FEAT_6_LTE_7.50) AND FEAT_3_GT_0.26) AND FEAT_4_GT_95.50) AND FEAT_4_GT_112.50)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('7', '39.50'), ('1', '28.75'), ('6', '7.50'), ('3', '0.26'), ('4', '95.50'), ('4', '112.50')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Age', 'Glucose', 'DiabetesPedigreeFunction', 'SkinThickness', 'Insulin', 'Insulin']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_LTE_142.50) AND FEAT_7_LTE_39.50) AND FEAT_1_GT_28.75) AND FEAT_6_GT_7.50) AND FEAT_1_LTE_39.45) AND FEAT_3_LTE_0.46) AND FEAT_6_LTE_13.50) AND FEAT_0_LTE_35.50)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('7', '39.50'), ('1', '28.75'), ('6', '7.50'), ('1', '39.45'), ('3', '0.46'), ('6', '13.50'), ('0', '35.50')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Age', 'Glucose', 'DiabetesPedigreeFunction', 'Glucose', 'SkinThickness', 'DiabetesPedigreeFunction', 'Pregnancies']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_LTE_142.50) AND FEAT_7_LTE_39.50) AND FEAT_1_GT_28.75) AND FEAT_6_GT_7.50) AND FEAT_1_LTE_39.45) AND FEAT_3_LTE_0.46) AND FEAT_6_LTE_13.50) AND FEAT_0_GT_35.50) AND FEAT_0_LTE_37.00)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('7', '39.50'), ('1', '28.75'), ('6', '7.50'), ('1', '39.45'), ('3', '0.46'), ('6', '13.50'), ('0', '35.50'), ('0', '37.00')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Age', 'Glucose', 'DiabetesPedigreeFunction', 'Glucose', 'SkinThickness', 'DiabetesPedigreeFunction', 'Pregnancies', 'Pregnancies']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_LTE_142.50) AND FEAT_7_LTE_39.50) AND FEAT_1_GT_28.75) AND FEAT_6_GT_7.50) AND FEAT_1_LTE_39.45) AND FEAT_3_LTE_0.46) AND FEAT_6_LTE_13.50) AND FEAT_0_GT_35.50) AND FEAT_0_GT_37.00) AND FEAT_4_LTE_130.00) AND FEAT_2_LTE_73.00) AND FEAT_2_LTE_63.00)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('7', '39.50'), ('1', '28.75'), ('6', '7.50'), ('1', '39.45'), ('3', '0.46'), ('6', '13.50'), ('0', '35.50'), ('0', '37.00'), ('4', '130.00'), ('2', '73.00'), ('2', '63.00')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Age', 'Glucose', 'DiabetesPedigreeFunction', 'Glucose', 'SkinThickness', 'DiabetesPedigreeFunction', 'Pregnancies', 'Pregnancies', 'Insulin', 'BloodPressure', 'BloodPressure']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_LTE_142.50) AND FEAT_7_LTE_39.50) AND FEAT_1_GT_28.75) AND FEAT_6_GT_7.50) AND FEAT_1_LTE_39.45) AND FEAT_3_LTE_0.46) AND FEAT_6_LTE_13.50) AND FEAT_0_GT_35.50) AND FEAT_0_GT_37.00) AND FEAT_4_LTE_130.00) AND FEAT_2_LTE_73.00) AND FEAT_2_GT_63.00)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('7', '39.50'), ('1', '28.75'), ('6', '7.50'), ('1', '39.45'), ('3', '0.46'), ('6', '13.50'), ('0', '35.50'), ('0', '37.00'), ('4', '130.00'), ('2', '73.00'), ('2', '63.00')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Age', 'Glucose', 'DiabetesPedigreeFunction', 'Glucose', 'SkinThickness', 'DiabetesPedigreeFunction', 'Pregnancies', 'Pregnancies', 'Insulin', 'BloodPressure', 'BloodPressure']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_LTE_142.50) AND FEAT_7_LTE_39.50) AND FEAT_1_GT_28.75) AND FEAT_6_GT_7.50) AND FEAT_1_LTE_39.45) AND FEAT_3_LTE_0.46) AND FEAT_6_LTE_13.50) AND FEAT_0_GT_35.50) AND FEAT_0_GT_37.00) AND FEAT_4_LTE_130.00) AND FEAT_2_GT_73.00)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('7', '39.50'), ('1', '28.75'), ('6', '7.50'), ('1', '39.45'), ('3', '0.46'), ('6', '13.50'), ('0', '35.50'), ('0', '37.00'), ('4', '130.00'), ('2', '73.00')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Age', 'Glucose', 'DiabetesPedigreeFunction', 'Glucose', 'SkinThickness', 'DiabetesPedigreeFunction', 'Pregnancies', 'Pregnancies', 'Insulin', 'BloodPressure']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_LTE_142.50) AND FEAT_7_LTE_39.50) AND FEAT_1_GT_28.75) AND FEAT_6_GT_7.50) AND FEAT_1_LTE_39.45) AND FEAT_3_LTE_0.46) AND FEAT_6_LTE_13.50) AND FEAT_0_GT_35.50) AND FEAT_0_GT_37.00) AND FEAT_4_GT_130.00)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('7', '39.50'), ('1', '28.75'), ('6', '7.50'), ('1', '39.45'), ('3', '0.46'), ('6', '13.50'), ('0', '35.50'), ('0', '37.00'), ('4', '130.00')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Age', 'Glucose', 'DiabetesPedigreeFunction', 'Glucose', 'SkinThickness', 'DiabetesPedigreeFunction', 'Pregnancies', 'Pregnancies', 'Insulin']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_LTE_142.50) AND FEAT_7_LTE_39.50) AND FEAT_1_GT_28.75) AND FEAT_6_GT_7.50) AND FEAT_1_LTE_39.45) AND FEAT_3_LTE_0.46) AND FEAT_6_GT_13.50)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('7', '39.50'), ('1', '28.75'), ('6', '7.50'), ('1', '39.45'), ('3', '0.46'), ('6', '13.50')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Age', 'Glucose', 'DiabetesPedigreeFunction', 'Glucose', 'SkinThickness', 'DiabetesPedigreeFunction']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_LTE_142.50) AND FEAT_7_LTE_39.50) AND FEAT_1_GT_28.75) AND FEAT_6_GT_7.50) AND FEAT_1_LTE_39.45) AND FEAT_3_GT_0.46) AND FEAT_4_LTE_102.00) AND FEAT_2_LTE_84.50)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('7', '39.50'), ('1', '28.75'), ('6', '7.50'), ('1', '39.45'), ('3', '0.46'), ('4', '102.00'), ('2', '84.50')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Age', 'Glucose', 'DiabetesPedigreeFunction', 'Glucose', 'SkinThickness', 'Insulin', 'BloodPressure']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_LTE_142.50) AND FEAT_7_LTE_39.50) AND FEAT_1_GT_28.75) AND FEAT_6_GT_7.50) AND FEAT_1_LTE_39.45) AND FEAT_3_GT_0.46) AND FEAT_4_LTE_102.00) AND FEAT_2_GT_84.50)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('7', '39.50'), ('1', '28.75'), ('6', '7.50'), ('1', '39.45'), ('3', '0.46'), ('4', '102.00'), ('2', '84.50')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Age', 'Glucose', 'DiabetesPedigreeFunction', 'Glucose', 'SkinThickness', 'Insulin', 'BloodPressure']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_LTE_142.50) AND FEAT_7_LTE_39.50) AND FEAT_1_GT_28.75) AND FEAT_6_GT_7.50) AND FEAT_1_LTE_39.45) AND FEAT_3_GT_0.46) AND FEAT_4_GT_102.00)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('7', '39.50'), ('1', '28.75'), ('6', '7.50'), ('1', '39.45'), ('3', '0.46'), ('4', '102.00')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Age', 'Glucose', 'DiabetesPedigreeFunction', 'Glucose', 'SkinThickness', 'Insulin']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_LTE_142.50) AND FEAT_7_LTE_39.50) AND FEAT_1_GT_28.75) AND FEAT_6_GT_7.50) AND FEAT_1_GT_39.45)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('7', '39.50'), ('1', '28.75'), ('6', '7.50'), ('1', '39.45')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Age', 'Glucose', 'DiabetesPedigreeFunction', 'Glucose']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_LTE_142.50) AND FEAT_7_GT_39.50) AND FEAT_0_LTE_53.00)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('7', '39.50'), ('0', '53.00')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Age', 'Pregnancies']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_LTE_142.50) AND FEAT_7_GT_39.50) AND FEAT_0_GT_53.00) AND FEAT_4_LTE_120.50)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('7', '39.50'), ('0', '53.00'), ('4', '120.50')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Age', 'Pregnancies', 'Insulin']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_LTE_142.50) AND FEAT_7_GT_39.50) AND FEAT_0_GT_53.00) AND FEAT_4_GT_120.50)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('7', '39.50'), ('0', '53.00'), ('4', '120.50')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'Age', 'Pregnancies', 'Insulin']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_GT_142.50) AND FEAT_3_LTE_0.21) AND FEAT_7_LTE_15.00) AND FEAT_0_LTE_39.00)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('3', '0.21'), ('7', '15.00'), ('0', '39.00')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'SkinThickness', 'Age', 'Pregnancies']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_GT_142.50) AND FEAT_3_LTE_0.21) AND FEAT_7_LTE_15.00) AND FEAT_0_GT_39.00)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('3', '0.21'), ('7', '15.00'), ('0', '39.00')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'SkinThickness', 'Age', 'Pregnancies']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_GT_142.50) AND FEAT_3_LTE_0.21) AND FEAT_7_GT_15.00)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('3', '0.21'), ('7', '15.00')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'SkinThickness', 'Age']
# Rule: FEAT_1_GT_27.35) AND FEAT_6_GT_6.50) AND FEAT_4_GT_142.50) AND FEAT_3_GT_0.21)
# Extracted Conditions: [('1', '27.35'), ('6', '6.50'), ('4', '142.50'), ('3', '0.21')]
# Matching Features: ['Glucose', 'DiabetesPedigreeFunction', 'Insulin', 'SkinThickness']

# %% [markdown]
# ### MILP Optimization of the Surrogate Interpretable Graph of the RF Classifier

# %% [markdown]
# ##### Simple Linear Optimizer

# %%
import networkx as nx
import matplotlib.pyplot as plt
from pulp import LpProblem, LpMaximize, LpVariable, lpSum, LpStatus

# 1. Mapping from encoded feature names to actual feature names
feature_mapping = {f"FEAT_{i}": feature for i, feature in enumerate(X.columns)}

# 2. Define edge weights (using previous code)
edge_weights = {}

# Debug: Check rule extraction and feature matching
for rule_text in encoded_rules:
    # Extract the features and thresholds
    conditions = re.findall(r'FEAT_(\d+)_\w+_([\d\.]+)', rule_text)
    
    # Map FEAT_0, FEAT_1, ... back to actual feature names in the dataset
    features_in_rule = [feature_mapping[f"FEAT_{cond[0]}"] for cond in conditions if f"FEAT_{cond[0]}" in feature_mapping]

    # If features are valid, build the edges
    if len(features_in_rule) > 1:
        for i in range(len(features_in_rule) - 1):
            edge = (features_in_rule[i], features_in_rule[i+1])
            edge_weights[edge] = edge_weights.get(edge, 0) + 1

# 3. Define maximum number of edges to select (surrogate graph size)
max_edges = 15

# 4. Create MILP problem: maximize sum of weights of selected edges subject to selecting <= max_edges.
prob = LpProblem("Surrogate_Graph_Selection", LpMaximize)

# 5. Create a binary variable for each edge in edge_dict
edge_vars = {edge: LpVariable(f"edge_{edge[0]}_{edge[1]}", cat='Binary')
             for edge in edge_weights.keys()}

# 6. Objective: maximize total weight of selected edges
prob += lpSum([edge_weights[edge] * edge_vars[edge] for edge in edge_vars]), "Total_Weight"

# 7. Constraint: number of selected edges <= max_edges
prob += lpSum([edge_vars[edge] for edge in edge_vars]) <= max_edges, "EdgeCountConstraint"

# 8. Solve the MILP problem
prob.solve()

print("MILP Status:", LpStatus[prob.status])

# 9. Extract selected edges from the MILP solution
# 9. Extract selected edges from the MILP solution
selected_edges = [edge for edge in edge_vars if edge_vars[edge].value() == 1]
print("Selected edges for surrogate graph:", selected_edges)


# 10. Build surrogate graph from selected edges
G_surrogate = nx.DiGraph()
for edge in selected_edges:
    G_surrogate.add_edge(edge[0], edge[1], weight=edge_weights[edge])

# 11. Visualize the surrogate graph
plt.figure(figsize=(15, 15))
pos = nx.circular_layout(G_surrogate)
edge_labels = nx.get_edge_attributes(G_surrogate, 'weight')
nx.draw(G_surrogate, pos, with_labels=True, node_size=21000, node_color="lightgreen", arrowsize=20)
nx.draw_networkx_edge_labels(G_surrogate, pos, edge_labels=edge_labels)
plt.title("Surrogate Interpretable Graph")
plt.show()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/DubeyA-Dev/miniconda3/envs/taylor/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/tk/qh_5gfz51996p7zxwjyl8r140000gp/T/c14301fe2d3a44edbd7098aed873a999-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/tk/qh_5gfz51996p7zxwjyl8r140000gp/T/c14301fe2d3a44edbd7098aed873a999-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 6 COLUMNS
# At line 263 RHS
# At line 265 BOUNDS
# At line 330 ENDATA
# Problem MODEL has 1 rows, 64 columns and 64 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 4412 - 0.00 seconds
# Cgl0004I processed model has 1 rows, 64 columns (64 integer (64 of which binary)) and 64 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -4412
# Cbc0038I Before mini branch and bound, 64 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -4412 - took 0.00 seconds
# Cbc0012I Integer solution of -4412 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -4412, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -4412 to -4412
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4412.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# MILP Status: Optimal
# Selected edges for surrogate graph: [('Glucose', 'BMI'), ('BMI', 'Insulin'), ('Insulin', 'Glucose'), ('Glucose', 'Insulin'), ('DiabetesPedigreeFunction', 'Glucose'), ('Glucose', 'SkinThickness'), ('Insulin', 'SkinThickness'), ('Pregnancies', 'Glucose'), ('Insulin', 'Age'), ('Glucose', 'BloodPressure'), ('DiabetesPedigreeFunction', 'Insulin'), ('SkinThickness', 'Glucose'), ('SkinThickness', 'Pregnancies'), ('Pregnancies', 'BMI'), ('Pregnancies', 'SkinThickness')]

# %% [markdown]
# ## The surrogate interpretable graph also analyzes the co-occurence of a feature during a decision and whether that feature can occur without the other or not. This is very difficult to analyze through traditional methods of interpretability of random forest models.
#
# ### How the subset of the features are important for arriving at a decision. Analyze two-way/single-way arrows for decision process

# %% [markdown]
# ## Analyzing conuterfactual for each of the tree within the search limit parameters

# %% [markdown]
# ## Counterfactual for each tree (aggregate analysis) of the RF Classifier

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.inspection import DecisionBoundaryDisplay

def ensemble_counterfactual_analysis(instance, rf_model, feature_names, 
                                    step=0.5, max_iter=500, target_class=None):
    """
    Advanced counterfactual analysis across Random Forest subtrees
    Returns:
    - (dict) Aggregate counterfactual statistics per feature
    - (dict) Individual tree counterfactual data
    - (matplotlib.figure) Visualizations
    """
    # Initialize data structures
    n_trees = len(rf_model.estimators_)
    n_features = len(feature_names)
    tree_data = []
    aggregate_results = {feat: {'deltas': [], 'success_rate': 0} 
                        for feat in feature_names}
    
    # Create progress bar for tree analysis
    with tqdm(total=n_trees, desc="Analyzing Subtrees") as pbar:
        for tree_idx, tree in enumerate(rf_model.estimators_):
            # Get original prediction from this subtree
            orig_pred = tree.predict(instance.reshape(1, -1))[0]
            target = 1 - orig_pred if target_class is None else target_class
            
            tree_results = {}
            
            # Analyze each feature
            for feat_idx, feat_name in enumerate(feature_names):
                found_cf = False
                # Try both perturbation directions
                for direction in [-1, 1]:
                    perturbed = instance.copy()
                    for i in range(max_iter):
                        perturbed[feat_idx] += direction * step * (i+1)
                        new_pred = tree.predict(perturbed.reshape(1, -1))[0]
                        if new_pred == target:
                            tree_results[feat_name] = {
                                'delta': direction * step * (i+1),
                                'iterations': i+1,
                                'direction': 'decrease' if direction == -1 else 'increase'
                            }
                            aggregate_results[feat_name]['deltas'].append(direction * step * (i+1))
                            found_cf = True
                            break
                    if found_cf:
                        break
                if not found_cf:
                    tree_results[feat_name] = {'delta': np.nan, 'iterations': max_iter}
            
            tree_data.append(tree_results)
            pbar.update(1)
    
    # Calculate success rates
    for feat in aggregate_results:
        successes = len([d for d in aggregate_results[feat]['deltas'] if not np.isnan(d)])
        aggregate_results[feat]['success_rate'] = successes / n_trees
    
    # Generate visualizations
    plt.figure(figsize=(30, 28))
    
    # 1. Feature Importance Heatmap
    plt.subplot(2, 2, 1)
    success_rates = [aggregate_results[feat]['success_rate'] for feat in feature_names]
    plt.imshow(np.array(success_rates).reshape(1, -1), cmap='viridis', aspect='auto')
    plt.colorbar(label='Success Rate')
    plt.yticks([])
    plt.xticks(np.arange(len(feature_names)), feature_names, rotation=90)
    plt.title('Counterfactual Success Rate Across Trees')
    
    # 2. Delta Distribution Swarm Plot
    plt.subplot(2, 2, 2)
    all_deltas = []
    for feat in feature_names:
        deltas = [d for d in aggregate_results[feat]['deltas'] if not np.isnan(d)]
        jitter = np.random.normal(loc=0, scale=0.1, size=len(deltas))
        plt.scatter(np.arange(len(deltas)) + jitter, deltas, 
                    alpha=0.3, label=feat)
    plt.axhline(0, color='gray', linestyle='--')
    plt.ylabel('Required Delta')
    plt.xlabel('Feature Index')
    plt.title('Perturbation Magnitude Distribution')
    
    # 3. Direction Consistency Plot
    plt.subplot(2, 2, 3)
    direction_counts = {feat: {'increase': 0, 'decrease': 0} 
                       for feat in feature_names}
    for tree in tree_data:
        for feat, res in tree.items():
            if 'direction' in res:
                direction_counts[feat][res['direction']] += 1
                
    width = 0.4
    for idx, feat in enumerate(feature_names):
        plt.bar(idx - width/2, direction_counts[feat]['increase'], 
               width=width, color='green')
        plt.bar(idx + width/2, direction_counts[feat]['decrease'], 
               width=width, color='red')
    plt.xticks(np.arange(len(feature_names)), feature_names, rotation=90)
    plt.ylabel('Count')
    plt.title('Direction Consistency Across Trees')
    plt.legend(['Increase', 'Decrease'])
    
    # 4. Decision Boundary Projection
    plt.subplot(2, 2, 4)
    top_feature = sorted(feature_names, 
                        key=lambda x: aggregate_results[x]['success_rate'])[-1]
    feat_idx = feature_names.index(top_feature)
    
    # Generate probability curve for top feature
    feat_values = np.linspace(instance[feat_idx] - 3*step*max_iter,
                            instance[feat_idx] + 3*step*max_iter, 100)
    probabilities = []
    
    for val in feat_values:
        modified = instance.copy()
        modified[feat_idx] = val
        # Get average probability across all trees
        avg_prob = np.mean([tree.predict_proba(modified.reshape(1, -1))[0][target_class] 
                          for tree in rf_model.estimators_])
        probabilities.append(avg_prob)
    
    plt.plot(feat_values, probabilities, color='navy', lw=2)
    plt.axvline(instance[feat_idx], color='red', linestyle='--', label='Original Value')
    plt.axhline(0.5, color='gray', linestyle=':', label='Decision Threshold')
    plt.xlabel(top_feature)
    plt.ylabel('Average Class Probability')
    plt.title(f'Probability Landscape for {top_feature}')
    plt.legend()
    
    plt.tight_layout()
    return aggregate_results, tree_data

# %% [markdown]
# #### This also enables directional consistency evaluations

# %%
# First get the global target class
instance = X.iloc[5].values
forest_pred = rf.predict(instance.reshape(1, -1))[0]
target_class = 1 - forest_pred  # Flip the prediction

agg_results, tree_data = ensemble_counterfactual_analysis(
    instance=instance,
    rf_model=rf,
    feature_names=list(X.columns),
    step=0.2,
    max_iter=50,
    target_class=target_class  # Explicit target class
)
# Out:
# /Users/DubeyA-Dev/miniconda3/envs/taylor/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Analyzing Subtrees: 100%|██████████| 10/10 [00:00<00:00, 23.77it/s]

# %% [markdown]
# ## SHAP feature contribution

# %% [markdown]
# ![image.png](attachment:image.png)
