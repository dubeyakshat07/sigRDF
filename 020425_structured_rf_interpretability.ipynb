# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import networkx as nx
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import _tree
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import AgglomerativeClustering
import plotly.express as px
from pulp import LpProblem, LpVariable, LpMaximize, lpSum, LpStatus, value
from sklearn.decomposition import PCA

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.tree import plot_tree

# Load the breast cancer dataset
data = load_breast_cancer()
X = data.data
y = data.target
feature_names = data.feature_names
target_names = data.target_names

X = pd.DataFrame(X, columns = feature_names)
# Train RandomForestClassifier
rf = RandomForestClassifier(n_estimators=10, random_state=42)
rf.fit(X, y)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=42)

# %% [markdown]
# ## Calculating feature usage in decision paths and feature importance based on impurity reduction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import plot_tree

def get_decision_paths(model, X):
    decision_paths = []
    
    # Iterate over each tree in the forest
    for tree in model.estimators_:
        tree_paths = extract_tree_paths(tree, X)
        decision_paths.append(tree_paths)
    
    return decision_paths

def extract_tree_paths(tree, X):
    # Get the decision tree structure
    children_left = tree.tree_.children_left
    children_right = tree.tree_.children_right
    feature = tree.tree_.feature
    threshold = tree.tree_.threshold
    value = tree.tree_.value
    
    paths = []
    
    # For each sample in X, trace the path from root to leaf
    for _, sample in X.iterrows():
        path = []
        node = 0  # Start from the root node
        
        while children_left[node] != children_right[node]:  # Not a leaf node
            feature_index = feature[node]
            threshold_value = threshold[node]
            feature_name = X.columns[feature_index]
            
            # Record the decision (feature, threshold, direction)
            if sample[feature_name] <= threshold_value:
                path.append((feature_name, threshold_value, "left"))
                node = children_left[node]
            else:
                path.append((feature_name, threshold_value, "right"))
                node = children_right[node]
        
        # At the leaf node, record the leaf prediction
        leaf_prediction = np.argmax(value[node])
        paths.append((path, leaf_prediction))
    
    return paths

def calculate_split_importance(model):
    importance_weights = []
    
    for tree in model.estimators_:
        tree_importance = extract_split_importance(tree)
        importance_weights.append(tree_importance)
    
    return importance_weights

def extract_split_importance(tree):
    # Get the decision tree structure
    children_left = tree.tree_.children_left
    children_right = tree.tree_.children_right
    feature = tree.tree_.feature
    impurity = tree.tree_.impurity
    
    importance_weights = []
    
    for node in range(tree.tree_.node_count):
        if children_left[node] != children_right[node]:  # Not a leaf node
            feature_index = feature[node]
            left_impurity = impurity[children_left[node]]
            right_impurity = impurity[children_right[node]]
            current_impurity = impurity[node]
            
            # Calculate the impurity reduction (importance weight)
            impurity_reduction = current_impurity - (left_impurity + right_impurity) / 2
            importance_weights.append((feature_index, impurity_reduction))
    
    return importance_weights

def visualize_decision_paths(decision_paths, feature_names):
    feature_count = {feature: 0 for feature in feature_names}
    
    # Count feature usage across all decision paths
    for tree_paths in decision_paths:
        for path, _ in tree_paths:
            for feature, _, _ in path:
                feature_count[feature] += 1

    # Create a bar plot for feature usage count
    feature_usage = list(feature_count.items())
    feature_usage.sort(key=lambda x: x[1], reverse=True)

    features, counts = zip(*feature_usage)

    plt.figure(figsize=(10, 6))
    sns.barplot(x=counts, y=features, palette='viridis')
    plt.title('Feature Usage in Decision Paths', fontsize=16)
    plt.xlabel('Number of Times Feature Appears', fontsize=14)
    plt.ylabel('Feature', fontsize=14)
    plt.show()

def visualize_feature_importance(importance_weights, feature_names):
    avg_importance = {feature: [] for feature in feature_names}
    
    # Aggregate importance across all trees
    for tree_importance in importance_weights:
        for feature_index, imp in tree_importance:
            feature_name = feature_names[feature_index]
            avg_importance[feature_name].append(imp)
    
    avg_importance = {feature: np.mean(imp) for feature, imp in avg_importance.items() if imp}
    
    # Sort by importance
    sorted_importance = sorted(avg_importance.items(), key=lambda x: x[1], reverse=True)
    features, importance = zip(*sorted_importance)

    # Plot feature importance
    plt.figure(figsize=(10, 6))
    sns.barplot(x=importance, y=features, palette='viridis')
    plt.title('Feature Importance Based on Impurity Reduction', fontsize=16)
    plt.xlabel('Average Impurity Reduction', fontsize=14)
    plt.ylabel('Feature', fontsize=14)
    plt.show()

def visualize_decision_trees(model, feature_names, target_names):
    for i, tree in enumerate(model.estimators_):
        plt.figure(figsize=(20, 10))
        plot_tree(tree, feature_names=feature_names, class_names=target_names, filled=True)
        plt.title(f"Decision Tree {i + 1}")
        plt.show()

# Get decision paths and importance weights
decision_paths = get_decision_paths(rf, X)
importance_weights = calculate_split_importance(rf)

# Visualize decision paths
visualize_decision_paths(decision_paths, X.columns)

# Visualize feature importance
visualize_feature_importance(importance_weights, X.columns)

# Visualize decision trees
# visualize_decision_trees(rf, X.columns, target_names)
# Out:
# /var/folders/tk/qh_5gfz51996p7zxwjyl8r140000gp/T/ipykernel_30768/2676868043.py:98: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=counts, y=features, palette='viridis')
# /var/folders/tk/qh_5gfz51996p7zxwjyl8r140000gp/T/ipykernel_30768/2676868043.py:121: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=importance, y=features, palette='viridis')

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.tree import _tree
from sklearn.preprocessing import LabelEncoder

# Load dataset
data = load_breast_cancer()
X = data.data
y = data.target
feature_names = data.feature_names
target_names = data.target_names

X = pd.DataFrame(X, columns=feature_names)

# Train RandomForestClassifier
rf = RandomForestClassifier(n_estimators=10, random_state=42)
rf.fit(X, y)

# Function to extract decision paths/rules
def extract_rule_paths(tree, feature_names):
    tree_ = tree.tree_
    feature = tree_.feature
    threshold = tree_.threshold
    rules = []

    def recurse(node, current_rule):
        if tree_.children_left[node] == _tree.TREE_LEAF:
            rule_str = " AND ".join(current_rule)
            rules.append(rule_str)
        else:
            rule_left = f"({feature_names[feature[node]]} <= {threshold[node]:.2f})"
            current_rule.append(rule_left)
            recurse(tree_.children_left[node], current_rule)
            current_rule.pop()

            rule_right = f"({feature_names[feature[node]]} > {threshold[node]:.2f})"
            current_rule.append(rule_right)
            recurse(tree_.children_right[node], current_rule)
            current_rule.pop()

    recurse(0, [])
    return rules

# Custom rule encoder that preserves the structure
def encode_rule_structure(rules):
    encoded_rules = []
    
    # Create a label encoder for feature names (make sure to fit it first)
    feature_encoder = LabelEncoder()
    feature_encoder.fit(feature_names)  # Fit encoder on all feature names
    
    for rule in rules:
        encoded_rule = []
        
        # Split the rule into components and encode
        components = rule.split(" AND ")
        for component in components:
            # Handle the comparison operators and extract feature names
            if "<=" in component:
                feature_name, threshold = component.split(" <= ")
                feature_name = feature_name.strip("()")  # Clean up extra characters
                encoded_rule.append(f"FEAT_{feature_encoder.transform([feature_name])[0]}_LTE_{threshold}")
            elif ">" in component:
                feature_name, threshold = component.split(" > ")
                feature_name = feature_name.strip("()")  # Clean up extra characters
                encoded_rule.append(f"FEAT_{feature_encoder.transform([feature_name])[0]}_GT_{threshold}")
        
        encoded_rules.append(" AND ".join(encoded_rule))
    
    return encoded_rules

# Extract all rules from Random Forest models
all_rule_texts = []
for est in rf.estimators_:
    rules = extract_rule_paths(est, feature_names)
    all_rule_texts.extend(rules)

# Encode the rules
encoded_rules = encode_rule_structure(all_rule_texts)

# Show some of the encoded rules
for i in range(10):
    print(encoded_rules[i])
# Out:
# FEAT_22_LTE_0.14) AND FEAT_14_LTE_21.31) AND FEAT_20_LTE_947.60) AND FEAT_15_LTE_4.03) AND FEAT_21_LTE_0.35)
# FEAT_22_LTE_0.14) AND FEAT_14_LTE_21.31) AND FEAT_20_LTE_947.60) AND FEAT_15_LTE_4.03) AND FEAT_21_GT_0.35) AND FEAT_4_LTE_0.00)
# FEAT_22_LTE_0.14) AND FEAT_14_LTE_21.31) AND FEAT_20_LTE_947.60) AND FEAT_15_LTE_4.03) AND FEAT_21_GT_0.35) AND FEAT_4_GT_0.00)
# FEAT_22_LTE_0.14) AND FEAT_14_LTE_21.31) AND FEAT_20_LTE_947.60) AND FEAT_15_GT_4.03) AND FEAT_13_LTE_0.17)
# FEAT_22_LTE_0.14) AND FEAT_14_LTE_21.31) AND FEAT_20_LTE_947.60) AND FEAT_15_GT_4.03) AND FEAT_13_GT_0.17)
# FEAT_22_LTE_0.14) AND FEAT_14_LTE_21.31) AND FEAT_20_GT_947.60) AND FEAT_23_LTE_0.19)
# FEAT_22_LTE_0.14) AND FEAT_14_LTE_21.31) AND FEAT_20_GT_947.60) AND FEAT_23_GT_0.19)
# FEAT_22_LTE_0.14) AND FEAT_14_GT_21.31) AND FEAT_25_LTE_101.30) AND FEAT_12_LTE_0.09)
# FEAT_22_LTE_0.14) AND FEAT_14_GT_21.31) AND FEAT_25_LTE_101.30) AND FEAT_12_GT_0.09) AND FEAT_12_LTE_0.09)
# FEAT_22_LTE_0.14) AND FEAT_14_GT_21.31) AND FEAT_25_LTE_101.30) AND FEAT_12_GT_0.09) AND FEAT_12_GT_0.09) AND FEAT_24_LTE_0.06)

# %%
# Function to decode an encoded rule
def decode_rule_structure(encoded_rules):
    decoded_rules = []

    # Create a label encoder for feature names (must fit the same encoder used for encoding)
    feature_encoder = LabelEncoder()
    feature_encoder.fit(feature_names)  # Fit encoder on all feature names
    
    for encoded_rule in encoded_rules:
        decoded_rule = []
        
        # Split the encoded rule into components
        components = encoded_rule.split(" AND ")
        
        for component in components:
            # Extract the feature index and threshold from the encoded part
            if "_LTE_" in component:  # Handling "<="
                feature_index, threshold = component.split("_LTE_")
                feature_index = int(feature_index.replace("FEAT_", ""))
                decoded_feature = feature_encoder.inverse_transform([feature_index])[0]  # Decode feature name
                decoded_rule.append(f"({decoded_feature} <= {threshold})")
            elif "_GT_" in component:  # Handling ">"
                feature_index, threshold = component.split("_GT_")
                feature_index = int(feature_index.replace("FEAT_", ""))
                decoded_feature = feature_encoder.inverse_transform([feature_index])[0]  # Decode feature name
                decoded_rule.append(f"({decoded_feature} > {threshold})")
        
        decoded_rules.append(" AND ".join(decoded_rule))
    
    return decoded_rules

# Example of decoding the encoded rules
encoded_rule_example = ["FEAT_22_LTE_0.14) AND FEAT_14_GT_21.31) AND FEAT_25_LTE_101.30) AND FEAT_12_GT_0.09) AND FEAT_12_LTE_0.09)"]  # Example encoded rule
decoded_rule = decode_rule_structure(encoded_rule_example)

# Show the decoded rule
print(decoded_rule[0])  # Example output: (mean radius <= 15.5) AND (mean smoothness > 20.1)
# Out:
# (worst concave points <= 0.14)) AND (mean texture > 21.31)) AND (worst perimeter <= 101.30)) AND (mean smoothness > 0.09)) AND (mean smoothness <= 0.09))

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import AgglomerativeClustering

# Step 1: Vectorize the encoded rules using CountVectorizer or TfidfVectorizer
vectorizer = CountVectorizer()  # You can also try TfidfVectorizer
encoded_rule_vectors = vectorizer.fit_transform(encoded_rules)

# Step 2: Perform hierarchical clustering on the vectorized encoded rules
n_clusters = 5
clustering = AgglomerativeClustering(n_clusters=n_clusters, metric='cosine', linkage='average')
labels = clustering.fit_predict(encoded_rule_vectors.toarray())

# Step 3: Group the rules by their clusters
clustered_rules = {i: [] for i in range(n_clusters)}
for encoded_rule, label in zip(encoded_rules, labels):
    clustered_rules[label].append(encoded_rule)

# Example: Print some clustered rules
for cluster_id, rules in clustered_rules.items():
    print(f"Cluster {cluster_id}:")
    for rule in rules[:5]:  # Show first 5 rules in each cluster
        print(f"  {rule}")
    print("\n")
# Out:
# Cluster 0:
#   FEAT_22_LTE_0.14) AND FEAT_14_LTE_21.31) AND FEAT_20_LTE_947.60) AND FEAT_15_LTE_4.03) AND FEAT_21_LTE_0.35)
#   FEAT_22_LTE_0.14) AND FEAT_14_LTE_21.31) AND FEAT_20_LTE_947.60) AND FEAT_15_LTE_4.03) AND FEAT_21_GT_0.35) AND FEAT_4_LTE_0.00)
#   FEAT_22_LTE_0.14) AND FEAT_14_LTE_21.31) AND FEAT_20_LTE_947.60) AND FEAT_15_LTE_4.03) AND FEAT_21_GT_0.35) AND FEAT_4_GT_0.00)
#   FEAT_22_LTE_0.14) AND FEAT_14_LTE_21.31) AND FEAT_20_LTE_947.60) AND FEAT_15_GT_4.03) AND FEAT_13_LTE_0.17)
#   FEAT_22_LTE_0.14) AND FEAT_14_LTE_21.31) AND FEAT_20_LTE_947.60) AND FEAT_15_GT_4.03) AND FEAT_13_GT_0.17)
#
#
# Cluster 1:
#   FEAT_26_GT_16.80) AND FEAT_14_LTE_15.82) AND FEAT_9_LTE_0.06)
#   FEAT_26_GT_16.80) AND FEAT_14_LTE_15.82) AND FEAT_9_GT_0.06)
#   FEAT_26_GT_16.80) AND FEAT_14_GT_15.82) AND FEAT_13_LTE_0.15) AND FEAT_13_LTE_0.15)
#   FEAT_26_GT_16.80) AND FEAT_14_GT_15.82) AND FEAT_13_LTE_0.15) AND FEAT_13_GT_0.15)
#   FEAT_26_GT_16.80) AND FEAT_14_GT_15.82) AND FEAT_13_GT_0.15)
#
#
# Cluster 2:
#   FEAT_23_LTE_0.26) AND FEAT_22_GT_0.16)
#
#
# Cluster 3:
#   FEAT_8_LTE_0.09) AND FEAT_26_GT_18.64)
#
#
# Cluster 4:
#   FEAT_10_GT_98.76) AND FEAT_14_LTE_14.10)
#   FEAT_10_GT_98.76) AND FEAT_14_GT_14.10) AND FEAT_4_LTE_0.00) AND FEAT_1_LTE_0.02)
#   FEAT_10_GT_98.76) AND FEAT_14_GT_14.10) AND FEAT_4_LTE_0.00) AND FEAT_1_GT_0.02)
#   FEAT_10_GT_98.76) AND FEAT_14_GT_14.10) AND FEAT_4_GT_0.00)

# %% [markdown]
# 1. **Explaining TF-IDF Preservation of Rule Structure**: This involves explaining how the feature encoding and the use of TF-IDF help preserve the logical structure of the rules (like mathematical operators and conditions) even after encoding feature names and thresholds.
#
#
#
# ### TF-IDF and Rule Structure Preservation
#
# When you encode rules, you need to preserve the logical structure (`<`, `>`, `=`, `AND`, `OR`) to maintain interpretability. TF-IDF (Term Frequency-Inverse Document Frequency) is traditionally used for text data, but when you use it for rules, we need to map the rule’s logical structure into features that TF-IDF can handle, ensuring the structure is preserved.
#
# #### Explanation of TF-IDF in Rule Encoding
#
# 1. **Feature and Threshold Encoding**: The features in the rule, like `FEAT_8_LTE_0.09`, are encoded using a consistent naming convention like `FEAT_8_LTE_0.09`. The feature names (`FEAT_8`) and thresholds (`0.09`) are preserved directly as terms.
#
#    Example:
#    - Original rule: `FEAT_8 <= 0.09 AND FEAT_20 > 957.45`
#    - Encoded rule (for TF-IDF): `FEAT_8_LTE_0.09 AND FEAT_20_GT_957.45`
#
# 2. **Mathematical Operators**: The logical operators like `<=`, `>`, and `AND` are encoded as part of the feature strings, allowing TF-IDF to capture the interaction between features and thresholds.
#    - The `<=` or `>` becomes part of the feature string, ensuring that the direction of the condition is preserved.
#    - The logical `AND` (and potentially `OR`) operators link the conditions together, so they are recognized as connected terms in the rule.
#
# 3. **Preservation of Rule Structure**: When rules are encoded into feature vectors using TF-IDF:
#    - **Term Frequency (TF)** captures how frequently a feature or condition appears across all rules. This tells you the "importance" of that feature in the decision rules.
#    - **Inverse Document Frequency (IDF)** highlights features that are rarer, giving higher importance to features that occur less frequently but still contribute to distinguishing between classes.
#
#    This structure is preserved because the individual conditions like `FEAT_8_LTE_0.09`, `FEAT_20_GT_957.45`, and the logical operators like `AND` are treated as individual terms. The interactions between them are captured in the vectorized form.
#
# #### Example: Encoding Preservation
#
# Let's consider the rule `FEAT_8 <= 0.09 AND FEAT_20 > 957.45`. After encoding:
#
# - `FEAT_8_LTE_0.09` will be a term.
# - `FEAT_20_GT_957.45` will be another term.
# - `AND` is treated as a logical separator that helps relate these terms to one another.
#
# Using TF-IDF, the model will generate a vector where:
# - The presence or absence of terms like `FEAT_8_LTE_0.09` and `FEAT_20_GT_957.45` is captured.
# - The logical relationship (like `AND`) between the terms remains part of the rule, maintaining the interpretability of the model.
#
# ### Final Thoughts
#
# - **Parallel Coordinates**: This will help visualize how the feature values are influencing the predictions across different rules, showing which rules contribute to a prediction of `1` or `0`.
# - **TF-IDF Preservation**: By encoding features and conditions as terms, TF-IDF preserves the logical structure of the rules. This encoding process ensures that the logical connections between features, thresholds, and logical operators are captured, allowing for interpretable rule-based explanations.

# %%
# 5. Visualize the clusters
# Create a DataFrame for the clusters and rules
cluster_df = pd.DataFrame({
    'Cluster': labels,
    'Rule': all_rule_texts
})

# %%
# # Visualize the clusters with PCA for dimensionality reduction (to 2D)
# from sklearn.decomposition import PCA
# import matplotlib.pyplot as plt
# pca = PCA(n_components=2)
# reduced_vectors = pca.fit_transform(encoded_rule_vectors.toarray())

# # Plot the clusters with different colors
# plt.figure(figsize=(20, 20))
# plt.scatter(reduced_vectors[:, 0], reduced_vectors[:, 1], c=labels, cmap='viridis')
# plt.colorbar(label='Cluster')
# plt.title("PCA of Clusters with Corresponding Rules")
# plt.xlabel("PCA Component 1")
# plt.ylabel("PCA Component 2")

# # Add the rules as labels
# for i, rule in enumerate(all_rule_texts):
#     plt.annotate(rule[:30], (reduced_vectors[i, 0], reduced_vectors[i, 1]), fontsize=4, alpha=0.8)
# plt.show()

# %%
# # 6. Print out the clustered rules
# print("\nClustered Rules:")
# for cluster, rules in clustered_rules.items():
#     print(f"\nCluster {cluster}:")
#     for rule in rules:
#         print(f" - {rule[:100]}...")  # Print the first 100 characters of each rule for brevity

# %%
# Mapping from encoded feature names to actual feature names
feature_mapping = {f"FEAT_{i}": feature for i, feature in enumerate(X.columns)}

# Initialize edge weights
edge_weights = {}

# Debug: Check rule extraction and feature matching
for rule_text in encoded_rules:
    # Extract the features and thresholds
    conditions = re.findall(r'FEAT_(\d+)_\w+_([\d\.]+)', rule_text)
    
    # Debug: Print the extracted features and thresholds
    print(f"Rule: {rule_text}")
    print(f"Extracted Conditions: {conditions}")

    # Map FEAT_0, FEAT_1, ... back to actual feature names in the dataset
    features_in_rule = [feature_mapping[f"FEAT_{cond[0]}"] for cond in conditions if f"FEAT_{cond[0]}" in feature_mapping]

    # Debug: Print the features that match the dataset
    print(f"Matching Features: {features_in_rule}")

    # If features are valid, build the edges
    if len(features_in_rule) > 1:
        for i in range(len(features_in_rule) - 1):
            edge = (features_in_rule[i], features_in_rule[i+1])
            edge_weights[edge] = edge_weights.get(edge, 0) + 1

# Create a directed graph using networkx
G = nx.DiGraph()

# Add edges and their weights to the graph
for (f_from, f_to), weight in edge_weights.items():
    G.add_edge(f_from, f_to, weight=weight)

# # Debug: Check the graph before proceeding
# print(f"Graph Nodes: {list(G.nodes())}")
# print(f"Graph Edges: {list(G.edges(data=True))}")

# Create a reversed graph (H) with negated weights for minimum spanning arborescence
H = nx.DiGraph()
for u, v, d in G.edges(data=True):
    H.add_edge(u, v, weight=-d['weight'])

# Compute the Minimum Spanning Arborescence (MSA)
if len(list(H.nodes())) > 0:
    root = list(H.nodes())[0]  # Choose an arbitrary root node
    msa = nx.minimum_spanning_arborescence(H)

    # Revert the edge weights to positive after the spanning tree computation
    for u, v, d in msa.edges(data=True):
        d['weight'] = -d['weight']
    
    # Plot the graph
    plt.figure(figsize=(20, 20))
    pos = nx.circular_layout(msa)  # Using circular layout for better visualization
    edge_labels = nx.get_edge_attributes(msa, 'weight')

    # Draw the nodes, edges, and edge labels
    nx.draw(msa, pos, with_labels=True, node_size=200, node_color="lightcoral", arrowsize=10)
    nx.draw_networkx_edge_labels(msa, pos, edge_labels=edge_labels)

    plt.title("Surrogate Interpretable Graph (MSA) [Un-optimized]")
    plt.show()
else:
    print("Graph H is empty. No feature transitions were detected.")
# Out:
# Rule: FEAT_22_LTE_0.14) AND FEAT_14_LTE_21.31) AND FEAT_20_LTE_947.60) AND FEAT_15_LTE_4.03) AND FEAT_21_LTE_0.35)
# Extracted Conditions: [('22', '0.14'), ('14', '21.31'), ('20', '947.60'), ('15', '4.03'), ('21', '0.35')]
# Matching Features: ['worst perimeter', 'smoothness error', 'worst radius', 'compactness error', 'worst texture']
# Rule: FEAT_22_LTE_0.14) AND FEAT_14_LTE_21.31) AND FEAT_20_LTE_947.60) AND FEAT_15_LTE_4.03) AND FEAT_21_GT_0.35) AND FEAT_4_LTE_0.00)
# Extracted Conditions: [('22', '0.14'), ('14', '21.31'), ('20', '947.60'), ('15', '4.03'), ('21', '0.35'), ('4', '0.00')]
# Matching Features: ['worst perimeter', 'smoothness error', 'worst radius', 'compactness error', 'worst texture', 'mean smoothness']
# Rule: FEAT_22_LTE_0.14) AND FEAT_14_LTE_21.31) AND FEAT_20_LTE_947.60) AND FEAT_15_LTE_4.03) AND FEAT_21_GT_0.35) AND FEAT_4_GT_0.00)
# Extracted Conditions: [('22', '0.14'), ('14', '21.31'), ('20', '947.60'), ('15', '4.03'), ('21', '0.35'), ('4', '0.00')]
# Matching Features: ['worst perimeter', 'smoothness error', 'worst radius', 'compactness error', 'worst texture', 'mean smoothness']
# Rule: FEAT_22_LTE_0.14) AND FEAT_14_LTE_21.31) AND FEAT_20_LTE_947.60) AND FEAT_15_GT_4.03) AND FEAT_13_LTE_0.17)
# Extracted Conditions: [('22', '0.14'), ('14', '21.31'), ('20', '947.60'), ('15', '4.03'), ('13', '0.17')]
# Matching Features: ['worst perimeter', 'smoothness error', 'worst radius', 'compactness error', 'area error']
# Rule: FEAT_22_LTE_0.14) AND FEAT_14_LTE_21.31) AND FEAT_20_LTE_947.60) AND FEAT_15_GT_4.03) AND FEAT_13_GT_0.17)
# Extracted Conditions: [('22', '0.14'), ('14', '21.31'), ('20', '947.60'), ('15', '4.03'), ('13', '0.17')]
# Matching Features: ['worst perimeter', 'smoothness error', 'worst radius', 'compactness error', 'area error']
# Rule: FEAT_22_LTE_0.14) AND FEAT_14_LTE_21.31) AND FEAT_20_GT_947.60) AND FEAT_23_LTE_0.19)
# Extracted Conditions: [('22', '0.14'), ('14', '21.31'), ('20', '947.60'), ('23', '0.19')]
# Matching Features: ['worst perimeter', 'smoothness error', 'worst radius', 'worst area']
# Rule: FEAT_22_LTE_0.14) AND FEAT_14_LTE_21.31) AND FEAT_20_GT_947.60) AND FEAT_23_GT_0.19)
# Extracted Conditions: [('22', '0.14'), ('14', '21.31'), ('20', '947.60'), ('23', '0.19')]
# Matching Features: ['worst perimeter', 'smoothness error', 'worst radius', 'worst area']
# Rule: FEAT_22_LTE_0.14) AND FEAT_14_GT_21.31) AND FEAT_25_LTE_101.30) AND FEAT_12_LTE_0.09)
# Extracted Conditions: [('22', '0.14'), ('14', '21.31'), ('25', '101.30'), ('12', '0.09')]
# Matching Features: ['worst perimeter', 'smoothness error', 'worst compactness', 'perimeter error']
# Rule: FEAT_22_LTE_0.14) AND FEAT_14_GT_21.31) AND FEAT_25_LTE_101.30) AND FEAT_12_GT_0.09) AND FEAT_12_LTE_0.09)
# Extracted Conditions: [('22', '0.14'), ('14', '21.31'), ('25', '101.30'), ('12', '0.09'), ('12', '0.09')]
# Matching Features: ['worst perimeter', 'smoothness error', 'worst compactness', 'perimeter error', 'perimeter error']
# Rule: FEAT_22_LTE_0.14) AND FEAT_14_GT_21.31) AND FEAT_25_LTE_101.30) AND FEAT_12_GT_0.09) AND FEAT_12_GT_0.09) AND FEAT_24_LTE_0.06)
# Extracted Conditions: [('22', '0.14'), ('14', '21.31'), ('25', '101.30'), ('12', '0.09'), ('12', '0.09'), ('24', '0.06')]
# Matching Features: ['worst perimeter', 'smoothness error', 'worst compactness', 'perimeter error', 'perimeter error', 'worst smoothness']
# Rule: FEAT_22_LTE_0.14) AND FEAT_14_GT_21.31) AND FEAT_25_LTE_101.30) AND FEAT_12_GT_0.09) AND FEAT_12_GT_0.09) AND FEAT_24_GT_0.06) AND FEAT_22_LTE_0.13)
# Extracted Conditions: [('22', '0.14'), ('14', '21.31'), ('25', '101.30'), ('12', '0.09'), ('12', '0.09'), ('24', '0.06'), ('22', '0.13')]
# Matching Features: ['worst perimeter', 'smoothness error', 'worst compactness', 'perimeter error', 'perimeter error', 'worst smoothness', 'worst perimeter']
# Rule: FEAT_22_LTE_0.14) AND FEAT_14_GT_21.31) AND FEAT_25_LTE_101.30) AND FEAT_12_GT_0.09) AND FEAT_12_GT_0.09) AND FEAT_24_GT_0.06) AND FEAT_22_GT_0.13)
# Extracted Conditions: [('22', '0.14'), ('14', '21.31'), ('25', '101.30'), ('12', '0.09'), ('12', '0.09'), ('24', '0.06'), ('22', '0.13')]
# Matching Features: ['worst perimeter', 'smoothness error', 'worst compactness', 'perimeter error', 'perimeter error', 'worst smoothness', 'worst perimeter']
# Rule: FEAT_22_LTE_0.14) AND FEAT_14_GT_21.31) AND FEAT_25_GT_101.30) AND FEAT_26_LTE_16.80) AND FEAT_4_LTE_0.00)
# Extracted Conditions: [('22', '0.14'), ('14', '21.31'), ('25', '101.30'), ('26', '16.80'), ('4', '0.00')]
# Matching Features: ['worst perimeter', 'smoothness error', 'worst compactness', 'worst concavity', 'mean smoothness']
# Rule: FEAT_22_LTE_0.14) AND FEAT_14_GT_21.31) AND FEAT_25_GT_101.30) AND FEAT_26_LTE_16.80) AND FEAT_4_GT_0.00)
# Extracted Conditions: [('22', '0.14'), ('14', '21.31'), ('25', '101.30'), ('26', '16.80'), ('4', '0.00')]
# Matching Features: ['worst perimeter', 'smoothness error', 'worst compactness', 'worst concavity', 'mean smoothness']
# Rule: FEAT_22_LTE_0.14) AND FEAT_14_GT_21.31) AND FEAT_25_GT_101.30) AND FEAT_26_GT_16.80)
# Extracted Conditions: [('22', '0.14'), ('14', '21.31'), ('25', '101.30'), ('26', '16.80')]
# Matching Features: ['worst perimeter', 'smoothness error', 'worst compactness', 'worst concavity']
# Rule: FEAT_22_GT_0.14) AND FEAT_20_LTE_492.25)
# Extracted Conditions: [('22', '0.14'), ('20', '492.25')]
# Matching Features: ['worst perimeter', 'worst radius']
# Rule: FEAT_22_GT_0.14) AND FEAT_20_GT_492.25) AND FEAT_15_LTE_1.54)
# Extracted Conditions: [('22', '0.14'), ('20', '492.25'), ('15', '1.54')]
# Matching Features: ['worst perimeter', 'worst radius', 'compactness error']
# Rule: FEAT_22_GT_0.14) AND FEAT_20_GT_492.25) AND FEAT_15_GT_1.54) AND FEAT_6_LTE_0.10) AND FEAT_23_LTE_0.21)
# Extracted Conditions: [('22', '0.14'), ('20', '492.25'), ('15', '1.54'), ('6', '0.10'), ('23', '0.21')]
# Matching Features: ['worst perimeter', 'worst radius', 'compactness error', 'mean concavity', 'worst area']
# Rule: FEAT_22_GT_0.14) AND FEAT_20_GT_492.25) AND FEAT_15_GT_1.54) AND FEAT_6_LTE_0.10) AND FEAT_23_GT_0.21)
# Extracted Conditions: [('22', '0.14'), ('20', '492.25'), ('15', '1.54'), ('6', '0.10'), ('23', '0.21')]
# Matching Features: ['worst perimeter', 'worst radius', 'compactness error', 'mean concavity', 'worst area']
# Rule: FEAT_22_GT_0.14) AND FEAT_20_GT_492.25) AND FEAT_15_GT_1.54) AND FEAT_6_GT_0.10)
# Extracted Conditions: [('22', '0.14'), ('20', '492.25'), ('15', '1.54'), ('6', '0.10')]
# Matching Features: ['worst perimeter', 'worst radius', 'compactness error', 'mean concavity']
# Rule: FEAT_23_LTE_0.26) AND FEAT_22_LTE_0.16) AND FEAT_20_LTE_1058.00) AND FEAT_22_LTE_0.11) AND FEAT_26_LTE_17.02) AND FEAT_12_LTE_0.10)
# Extracted Conditions: [('23', '0.26'), ('22', '0.16'), ('20', '1058.00'), ('22', '0.11'), ('26', '17.02'), ('12', '0.10')]
# Matching Features: ['worst area', 'worst perimeter', 'worst radius', 'worst perimeter', 'worst concavity', 'perimeter error']
# Rule: FEAT_23_LTE_0.26) AND FEAT_22_LTE_0.16) AND FEAT_20_LTE_1058.00) AND FEAT_22_LTE_0.11) AND FEAT_26_LTE_17.02) AND FEAT_12_GT_0.10) AND FEAT_27_LTE_0.11)
# Extracted Conditions: [('23', '0.26'), ('22', '0.16'), ('20', '1058.00'), ('22', '0.11'), ('26', '17.02'), ('12', '0.10'), ('27', '0.11')]
# Matching Features: ['worst area', 'worst perimeter', 'worst radius', 'worst perimeter', 'worst concavity', 'perimeter error', 'worst concave points']
# Rule: FEAT_23_LTE_0.26) AND FEAT_22_LTE_0.16) AND FEAT_20_LTE_1058.00) AND FEAT_22_LTE_0.11) AND FEAT_26_LTE_17.02) AND FEAT_12_GT_0.10) AND FEAT_27_GT_0.11)
# Extracted Conditions: [('23', '0.26'), ('22', '0.16'), ('20', '1058.00'), ('22', '0.11'), ('26', '17.02'), ('12', '0.10'), ('27', '0.11')]
# Matching Features: ['worst area', 'worst perimeter', 'worst radius', 'worst perimeter', 'worst concavity', 'perimeter error', 'worst concave points']
# Rule: FEAT_23_LTE_0.26) AND FEAT_22_LTE_0.16) AND FEAT_20_LTE_1058.00) AND FEAT_22_LTE_0.11) AND FEAT_26_GT_17.02) AND FEAT_26_LTE_17.69)
# Extracted Conditions: [('23', '0.26'), ('22', '0.16'), ('20', '1058.00'), ('22', '0.11'), ('26', '17.02'), ('26', '17.69')]
# Matching Features: ['worst area', 'worst perimeter', 'worst radius', 'worst perimeter', 'worst concavity', 'worst concavity']
# Rule: FEAT_23_LTE_0.26) AND FEAT_22_LTE_0.16) AND FEAT_20_LTE_1058.00) AND FEAT_22_LTE_0.11) AND FEAT_26_GT_17.02) AND FEAT_26_GT_17.69)
# Extracted Conditions: [('23', '0.26'), ('22', '0.16'), ('20', '1058.00'), ('22', '0.11'), ('26', '17.02'), ('26', '17.69')]
# Matching Features: ['worst area', 'worst perimeter', 'worst radius', 'worst perimeter', 'worst concavity', 'worst concavity']
# Rule: FEAT_23_LTE_0.26) AND FEAT_22_LTE_0.16) AND FEAT_20_LTE_1058.00) AND FEAT_22_GT_0.11) AND FEAT_9_LTE_0.06)
# Extracted Conditions: [('23', '0.26'), ('22', '0.16'), ('20', '1058.00'), ('22', '0.11'), ('9', '0.06')]
# Matching Features: ['worst area', 'worst perimeter', 'worst radius', 'worst perimeter', 'mean fractal dimension']
# Rule: FEAT_23_LTE_0.26) AND FEAT_22_LTE_0.16) AND FEAT_20_LTE_1058.00) AND FEAT_22_GT_0.11) AND FEAT_9_GT_0.06)
# Extracted Conditions: [('23', '0.26'), ('22', '0.16'), ('20', '1058.00'), ('22', '0.11'), ('9', '0.06')]
# Matching Features: ['worst area', 'worst perimeter', 'worst radius', 'worst perimeter', 'mean fractal dimension']
# Rule: FEAT_23_LTE_0.26) AND FEAT_22_LTE_0.16) AND FEAT_20_GT_1058.00)
# Extracted Conditions: [('23', '0.26'), ('22', '0.16'), ('20', '1058.00')]
# Matching Features: ['worst area', 'worst perimeter', 'worst radius']
# Rule: FEAT_23_LTE_0.26) AND FEAT_22_GT_0.16)
# Extracted Conditions: [('23', '0.26'), ('22', '0.16')]
# Matching Features: ['worst area', 'worst perimeter']
# Rule: FEAT_23_GT_0.26) AND FEAT_25_LTE_100.59) AND FEAT_22_LTE_0.18) AND FEAT_29_LTE_33.61)
# Extracted Conditions: [('23', '0.26'), ('25', '100.59'), ('22', '0.18'), ('29', '33.61')]
# Matching Features: ['worst area', 'worst compactness', 'worst perimeter', 'worst fractal dimension']
# Rule: FEAT_23_GT_0.26) AND FEAT_25_LTE_100.59) AND FEAT_22_LTE_0.18) AND FEAT_29_GT_33.61) AND FEAT_23_LTE_0.35)
# Extracted Conditions: [('23', '0.26'), ('25', '100.59'), ('22', '0.18'), ('29', '33.61'), ('23', '0.35')]
# Matching Features: ['worst area', 'worst compactness', 'worst perimeter', 'worst fractal dimension', 'worst area']
# Rule: FEAT_23_GT_0.26) AND FEAT_25_LTE_100.59) AND FEAT_22_LTE_0.18) AND FEAT_29_GT_33.61) AND FEAT_23_GT_0.35)
# Extracted Conditions: [('23', '0.26'), ('25', '100.59'), ('22', '0.18'), ('29', '33.61'), ('23', '0.35')]
# Matching Features: ['worst area', 'worst compactness', 'worst perimeter', 'worst fractal dimension', 'worst area']
# Rule: FEAT_23_GT_0.26) AND FEAT_25_LTE_100.59) AND FEAT_22_GT_0.18)
# Extracted Conditions: [('23', '0.26'), ('25', '100.59'), ('22', '0.18')]
# Matching Features: ['worst area', 'worst compactness', 'worst perimeter']
# Rule: FEAT_23_GT_0.26) AND FEAT_25_GT_100.59) AND FEAT_7_LTE_0.04) AND FEAT_2_LTE_0.01)
# Extracted Conditions: [('23', '0.26'), ('25', '100.59'), ('7', '0.04'), ('2', '0.01')]
# Matching Features: ['worst area', 'worst compactness', 'mean concave points', 'mean perimeter']
# Rule: FEAT_23_GT_0.26) AND FEAT_25_GT_100.59) AND FEAT_7_LTE_0.04) AND FEAT_2_GT_0.01) AND FEAT_23_LTE_0.26)
# Extracted Conditions: [('23', '0.26'), ('25', '100.59'), ('7', '0.04'), ('2', '0.01'), ('23', '0.26')]
# Matching Features: ['worst area', 'worst compactness', 'mean concave points', 'mean perimeter', 'worst area']
# Rule: FEAT_23_GT_0.26) AND FEAT_25_GT_100.59) AND FEAT_7_LTE_0.04) AND FEAT_2_GT_0.01) AND FEAT_23_GT_0.26)
# Extracted Conditions: [('23', '0.26'), ('25', '100.59'), ('7', '0.04'), ('2', '0.01'), ('23', '0.26')]
# Matching Features: ['worst area', 'worst compactness', 'mean concave points', 'mean perimeter', 'worst area']
# Rule: FEAT_23_GT_0.26) AND FEAT_25_GT_100.59) AND FEAT_7_GT_0.04) AND FEAT_5_LTE_656.50) AND FEAT_10_LTE_97.12) AND FEAT_29_LTE_22.94)
# Extracted Conditions: [('23', '0.26'), ('25', '100.59'), ('7', '0.04'), ('5', '656.50'), ('10', '97.12'), ('29', '22.94')]
# Matching Features: ['worst area', 'worst compactness', 'mean concave points', 'mean compactness', 'radius error', 'worst fractal dimension']
# Rule: FEAT_23_GT_0.26) AND FEAT_25_GT_100.59) AND FEAT_7_GT_0.04) AND FEAT_5_LTE_656.50) AND FEAT_10_LTE_97.12) AND FEAT_29_GT_22.94)
# Extracted Conditions: [('23', '0.26'), ('25', '100.59'), ('7', '0.04'), ('5', '656.50'), ('10', '97.12'), ('29', '22.94')]
# Matching Features: ['worst area', 'worst compactness', 'mean concave points', 'mean compactness', 'radius error', 'worst fractal dimension']
# Rule: FEAT_23_GT_0.26) AND FEAT_25_GT_100.59) AND FEAT_7_GT_0.04) AND FEAT_5_LTE_656.50) AND FEAT_10_GT_97.12)
# Extracted Conditions: [('23', '0.26'), ('25', '100.59'), ('7', '0.04'), ('5', '656.50'), ('10', '97.12')]
# Matching Features: ['worst area', 'worst compactness', 'mean concave points', 'mean compactness', 'radius error']
# Rule: FEAT_23_GT_0.26) AND FEAT_25_GT_100.59) AND FEAT_7_GT_0.04) AND FEAT_5_GT_656.50)
# Extracted Conditions: [('23', '0.26'), ('25', '100.59'), ('7', '0.04'), ('5', '656.50')]
# Matching Features: ['worst area', 'worst compactness', 'mean concave points', 'mean compactness']
# Rule: FEAT_22_LTE_0.14) AND FEAT_5_LTE_694.10) AND FEAT_20_LTE_727.10) AND FEAT_0_LTE_48.98) AND FEAT_25_LTE_92.02)
# Extracted Conditions: [('22', '0.14'), ('5', '694.10'), ('20', '727.10'), ('0', '48.98'), ('25', '92.02')]
# Matching Features: ['worst perimeter', 'mean compactness', 'worst radius', 'mean radius', 'worst compactness']
# Rule: FEAT_22_LTE_0.14) AND FEAT_5_LTE_694.10) AND FEAT_20_LTE_727.10) AND FEAT_0_LTE_48.98) AND FEAT_25_GT_92.02) AND FEAT_17_LTE_0.01)
# Extracted Conditions: [('22', '0.14'), ('5', '694.10'), ('20', '727.10'), ('0', '48.98'), ('25', '92.02'), ('17', '0.01')]
# Matching Features: ['worst perimeter', 'mean compactness', 'worst radius', 'mean radius', 'worst compactness', 'concave points error']
# Rule: FEAT_22_LTE_0.14) AND FEAT_5_LTE_694.10) AND FEAT_20_LTE_727.10) AND FEAT_0_LTE_48.98) AND FEAT_25_GT_92.02) AND FEAT_17_GT_0.01) AND FEAT_12_LTE_0.09)
# Extracted Conditions: [('22', '0.14'), ('5', '694.10'), ('20', '727.10'), ('0', '48.98'), ('25', '92.02'), ('17', '0.01'), ('12', '0.09')]
# Matching Features: ['worst perimeter', 'mean compactness', 'worst radius', 'mean radius', 'worst compactness', 'concave points error', 'perimeter error']
# Rule: FEAT_22_LTE_0.14) AND FEAT_5_LTE_694.10) AND FEAT_20_LTE_727.10) AND FEAT_0_LTE_48.98) AND FEAT_25_GT_92.02) AND FEAT_17_GT_0.01) AND FEAT_12_GT_0.09)
# Extracted Conditions: [('22', '0.14'), ('5', '694.10'), ('20', '727.10'), ('0', '48.98'), ('25', '92.02'), ('17', '0.01'), ('12', '0.09')]
# Matching Features: ['worst perimeter', 'mean compactness', 'worst radius', 'mean radius', 'worst compactness', 'concave points error', 'perimeter error']
# Rule: FEAT_22_LTE_0.14) AND FEAT_5_LTE_694.10) AND FEAT_20_LTE_727.10) AND FEAT_0_GT_48.98)
# Extracted Conditions: [('22', '0.14'), ('5', '694.10'), ('20', '727.10'), ('0', '48.98')]
# Matching Features: ['worst perimeter', 'mean compactness', 'worst radius', 'mean radius']
# Rule: FEAT_22_LTE_0.14) AND FEAT_5_LTE_694.10) AND FEAT_20_GT_727.10) AND FEAT_29_LTE_29.68) AND FEAT_27_LTE_0.14)
# Extracted Conditions: [('22', '0.14'), ('5', '694.10'), ('20', '727.10'), ('29', '29.68'), ('27', '0.14')]
# Matching Features: ['worst perimeter', 'mean compactness', 'worst radius', 'worst fractal dimension', 'worst concave points']
# Rule: FEAT_22_LTE_0.14) AND FEAT_5_LTE_694.10) AND FEAT_20_GT_727.10) AND FEAT_29_LTE_29.68) AND FEAT_27_GT_0.14)
# Extracted Conditions: [('22', '0.14'), ('5', '694.10'), ('20', '727.10'), ('29', '29.68'), ('27', '0.14')]
# Matching Features: ['worst perimeter', 'mean compactness', 'worst radius', 'worst fractal dimension', 'worst concave points']
# Rule: FEAT_22_LTE_0.14) AND FEAT_5_LTE_694.10) AND FEAT_20_GT_727.10) AND FEAT_29_GT_29.68) AND FEAT_19_LTE_0.87)
# Extracted Conditions: [('22', '0.14'), ('5', '694.10'), ('20', '727.10'), ('29', '29.68'), ('19', '0.87')]
# Matching Features: ['worst perimeter', 'mean compactness', 'worst radius', 'worst fractal dimension', 'fractal dimension error']
# Rule: FEAT_22_LTE_0.14) AND FEAT_5_LTE_694.10) AND FEAT_20_GT_727.10) AND FEAT_29_GT_29.68) AND FEAT_19_GT_0.87) AND FEAT_19_LTE_1.35)
# Extracted Conditions: [('22', '0.14'), ('5', '694.10'), ('20', '727.10'), ('29', '29.68'), ('19', '0.87'), ('19', '1.35')]
# Matching Features: ['worst perimeter', 'mean compactness', 'worst radius', 'worst fractal dimension', 'fractal dimension error', 'fractal dimension error']
# Rule: FEAT_22_LTE_0.14) AND FEAT_5_LTE_694.10) AND FEAT_20_GT_727.10) AND FEAT_29_GT_29.68) AND FEAT_19_GT_0.87) AND FEAT_19_GT_1.35) AND FEAT_28_LTE_0.22)
# Extracted Conditions: [('22', '0.14'), ('5', '694.10'), ('20', '727.10'), ('29', '29.68'), ('19', '0.87'), ('19', '1.35'), ('28', '0.22')]
# Matching Features: ['worst perimeter', 'mean compactness', 'worst radius', 'worst fractal dimension', 'fractal dimension error', 'fractal dimension error', 'worst symmetry']
# Rule: FEAT_22_LTE_0.14) AND FEAT_5_LTE_694.10) AND FEAT_20_GT_727.10) AND FEAT_29_GT_29.68) AND FEAT_19_GT_0.87) AND FEAT_19_GT_1.35) AND FEAT_28_GT_0.22)
# Extracted Conditions: [('22', '0.14'), ('5', '694.10'), ('20', '727.10'), ('29', '29.68'), ('19', '0.87'), ('19', '1.35'), ('28', '0.22')]
# Matching Features: ['worst perimeter', 'mean compactness', 'worst radius', 'worst fractal dimension', 'fractal dimension error', 'fractal dimension error', 'worst symmetry']
# Rule: FEAT_22_LTE_0.14) AND FEAT_5_GT_694.10) AND FEAT_29_LTE_19.74)
# Extracted Conditions: [('22', '0.14'), ('5', '694.10'), ('29', '19.74')]
# Matching Features: ['worst perimeter', 'mean compactness', 'worst fractal dimension']
# Rule: FEAT_22_LTE_0.14) AND FEAT_5_GT_694.10) AND FEAT_29_GT_19.74) AND FEAT_19_LTE_1.44)
# Extracted Conditions: [('22', '0.14'), ('5', '694.10'), ('29', '19.74'), ('19', '1.44')]
# Matching Features: ['worst perimeter', 'mean compactness', 'worst fractal dimension', 'fractal dimension error']
# Rule: FEAT_22_LTE_0.14) AND FEAT_5_GT_694.10) AND FEAT_29_GT_19.74) AND FEAT_19_GT_1.44) AND FEAT_16_LTE_0.50)
# Extracted Conditions: [('22', '0.14'), ('5', '694.10'), ('29', '19.74'), ('19', '1.44'), ('16', '0.50')]
# Matching Features: ['worst perimeter', 'mean compactness', 'worst fractal dimension', 'fractal dimension error', 'concavity error']
# Rule: FEAT_22_LTE_0.14) AND FEAT_5_GT_694.10) AND FEAT_29_GT_19.74) AND FEAT_19_GT_1.44) AND FEAT_16_GT_0.50)
# Extracted Conditions: [('22', '0.14'), ('5', '694.10'), ('29', '19.74'), ('19', '1.44'), ('16', '0.50')]
# Matching Features: ['worst perimeter', 'mean compactness', 'worst fractal dimension', 'fractal dimension error', 'concavity error']
# Rule: FEAT_22_GT_0.14) AND FEAT_26_LTE_16.29) AND FEAT_24_LTE_0.12) AND FEAT_1_LTE_0.02)
# Extracted Conditions: [('22', '0.14'), ('26', '16.29'), ('24', '0.12'), ('1', '0.02')]
# Matching Features: ['worst perimeter', 'worst concavity', 'worst smoothness', 'mean texture']
# Rule: FEAT_22_GT_0.14) AND FEAT_26_LTE_16.29) AND FEAT_24_LTE_0.12) AND FEAT_1_GT_0.02) AND FEAT_13_LTE_0.24)
# Extracted Conditions: [('22', '0.14'), ('26', '16.29'), ('24', '0.12'), ('1', '0.02'), ('13', '0.24')]
# Matching Features: ['worst perimeter', 'worst concavity', 'worst smoothness', 'mean texture', 'area error']
# Rule: FEAT_22_GT_0.14) AND FEAT_26_LTE_16.29) AND FEAT_24_LTE_0.12) AND FEAT_1_GT_0.02) AND FEAT_13_GT_0.24)
# Extracted Conditions: [('22', '0.14'), ('26', '16.29'), ('24', '0.12'), ('1', '0.02'), ('13', '0.24')]
# Matching Features: ['worst perimeter', 'worst concavity', 'worst smoothness', 'mean texture', 'area error']
# Rule: FEAT_22_GT_0.14) AND FEAT_26_LTE_16.29) AND FEAT_24_GT_0.12)
# Extracted Conditions: [('22', '0.14'), ('26', '16.29'), ('24', '0.12')]
# Matching Features: ['worst perimeter', 'worst concavity', 'worst smoothness']
# Rule: FEAT_22_GT_0.14) AND FEAT_26_GT_16.29) AND FEAT_22_LTE_0.15) AND FEAT_16_LTE_0.43)
# Extracted Conditions: [('22', '0.14'), ('26', '16.29'), ('22', '0.15'), ('16', '0.43')]
# Matching Features: ['worst perimeter', 'worst concavity', 'worst perimeter', 'concavity error']
# Rule: FEAT_22_GT_0.14) AND FEAT_26_GT_16.29) AND FEAT_22_LTE_0.15) AND FEAT_16_GT_0.43)
# Extracted Conditions: [('22', '0.14'), ('26', '16.29'), ('22', '0.15'), ('16', '0.43')]
# Matching Features: ['worst perimeter', 'worst concavity', 'worst perimeter', 'concavity error']
# Rule: FEAT_22_GT_0.14) AND FEAT_26_GT_16.29) AND FEAT_22_GT_0.15)
# Extracted Conditions: [('22', '0.14'), ('26', '16.29'), ('22', '0.15')]
# Matching Features: ['worst perimeter', 'worst concavity', 'worst perimeter']
# Rule: FEAT_26_LTE_16.80) AND FEAT_22_LTE_0.14) AND FEAT_16_LTE_0.64) AND FEAT_25_LTE_102.10)
# Extracted Conditions: [('26', '16.80'), ('22', '0.14'), ('16', '0.64'), ('25', '102.10')]
# Matching Features: ['worst concavity', 'worst perimeter', 'concavity error', 'worst compactness']
# Rule: FEAT_26_LTE_16.80) AND FEAT_22_LTE_0.14) AND FEAT_16_LTE_0.64) AND FEAT_25_GT_102.10) AND FEAT_25_LTE_102.70)
# Extracted Conditions: [('26', '16.80'), ('22', '0.14'), ('16', '0.64'), ('25', '102.10'), ('25', '102.70')]
# Matching Features: ['worst concavity', 'worst perimeter', 'concavity error', 'worst compactness', 'worst compactness']
# Rule: FEAT_26_LTE_16.80) AND FEAT_22_LTE_0.14) AND FEAT_16_LTE_0.64) AND FEAT_25_GT_102.10) AND FEAT_25_GT_102.70)
# Extracted Conditions: [('26', '16.80'), ('22', '0.14'), ('16', '0.64'), ('25', '102.10'), ('25', '102.70')]
# Matching Features: ['worst concavity', 'worst perimeter', 'concavity error', 'worst compactness', 'worst compactness']
# Rule: FEAT_26_LTE_16.80) AND FEAT_22_LTE_0.14) AND FEAT_16_GT_0.64) AND FEAT_12_LTE_0.09)
# Extracted Conditions: [('26', '16.80'), ('22', '0.14'), ('16', '0.64'), ('12', '0.09')]
# Matching Features: ['worst concavity', 'worst perimeter', 'concavity error', 'perimeter error']
# Rule: FEAT_26_LTE_16.80) AND FEAT_22_LTE_0.14) AND FEAT_16_GT_0.64) AND FEAT_12_GT_0.09) AND FEAT_6_LTE_0.07)
# Extracted Conditions: [('26', '16.80'), ('22', '0.14'), ('16', '0.64'), ('12', '0.09'), ('6', '0.07')]
# Matching Features: ['worst concavity', 'worst perimeter', 'concavity error', 'perimeter error', 'mean concavity']
# Rule: FEAT_26_LTE_16.80) AND FEAT_22_LTE_0.14) AND FEAT_16_GT_0.64) AND FEAT_12_GT_0.09) AND FEAT_6_GT_0.07)
# Extracted Conditions: [('26', '16.80'), ('22', '0.14'), ('16', '0.64'), ('12', '0.09'), ('6', '0.07')]
# Matching Features: ['worst concavity', 'worst perimeter', 'concavity error', 'perimeter error', 'mean concavity']
# Rule: FEAT_26_LTE_16.80) AND FEAT_22_GT_0.14) AND FEAT_12_LTE_0.12) AND FEAT_29_LTE_27.22) AND FEAT_21_LTE_0.24)
# Extracted Conditions: [('26', '16.80'), ('22', '0.14'), ('12', '0.12'), ('29', '27.22'), ('21', '0.24')]
# Matching Features: ['worst concavity', 'worst perimeter', 'perimeter error', 'worst fractal dimension', 'worst texture']
# Rule: FEAT_26_LTE_16.80) AND FEAT_22_GT_0.14) AND FEAT_12_LTE_0.12) AND FEAT_29_LTE_27.22) AND FEAT_21_GT_0.24) AND FEAT_12_LTE_0.11) AND FEAT_26_LTE_16.41)
# Extracted Conditions: [('26', '16.80'), ('22', '0.14'), ('12', '0.12'), ('29', '27.22'), ('21', '0.24'), ('12', '0.11'), ('26', '16.41')]
# Matching Features: ['worst concavity', 'worst perimeter', 'perimeter error', 'worst fractal dimension', 'worst texture', 'perimeter error', 'worst concavity']
# Rule: FEAT_26_LTE_16.80) AND FEAT_22_GT_0.14) AND FEAT_12_LTE_0.12) AND FEAT_29_LTE_27.22) AND FEAT_21_GT_0.24) AND FEAT_12_LTE_0.11) AND FEAT_26_GT_16.41) AND FEAT_19_LTE_0.70)
# Extracted Conditions: [('26', '16.80'), ('22', '0.14'), ('12', '0.12'), ('29', '27.22'), ('21', '0.24'), ('12', '0.11'), ('26', '16.41'), ('19', '0.70')]
# Matching Features: ['worst concavity', 'worst perimeter', 'perimeter error', 'worst fractal dimension', 'worst texture', 'perimeter error', 'worst concavity', 'fractal dimension error']
# Rule: FEAT_26_LTE_16.80) AND FEAT_22_GT_0.14) AND FEAT_12_LTE_0.12) AND FEAT_29_LTE_27.22) AND FEAT_21_GT_0.24) AND FEAT_12_LTE_0.11) AND FEAT_26_GT_16.41) AND FEAT_19_GT_0.70)
# Extracted Conditions: [('26', '16.80'), ('22', '0.14'), ('12', '0.12'), ('29', '27.22'), ('21', '0.24'), ('12', '0.11'), ('26', '16.41'), ('19', '0.70')]
# Matching Features: ['worst concavity', 'worst perimeter', 'perimeter error', 'worst fractal dimension', 'worst texture', 'perimeter error', 'worst concavity', 'fractal dimension error']
# Rule: FEAT_26_LTE_16.80) AND FEAT_22_GT_0.14) AND FEAT_12_LTE_0.12) AND FEAT_29_LTE_27.22) AND FEAT_21_GT_0.24) AND FEAT_12_GT_0.11) AND FEAT_29_LTE_20.20)
# Extracted Conditions: [('26', '16.80'), ('22', '0.14'), ('12', '0.12'), ('29', '27.22'), ('21', '0.24'), ('12', '0.11'), ('29', '20.20')]
# Matching Features: ['worst concavity', 'worst perimeter', 'perimeter error', 'worst fractal dimension', 'worst texture', 'perimeter error', 'worst fractal dimension']
# Rule: FEAT_26_LTE_16.80) AND FEAT_22_GT_0.14) AND FEAT_12_LTE_0.12) AND FEAT_29_LTE_27.22) AND FEAT_21_GT_0.24) AND FEAT_12_GT_0.11) AND FEAT_29_GT_20.20)
# Extracted Conditions: [('26', '16.80'), ('22', '0.14'), ('12', '0.12'), ('29', '27.22'), ('21', '0.24'), ('12', '0.11'), ('29', '20.20')]
# Matching Features: ['worst concavity', 'worst perimeter', 'perimeter error', 'worst fractal dimension', 'worst texture', 'perimeter error', 'worst fractal dimension']
# Rule: FEAT_26_LTE_16.80) AND FEAT_22_GT_0.14) AND FEAT_12_LTE_0.12) AND FEAT_29_GT_27.22)
# Extracted Conditions: [('26', '16.80'), ('22', '0.14'), ('12', '0.12'), ('29', '27.22')]
# Matching Features: ['worst concavity', 'worst perimeter', 'perimeter error', 'worst fractal dimension']
# Rule: FEAT_26_LTE_16.80) AND FEAT_22_GT_0.14) AND FEAT_12_GT_0.12)
# Extracted Conditions: [('26', '16.80'), ('22', '0.14'), ('12', '0.12')]
# Matching Features: ['worst concavity', 'worst perimeter', 'perimeter error']
# Rule: FEAT_26_GT_16.80) AND FEAT_14_LTE_15.82) AND FEAT_9_LTE_0.06)
# Extracted Conditions: [('26', '16.80'), ('14', '15.82'), ('9', '0.06')]
# Matching Features: ['worst concavity', 'smoothness error', 'mean fractal dimension']
# Rule: FEAT_26_GT_16.80) AND FEAT_14_LTE_15.82) AND FEAT_9_GT_0.06)
# Extracted Conditions: [('26', '16.80'), ('14', '15.82'), ('9', '0.06')]
# Matching Features: ['worst concavity', 'smoothness error', 'mean fractal dimension']
# Rule: FEAT_26_GT_16.80) AND FEAT_14_GT_15.82) AND FEAT_13_LTE_0.15) AND FEAT_13_LTE_0.15)
# Extracted Conditions: [('26', '16.80'), ('14', '15.82'), ('13', '0.15'), ('13', '0.15')]
# Matching Features: ['worst concavity', 'smoothness error', 'area error', 'area error']
# Rule: FEAT_26_GT_16.80) AND FEAT_14_GT_15.82) AND FEAT_13_LTE_0.15) AND FEAT_13_GT_0.15)
# Extracted Conditions: [('26', '16.80'), ('14', '15.82'), ('13', '0.15'), ('13', '0.15')]
# Matching Features: ['worst concavity', 'smoothness error', 'area error', 'area error']
# Rule: FEAT_26_GT_16.80) AND FEAT_14_GT_15.82) AND FEAT_13_GT_0.15)
# Extracted Conditions: [('26', '16.80'), ('14', '15.82'), ('13', '0.15')]
# Matching Features: ['worst concavity', 'smoothness error', 'area error']
# Rule: FEAT_0_LTE_34.85) AND FEAT_25_LTE_104.10) AND FEAT_28_LTE_0.50) AND FEAT_5_LTE_532.60) AND FEAT_22_LTE_0.14)
# Extracted Conditions: [('0', '34.85'), ('25', '104.10'), ('28', '0.50'), ('5', '532.60'), ('22', '0.14')]
# Matching Features: ['mean radius', 'worst compactness', 'worst symmetry', 'mean compactness', 'worst perimeter']
# Rule: FEAT_0_LTE_34.85) AND FEAT_25_LTE_104.10) AND FEAT_28_LTE_0.50) AND FEAT_5_LTE_532.60) AND FEAT_22_GT_0.14) AND FEAT_3_LTE_0.04)
# Extracted Conditions: [('0', '34.85'), ('25', '104.10'), ('28', '0.50'), ('5', '532.60'), ('22', '0.14'), ('3', '0.04')]
# Matching Features: ['mean radius', 'worst compactness', 'worst symmetry', 'mean compactness', 'worst perimeter', 'mean area']
# Rule: FEAT_0_LTE_34.85) AND FEAT_25_LTE_104.10) AND FEAT_28_LTE_0.50) AND FEAT_5_LTE_532.60) AND FEAT_22_GT_0.14) AND FEAT_3_GT_0.04)
# Extracted Conditions: [('0', '34.85'), ('25', '104.10'), ('28', '0.50'), ('5', '532.60'), ('22', '0.14'), ('3', '0.04')]
# Matching Features: ['mean radius', 'worst compactness', 'worst symmetry', 'mean compactness', 'worst perimeter', 'mean area']
# Rule: FEAT_0_LTE_34.85) AND FEAT_25_LTE_104.10) AND FEAT_28_LTE_0.50) AND FEAT_5_GT_532.60) AND FEAT_24_LTE_0.10) AND FEAT_20_LTE_785.75) AND FEAT_0_LTE_32.88)
# Extracted Conditions: [('0', '34.85'), ('25', '104.10'), ('28', '0.50'), ('5', '532.60'), ('24', '0.10'), ('20', '785.75'), ('0', '32.88')]
# Matching Features: ['mean radius', 'worst compactness', 'worst symmetry', 'mean compactness', 'worst smoothness', 'worst radius', 'mean radius']
# Rule: FEAT_0_LTE_34.85) AND FEAT_25_LTE_104.10) AND FEAT_28_LTE_0.50) AND FEAT_5_GT_532.60) AND FEAT_24_LTE_0.10) AND FEAT_20_LTE_785.75) AND FEAT_0_GT_32.88)
# Extracted Conditions: [('0', '34.85'), ('25', '104.10'), ('28', '0.50'), ('5', '532.60'), ('24', '0.10'), ('20', '785.75'), ('0', '32.88')]
# Matching Features: ['mean radius', 'worst compactness', 'worst symmetry', 'mean compactness', 'worst smoothness', 'worst radius', 'mean radius']
# Rule: FEAT_0_LTE_34.85) AND FEAT_25_LTE_104.10) AND FEAT_28_LTE_0.50) AND FEAT_5_GT_532.60) AND FEAT_24_LTE_0.10) AND FEAT_20_GT_785.75) AND FEAT_20_LTE_795.80)
# Extracted Conditions: [('0', '34.85'), ('25', '104.10'), ('28', '0.50'), ('5', '532.60'), ('24', '0.10'), ('20', '785.75'), ('20', '795.80')]
# Matching Features: ['mean radius', 'worst compactness', 'worst symmetry', 'mean compactness', 'worst smoothness', 'worst radius', 'worst radius']
# Rule: FEAT_0_LTE_34.85) AND FEAT_25_LTE_104.10) AND FEAT_28_LTE_0.50) AND FEAT_5_GT_532.60) AND FEAT_24_LTE_0.10) AND FEAT_20_GT_785.75) AND FEAT_20_GT_795.80)
# Extracted Conditions: [('0', '34.85'), ('25', '104.10'), ('28', '0.50'), ('5', '532.60'), ('24', '0.10'), ('20', '785.75'), ('20', '795.80')]
# Matching Features: ['mean radius', 'worst compactness', 'worst symmetry', 'mean compactness', 'worst smoothness', 'worst radius', 'worst radius']
# Rule: FEAT_0_LTE_34.85) AND FEAT_25_LTE_104.10) AND FEAT_28_LTE_0.50) AND FEAT_5_GT_532.60) AND FEAT_24_GT_0.10)
# Extracted Conditions: [('0', '34.85'), ('25', '104.10'), ('28', '0.50'), ('5', '532.60'), ('24', '0.10')]
# Matching Features: ['mean radius', 'worst compactness', 'worst symmetry', 'mean compactness', 'worst smoothness']
# Rule: FEAT_0_LTE_34.85) AND FEAT_25_LTE_104.10) AND FEAT_28_GT_0.50)
# Extracted Conditions: [('0', '34.85'), ('25', '104.10'), ('28', '0.50')]
# Matching Features: ['mean radius', 'worst compactness', 'worst symmetry']
# Rule: FEAT_0_LTE_34.85) AND FEAT_25_GT_104.10) AND FEAT_22_LTE_0.14) AND FEAT_14_LTE_22.26) AND FEAT_18_LTE_0.01)
# Extracted Conditions: [('0', '34.85'), ('25', '104.10'), ('22', '0.14'), ('14', '22.26'), ('18', '0.01')]
# Matching Features: ['mean radius', 'worst compactness', 'worst perimeter', 'smoothness error', 'symmetry error']
# Rule: FEAT_0_LTE_34.85) AND FEAT_25_GT_104.10) AND FEAT_22_LTE_0.14) AND FEAT_14_LTE_22.26) AND FEAT_18_GT_0.01)
# Extracted Conditions: [('0', '34.85'), ('25', '104.10'), ('22', '0.14'), ('14', '22.26'), ('18', '0.01')]
# Matching Features: ['mean radius', 'worst compactness', 'worst perimeter', 'smoothness error', 'symmetry error']
# Rule: FEAT_0_LTE_34.85) AND FEAT_25_GT_104.10) AND FEAT_22_LTE_0.14) AND FEAT_14_GT_22.26)
# Extracted Conditions: [('0', '34.85'), ('25', '104.10'), ('22', '0.14'), ('14', '22.26')]
# Matching Features: ['mean radius', 'worst compactness', 'worst perimeter', 'smoothness error']
# Rule: FEAT_0_LTE_34.85) AND FEAT_25_GT_104.10) AND FEAT_22_GT_0.14) AND FEAT_10_LTE_85.10)
# Extracted Conditions: [('0', '34.85'), ('25', '104.10'), ('22', '0.14'), ('10', '85.10')]
# Matching Features: ['mean radius', 'worst compactness', 'worst perimeter', 'radius error']
# Rule: FEAT_0_LTE_34.85) AND FEAT_25_GT_104.10) AND FEAT_22_GT_0.14) AND FEAT_10_GT_85.10)
# Extracted Conditions: [('0', '34.85'), ('25', '104.10'), ('22', '0.14'), ('10', '85.10')]
# Matching Features: ['mean radius', 'worst compactness', 'worst perimeter', 'radius error']
# Rule: FEAT_0_GT_34.85) AND FEAT_7_LTE_0.05) AND FEAT_15_LTE_4.12) AND FEAT_27_LTE_0.14)
# Extracted Conditions: [('0', '34.85'), ('7', '0.05'), ('15', '4.12'), ('27', '0.14')]
# Matching Features: ['mean radius', 'mean concave points', 'compactness error', 'worst concave points']
# Rule: FEAT_0_GT_34.85) AND FEAT_7_LTE_0.05) AND FEAT_15_LTE_4.12) AND FEAT_27_GT_0.14)
# Extracted Conditions: [('0', '34.85'), ('7', '0.05'), ('15', '4.12'), ('27', '0.14')]
# Matching Features: ['mean radius', 'mean concave points', 'compactness error', 'worst concave points']
# Rule: FEAT_0_GT_34.85) AND FEAT_7_LTE_0.05) AND FEAT_15_GT_4.12) AND FEAT_2_LTE_0.01)
# Extracted Conditions: [('0', '34.85'), ('7', '0.05'), ('15', '4.12'), ('2', '0.01')]
# Matching Features: ['mean radius', 'mean concave points', 'compactness error', 'mean perimeter']
# Rule: FEAT_0_GT_34.85) AND FEAT_7_LTE_0.05) AND FEAT_15_GT_4.12) AND FEAT_2_GT_0.01)
# Extracted Conditions: [('0', '34.85'), ('7', '0.05'), ('15', '4.12'), ('2', '0.01')]
# Matching Features: ['mean radius', 'mean concave points', 'compactness error', 'mean perimeter']
# Rule: FEAT_0_GT_34.85) AND FEAT_7_GT_0.05) AND FEAT_29_LTE_19.03) AND FEAT_20_LTE_952.80)
# Extracted Conditions: [('0', '34.85'), ('7', '0.05'), ('29', '19.03'), ('20', '952.80')]
# Matching Features: ['mean radius', 'mean concave points', 'worst fractal dimension', 'worst radius']
# Rule: FEAT_0_GT_34.85) AND FEAT_7_GT_0.05) AND FEAT_29_LTE_19.03) AND FEAT_20_GT_952.80)
# Extracted Conditions: [('0', '34.85'), ('7', '0.05'), ('29', '19.03'), ('20', '952.80')]
# Matching Features: ['mean radius', 'mean concave points', 'worst fractal dimension', 'worst radius']
# Rule: FEAT_0_GT_34.85) AND FEAT_7_GT_0.05) AND FEAT_29_GT_19.03)
# Extracted Conditions: [('0', '34.85'), ('7', '0.05'), ('29', '19.03')]
# Matching Features: ['mean radius', 'mean concave points', 'worst fractal dimension']
# Rule: FEAT_21_LTE_0.28) AND FEAT_10_LTE_97.92) AND FEAT_26_LTE_16.88) AND FEAT_8_LTE_0.14) AND FEAT_28_LTE_0.20) AND FEAT_13_LTE_0.16)
# Extracted Conditions: [('21', '0.28'), ('10', '97.92'), ('26', '16.88'), ('8', '0.14'), ('28', '0.20'), ('13', '0.16')]
# Matching Features: ['worst texture', 'radius error', 'worst concavity', 'mean symmetry', 'worst symmetry', 'area error']
# Rule: FEAT_21_LTE_0.28) AND FEAT_10_LTE_97.92) AND FEAT_26_LTE_16.88) AND FEAT_8_LTE_0.14) AND FEAT_28_LTE_0.20) AND FEAT_13_GT_0.16) AND FEAT_13_LTE_0.16)
# Extracted Conditions: [('21', '0.28'), ('10', '97.92'), ('26', '16.88'), ('8', '0.14'), ('28', '0.20'), ('13', '0.16'), ('13', '0.16')]
# Matching Features: ['worst texture', 'radius error', 'worst concavity', 'mean symmetry', 'worst symmetry', 'area error', 'area error']
# Rule: FEAT_21_LTE_0.28) AND FEAT_10_LTE_97.92) AND FEAT_26_LTE_16.88) AND FEAT_8_LTE_0.14) AND FEAT_28_LTE_0.20) AND FEAT_13_GT_0.16) AND FEAT_13_GT_0.16)
# Extracted Conditions: [('21', '0.28'), ('10', '97.92'), ('26', '16.88'), ('8', '0.14'), ('28', '0.20'), ('13', '0.16'), ('13', '0.16')]
# Matching Features: ['worst texture', 'radius error', 'worst concavity', 'mean symmetry', 'worst symmetry', 'area error', 'area error']
# Rule: FEAT_21_LTE_0.28) AND FEAT_10_LTE_97.92) AND FEAT_26_LTE_16.88) AND FEAT_8_LTE_0.14) AND FEAT_28_GT_0.20) AND FEAT_19_LTE_0.83) AND FEAT_17_LTE_0.00) AND FEAT_1_LTE_0.01)
# Extracted Conditions: [('21', '0.28'), ('10', '97.92'), ('26', '16.88'), ('8', '0.14'), ('28', '0.20'), ('19', '0.83'), ('17', '0.00'), ('1', '0.01')]
# Matching Features: ['worst texture', 'radius error', 'worst concavity', 'mean symmetry', 'worst symmetry', 'fractal dimension error', 'concave points error', 'mean texture']
# Rule: FEAT_21_LTE_0.28) AND FEAT_10_LTE_97.92) AND FEAT_26_LTE_16.88) AND FEAT_8_LTE_0.14) AND FEAT_28_GT_0.20) AND FEAT_19_LTE_0.83) AND FEAT_17_LTE_0.00) AND FEAT_1_GT_0.01)
# Extracted Conditions: [('21', '0.28'), ('10', '97.92'), ('26', '16.88'), ('8', '0.14'), ('28', '0.20'), ('19', '0.83'), ('17', '0.00'), ('1', '0.01')]
# Matching Features: ['worst texture', 'radius error', 'worst concavity', 'mean symmetry', 'worst symmetry', 'fractal dimension error', 'concave points error', 'mean texture']
# Rule: FEAT_21_LTE_0.28) AND FEAT_10_LTE_97.92) AND FEAT_26_LTE_16.88) AND FEAT_8_LTE_0.14) AND FEAT_28_GT_0.20) AND FEAT_19_LTE_0.83) AND FEAT_17_GT_0.00)
# Extracted Conditions: [('21', '0.28'), ('10', '97.92'), ('26', '16.88'), ('8', '0.14'), ('28', '0.20'), ('19', '0.83'), ('17', '0.00')]
# Matching Features: ['worst texture', 'radius error', 'worst concavity', 'mean symmetry', 'worst symmetry', 'fractal dimension error', 'concave points error']
# Rule: FEAT_21_LTE_0.28) AND FEAT_10_LTE_97.92) AND FEAT_26_LTE_16.88) AND FEAT_8_LTE_0.14) AND FEAT_28_GT_0.20) AND FEAT_19_GT_0.83) AND FEAT_22_LTE_0.09)
# Extracted Conditions: [('21', '0.28'), ('10', '97.92'), ('26', '16.88'), ('8', '0.14'), ('28', '0.20'), ('19', '0.83'), ('22', '0.09')]
# Matching Features: ['worst texture', 'radius error', 'worst concavity', 'mean symmetry', 'worst symmetry', 'fractal dimension error', 'worst perimeter']
# Rule: FEAT_21_LTE_0.28) AND FEAT_10_LTE_97.92) AND FEAT_26_LTE_16.88) AND FEAT_8_LTE_0.14) AND FEAT_28_GT_0.20) AND FEAT_19_GT_0.83) AND FEAT_22_GT_0.09) AND FEAT_29_LTE_33.27)
# Extracted Conditions: [('21', '0.28'), ('10', '97.92'), ('26', '16.88'), ('8', '0.14'), ('28', '0.20'), ('19', '0.83'), ('22', '0.09'), ('29', '33.27')]
# Matching Features: ['worst texture', 'radius error', 'worst concavity', 'mean symmetry', 'worst symmetry', 'fractal dimension error', 'worst perimeter', 'worst fractal dimension']
# Rule: FEAT_21_LTE_0.28) AND FEAT_10_LTE_97.92) AND FEAT_26_LTE_16.88) AND FEAT_8_LTE_0.14) AND FEAT_28_GT_0.20) AND FEAT_19_GT_0.83) AND FEAT_22_GT_0.09) AND FEAT_29_GT_33.27) AND FEAT_27_LTE_0.14)
# Extracted Conditions: [('21', '0.28'), ('10', '97.92'), ('26', '16.88'), ('8', '0.14'), ('28', '0.20'), ('19', '0.83'), ('22', '0.09'), ('29', '33.27'), ('27', '0.14')]
# Matching Features: ['worst texture', 'radius error', 'worst concavity', 'mean symmetry', 'worst symmetry', 'fractal dimension error', 'worst perimeter', 'worst fractal dimension', 'worst concave points']
# Rule: FEAT_21_LTE_0.28) AND FEAT_10_LTE_97.92) AND FEAT_26_LTE_16.88) AND FEAT_8_LTE_0.14) AND FEAT_28_GT_0.20) AND FEAT_19_GT_0.83) AND FEAT_22_GT_0.09) AND FEAT_29_GT_33.27) AND FEAT_27_GT_0.14)
# Extracted Conditions: [('21', '0.28'), ('10', '97.92'), ('26', '16.88'), ('8', '0.14'), ('28', '0.20'), ('19', '0.83'), ('22', '0.09'), ('29', '33.27'), ('27', '0.14')]
# Matching Features: ['worst texture', 'radius error', 'worst concavity', 'mean symmetry', 'worst symmetry', 'fractal dimension error', 'worst perimeter', 'worst fractal dimension', 'worst concave points']
# Rule: FEAT_21_LTE_0.28) AND FEAT_10_LTE_97.92) AND FEAT_26_LTE_16.88) AND FEAT_8_GT_0.14)
# Extracted Conditions: [('21', '0.28'), ('10', '97.92'), ('26', '16.88'), ('8', '0.14')]
# Matching Features: ['worst texture', 'radius error', 'worst concavity', 'mean symmetry']
# Rule: FEAT_21_LTE_0.28) AND FEAT_10_LTE_97.92) AND FEAT_26_GT_16.88)
# Extracted Conditions: [('21', '0.28'), ('10', '97.92'), ('26', '16.88')]
# Matching Features: ['worst texture', 'radius error', 'worst concavity']
# Rule: FEAT_21_LTE_0.28) AND FEAT_10_GT_97.92) AND FEAT_29_LTE_21.14) AND FEAT_23_LTE_0.22)
# Extracted Conditions: [('21', '0.28'), ('10', '97.92'), ('29', '21.14'), ('23', '0.22')]
# Matching Features: ['worst texture', 'radius error', 'worst fractal dimension', 'worst area']
# Rule: FEAT_21_LTE_0.28) AND FEAT_10_GT_97.92) AND FEAT_29_LTE_21.14) AND FEAT_23_GT_0.22)
# Extracted Conditions: [('21', '0.28'), ('10', '97.92'), ('29', '21.14'), ('23', '0.22')]
# Matching Features: ['worst texture', 'radius error', 'worst fractal dimension', 'worst area']
# Rule: FEAT_21_LTE_0.28) AND FEAT_10_GT_97.92) AND FEAT_29_GT_21.14)
# Extracted Conditions: [('21', '0.28'), ('10', '97.92'), ('29', '21.14')]
# Matching Features: ['worst texture', 'radius error', 'worst fractal dimension']
# Rule: FEAT_21_GT_0.28) AND FEAT_7_LTE_0.05) AND FEAT_26_LTE_16.82)
# Extracted Conditions: [('21', '0.28'), ('7', '0.05'), ('26', '16.82')]
# Matching Features: ['worst texture', 'mean concave points', 'worst concavity']
# Rule: FEAT_21_GT_0.28) AND FEAT_7_LTE_0.05) AND FEAT_26_GT_16.82)
# Extracted Conditions: [('21', '0.28'), ('7', '0.05'), ('26', '16.82')]
# Matching Features: ['worst texture', 'mean concave points', 'worst concavity']
# Rule: FEAT_21_GT_0.28) AND FEAT_7_GT_0.05) AND FEAT_26_LTE_15.39) AND FEAT_14_LTE_20.30)
# Extracted Conditions: [('21', '0.28'), ('7', '0.05'), ('26', '15.39'), ('14', '20.30')]
# Matching Features: ['worst texture', 'mean concave points', 'worst concavity', 'smoothness error']
# Rule: FEAT_21_GT_0.28) AND FEAT_7_GT_0.05) AND FEAT_26_LTE_15.39) AND FEAT_14_GT_20.30)
# Extracted Conditions: [('21', '0.28'), ('7', '0.05'), ('26', '15.39'), ('14', '20.30')]
# Matching Features: ['worst texture', 'mean concave points', 'worst concavity', 'smoothness error']
# Rule: FEAT_21_GT_0.28) AND FEAT_7_GT_0.05) AND FEAT_26_GT_15.39) AND FEAT_0_LTE_16.20)
# Extracted Conditions: [('21', '0.28'), ('7', '0.05'), ('26', '15.39'), ('0', '16.20')]
# Matching Features: ['worst texture', 'mean concave points', 'worst concavity', 'mean radius']
# Rule: FEAT_21_GT_0.28) AND FEAT_7_GT_0.05) AND FEAT_26_GT_15.39) AND FEAT_0_GT_16.20) AND FEAT_23_LTE_0.26) AND FEAT_3_LTE_0.03)
# Extracted Conditions: [('21', '0.28'), ('7', '0.05'), ('26', '15.39'), ('0', '16.20'), ('23', '0.26'), ('3', '0.03')]
# Matching Features: ['worst texture', 'mean concave points', 'worst concavity', 'mean radius', 'worst area', 'mean area']
# Rule: FEAT_21_GT_0.28) AND FEAT_7_GT_0.05) AND FEAT_26_GT_15.39) AND FEAT_0_GT_16.20) AND FEAT_23_LTE_0.26) AND FEAT_3_GT_0.03)
# Extracted Conditions: [('21', '0.28'), ('7', '0.05'), ('26', '15.39'), ('0', '16.20'), ('23', '0.26'), ('3', '0.03')]
# Matching Features: ['worst texture', 'mean concave points', 'worst concavity', 'mean radius', 'worst area', 'mean area']
# Rule: FEAT_21_GT_0.28) AND FEAT_7_GT_0.05) AND FEAT_26_GT_15.39) AND FEAT_0_GT_16.20) AND FEAT_23_GT_0.26) AND FEAT_1_LTE_0.05)
# Extracted Conditions: [('21', '0.28'), ('7', '0.05'), ('26', '15.39'), ('0', '16.20'), ('23', '0.26'), ('1', '0.05')]
# Matching Features: ['worst texture', 'mean concave points', 'worst concavity', 'mean radius', 'worst area', 'mean texture']
# Rule: FEAT_21_GT_0.28) AND FEAT_7_GT_0.05) AND FEAT_26_GT_15.39) AND FEAT_0_GT_16.20) AND FEAT_23_GT_0.26) AND FEAT_1_GT_0.05) AND FEAT_7_LTE_0.07)
# Extracted Conditions: [('21', '0.28'), ('7', '0.05'), ('26', '15.39'), ('0', '16.20'), ('23', '0.26'), ('1', '0.05'), ('7', '0.07')]
# Matching Features: ['worst texture', 'mean concave points', 'worst concavity', 'mean radius', 'worst area', 'mean texture', 'mean concave points']
# Rule: FEAT_21_GT_0.28) AND FEAT_7_GT_0.05) AND FEAT_26_GT_15.39) AND FEAT_0_GT_16.20) AND FEAT_23_GT_0.26) AND FEAT_1_GT_0.05) AND FEAT_7_GT_0.07)
# Extracted Conditions: [('21', '0.28'), ('7', '0.05'), ('26', '15.39'), ('0', '16.20'), ('23', '0.26'), ('1', '0.05'), ('7', '0.07')]
# Matching Features: ['worst texture', 'mean concave points', 'worst concavity', 'mean radius', 'worst area', 'mean texture', 'mean concave points']
# Rule: FEAT_25_LTE_105.15) AND FEAT_28_LTE_0.41) AND FEAT_22_LTE_0.13)
# Extracted Conditions: [('25', '105.15'), ('28', '0.41'), ('22', '0.13')]
# Matching Features: ['worst compactness', 'worst symmetry', 'worst perimeter']
# Rule: FEAT_25_LTE_105.15) AND FEAT_28_LTE_0.41) AND FEAT_22_GT_0.13) AND FEAT_3_LTE_0.06) AND FEAT_0_LTE_18.47)
# Extracted Conditions: [('25', '105.15'), ('28', '0.41'), ('22', '0.13'), ('3', '0.06'), ('0', '18.47')]
# Matching Features: ['worst compactness', 'worst symmetry', 'worst perimeter', 'mean area', 'mean radius']
# Rule: FEAT_25_LTE_105.15) AND FEAT_28_LTE_0.41) AND FEAT_22_GT_0.13) AND FEAT_3_LTE_0.06) AND FEAT_0_GT_18.47)
# Extracted Conditions: [('25', '105.15'), ('28', '0.41'), ('22', '0.13'), ('3', '0.06'), ('0', '18.47')]
# Matching Features: ['worst compactness', 'worst symmetry', 'worst perimeter', 'mean area', 'mean radius']
# Rule: FEAT_25_LTE_105.15) AND FEAT_28_LTE_0.41) AND FEAT_22_GT_0.13) AND FEAT_3_GT_0.06)
# Extracted Conditions: [('25', '105.15'), ('28', '0.41'), ('22', '0.13'), ('3', '0.06')]
# Matching Features: ['worst compactness', 'worst symmetry', 'worst perimeter', 'mean area']
# Rule: FEAT_25_LTE_105.15) AND FEAT_28_GT_0.41)
# Extracted Conditions: [('25', '105.15'), ('28', '0.41')]
# Matching Features: ['worst compactness', 'worst symmetry']
# Rule: FEAT_25_GT_105.15) AND FEAT_7_LTE_0.05) AND FEAT_20_LTE_957.45) AND FEAT_19_LTE_0.98)
# Extracted Conditions: [('25', '105.15'), ('7', '0.05'), ('20', '957.45'), ('19', '0.98')]
# Matching Features: ['worst compactness', 'mean concave points', 'worst radius', 'fractal dimension error']
# Rule: FEAT_25_GT_105.15) AND FEAT_7_LTE_0.05) AND FEAT_20_LTE_957.45) AND FEAT_19_GT_0.98) AND FEAT_29_LTE_33.78)
# Extracted Conditions: [('25', '105.15'), ('7', '0.05'), ('20', '957.45'), ('19', '0.98'), ('29', '33.78')]
# Matching Features: ['worst compactness', 'mean concave points', 'worst radius', 'fractal dimension error', 'worst fractal dimension']
# Rule: FEAT_25_GT_105.15) AND FEAT_7_LTE_0.05) AND FEAT_20_LTE_957.45) AND FEAT_19_GT_0.98) AND FEAT_29_GT_33.78)
# Extracted Conditions: [('25', '105.15'), ('7', '0.05'), ('20', '957.45'), ('19', '0.98'), ('29', '33.78')]
# Matching Features: ['worst compactness', 'mean concave points', 'worst radius', 'fractal dimension error', 'worst fractal dimension']
# Rule: FEAT_25_GT_105.15) AND FEAT_7_LTE_0.05) AND FEAT_20_GT_957.45) AND FEAT_11_LTE_16.77) AND FEAT_12_LTE_0.09)
# Extracted Conditions: [('25', '105.15'), ('7', '0.05'), ('20', '957.45'), ('11', '16.77'), ('12', '0.09')]
# Matching Features: ['worst compactness', 'mean concave points', 'worst radius', 'texture error', 'perimeter error']
# Rule: FEAT_25_GT_105.15) AND FEAT_7_LTE_0.05) AND FEAT_20_GT_957.45) AND FEAT_11_LTE_16.77) AND FEAT_12_GT_0.09)
# Extracted Conditions: [('25', '105.15'), ('7', '0.05'), ('20', '957.45'), ('11', '16.77'), ('12', '0.09')]
# Matching Features: ['worst compactness', 'mean concave points', 'worst radius', 'texture error', 'perimeter error']
# Rule: FEAT_25_GT_105.15) AND FEAT_7_LTE_0.05) AND FEAT_20_GT_957.45) AND FEAT_11_GT_16.77) AND FEAT_8_LTE_0.04)
# Extracted Conditions: [('25', '105.15'), ('7', '0.05'), ('20', '957.45'), ('11', '16.77'), ('8', '0.04')]
# Matching Features: ['worst compactness', 'mean concave points', 'worst radius', 'texture error', 'mean symmetry']
# Rule: FEAT_25_GT_105.15) AND FEAT_7_LTE_0.05) AND FEAT_20_GT_957.45) AND FEAT_11_GT_16.77) AND FEAT_8_GT_0.04)
# Extracted Conditions: [('25', '105.15'), ('7', '0.05'), ('20', '957.45'), ('11', '16.77'), ('8', '0.04')]
# Matching Features: ['worst compactness', 'mean concave points', 'worst radius', 'texture error', 'mean symmetry']
# Rule: FEAT_25_GT_105.15) AND FEAT_7_GT_0.05) AND FEAT_14_LTE_16.53) AND FEAT_11_LTE_15.88) AND FEAT_5_LTE_612.10)
# Extracted Conditions: [('25', '105.15'), ('7', '0.05'), ('14', '16.53'), ('11', '15.88'), ('5', '612.10')]
# Matching Features: ['worst compactness', 'mean concave points', 'smoothness error', 'texture error', 'mean compactness']
# Rule: FEAT_25_GT_105.15) AND FEAT_7_GT_0.05) AND FEAT_14_LTE_16.53) AND FEAT_11_LTE_15.88) AND FEAT_5_GT_612.10)
# Extracted Conditions: [('25', '105.15'), ('7', '0.05'), ('14', '16.53'), ('11', '15.88'), ('5', '612.10')]
# Matching Features: ['worst compactness', 'mean concave points', 'smoothness error', 'texture error', 'mean compactness']
# Rule: FEAT_25_GT_105.15) AND FEAT_7_GT_0.05) AND FEAT_14_LTE_16.53) AND FEAT_11_GT_15.88)
# Extracted Conditions: [('25', '105.15'), ('7', '0.05'), ('14', '16.53'), ('11', '15.88')]
# Matching Features: ['worst compactness', 'mean concave points', 'smoothness error', 'texture error']
# Rule: FEAT_25_GT_105.15) AND FEAT_7_GT_0.05) AND FEAT_14_GT_16.53)
# Extracted Conditions: [('25', '105.15'), ('7', '0.05'), ('14', '16.53')]
# Matching Features: ['worst compactness', 'mean concave points', 'smoothness error']
# Rule: FEAT_11_LTE_14.98) AND FEAT_23_LTE_0.36) AND FEAT_15_LTE_2.56)
# Extracted Conditions: [('11', '14.98'), ('23', '0.36'), ('15', '2.56')]
# Matching Features: ['texture error', 'worst area', 'compactness error']
# Rule: FEAT_11_LTE_14.98) AND FEAT_23_LTE_0.36) AND FEAT_15_GT_2.56) AND FEAT_17_LTE_0.01) AND FEAT_27_LTE_0.13) AND FEAT_0_LTE_45.93)
# ...
# Rule: FEAT_11_LTE_14.98) AND FEAT_23_LTE_0.36) AND FEAT_15_GT_2.56) AND FEAT_17_GT_0.01) AND FEAT_25_GT_105.05) AND FEAT_24_GT_0.08)
# Extracted Conditions: [('11', '14.98'), ('23', '0.36'), ('15', '2.56'), ('17', '0.01'), ('25', '105.05'), ('24', '0.08')]
# Matching Features: ['texture error', 'worst area', 'compactness error', 'concave points error', 'worst compactness', 'worst smoothness']
# Rule: FEAT_11_LTE_14.98) AND FEAT_23_GT_0.36) AND FEAT_20_LTE_493.45)
# Extracted Conditions: [('11', '14.98'), ('23', '0.36'), ('20', '493.45')]
# Matching Features: ['texture error', 'worst area', 'worst radius']
# Rule: FEAT_11_LTE_14.98) AND FEAT_23_GT_0.36) AND FEAT_20_GT_493.45) AND FEAT_29_LTE_25.94) AND FEAT_7_LTE_0.09)
# Extracted Conditions: [('11', '14.98'), ('23', '0.36'), ('20', '493.45'), ('29', '25.94'), ('7', '0.09')]
# Matching Features: ['texture error', 'worst area', 'worst radius', 'worst fractal dimension', 'mean concave points']
# Rule: FEAT_11_LTE_14.98) AND FEAT_23_GT_0.36) AND FEAT_20_GT_493.45) AND FEAT_29_LTE_25.94) AND FEAT_7_GT_0.09)
# Extracted Conditions: [('11', '14.98'), ('23', '0.36'), ('20', '493.45'), ('29', '25.94'), ('7', '0.09')]
# Matching Features: ['texture error', 'worst area', 'worst radius', 'worst fractal dimension', 'mean concave points']
# Rule: FEAT_11_LTE_14.98) AND FEAT_23_GT_0.36) AND FEAT_20_GT_493.45) AND FEAT_29_GT_25.94)
# Extracted Conditions: [('11', '14.98'), ('23', '0.36'), ('20', '493.45'), ('29', '25.94')]
# Matching Features: ['texture error', 'worst area', 'worst radius', 'worst fractal dimension']
# Rule: FEAT_11_GT_14.98) AND FEAT_23_LTE_0.22) AND FEAT_12_LTE_0.09) AND FEAT_3_LTE_0.03)
# Extracted Conditions: [('11', '14.98'), ('23', '0.22'), ('12', '0.09'), ('3', '0.03')]
# Matching Features: ['texture error', 'worst area', 'perimeter error', 'mean area']
# Rule: FEAT_11_GT_14.98) AND FEAT_23_LTE_0.22) AND FEAT_12_LTE_0.09) AND FEAT_3_GT_0.03)
# Extracted Conditions: [('11', '14.98'), ('23', '0.22'), ('12', '0.09'), ('3', '0.03')]
# Matching Features: ['texture error', 'worst area', 'perimeter error', 'mean area']
# Rule: FEAT_11_GT_14.98) AND FEAT_23_LTE_0.22) AND FEAT_12_GT_0.09)
# Extracted Conditions: [('11', '14.98'), ('23', '0.22'), ('12', '0.09')]
# Matching Features: ['texture error', 'worst area', 'perimeter error']
# Rule: FEAT_11_GT_14.98) AND FEAT_23_GT_0.22) AND FEAT_25_LTE_111.10)
# Extracted Conditions: [('11', '14.98'), ('23', '0.22'), ('25', '111.10')]
# Matching Features: ['texture error', 'worst area', 'worst compactness']
# Rule: FEAT_11_GT_14.98) AND FEAT_23_GT_0.22) AND FEAT_25_GT_111.10) AND FEAT_16_LTE_0.24) AND FEAT_22_LTE_0.13)
# Extracted Conditions: [('11', '14.98'), ('23', '0.22'), ('25', '111.10'), ('16', '0.24'), ('22', '0.13')]
# Matching Features: ['texture error', 'worst area', 'worst compactness', 'concavity error', 'worst perimeter']
# Rule: FEAT_11_GT_14.98) AND FEAT_23_GT_0.22) AND FEAT_25_GT_111.10) AND FEAT_16_LTE_0.24) AND FEAT_22_GT_0.13)
# Extracted Conditions: [('11', '14.98'), ('23', '0.22'), ('25', '111.10'), ('16', '0.24'), ('22', '0.13')]
# Matching Features: ['texture error', 'worst area', 'worst compactness', 'concavity error', 'worst perimeter']
# Rule: FEAT_11_GT_14.98) AND FEAT_23_GT_0.22) AND FEAT_25_GT_111.10) AND FEAT_16_GT_0.24)
# Extracted Conditions: [('11', '14.98'), ('23', '0.22'), ('25', '111.10'), ('16', '0.24')]
# Matching Features: ['texture error', 'worst area', 'worst compactness', 'concavity error']
# Rule: FEAT_10_LTE_98.76) AND FEAT_7_LTE_0.05) AND FEAT_26_LTE_16.83) AND FEAT_15_LTE_4.03) AND FEAT_14_LTE_22.45)
# Extracted Conditions: [('10', '98.76'), ('7', '0.05'), ('26', '16.83'), ('15', '4.03'), ('14', '22.45')]
# Matching Features: ['radius error', 'mean concave points', 'worst concavity', 'compactness error', 'smoothness error']
# Rule: FEAT_10_LTE_98.76) AND FEAT_7_LTE_0.05) AND FEAT_26_LTE_16.83) AND FEAT_15_LTE_4.03) AND FEAT_14_GT_22.45) AND FEAT_14_LTE_22.57)
# Extracted Conditions: [('10', '98.76'), ('7', '0.05'), ('26', '16.83'), ('15', '4.03'), ('14', '22.45'), ('14', '22.57')]
# Matching Features: ['radius error', 'mean concave points', 'worst concavity', 'compactness error', 'smoothness error', 'smoothness error']
# Rule: FEAT_10_LTE_98.76) AND FEAT_7_LTE_0.05) AND FEAT_26_LTE_16.83) AND FEAT_15_LTE_4.03) AND FEAT_14_GT_22.45) AND FEAT_14_GT_22.57)
# Extracted Conditions: [('10', '98.76'), ('7', '0.05'), ('26', '16.83'), ('15', '4.03'), ('14', '22.45'), ('14', '22.57')]
# Matching Features: ['radius error', 'mean concave points', 'worst concavity', 'compactness error', 'smoothness error', 'smoothness error']
# Rule: FEAT_10_LTE_98.76) AND FEAT_7_LTE_0.05) AND FEAT_26_LTE_16.83) AND FEAT_15_GT_4.03) AND FEAT_13_LTE_0.17)
# Extracted Conditions: [('10', '98.76'), ('7', '0.05'), ('26', '16.83'), ('15', '4.03'), ('13', '0.17')]
# Matching Features: ['radius error', 'mean concave points', 'worst concavity', 'compactness error', 'area error']
# Rule: FEAT_10_LTE_98.76) AND FEAT_7_LTE_0.05) AND FEAT_26_LTE_16.83) AND FEAT_15_GT_4.03) AND FEAT_13_GT_0.17)
# Extracted Conditions: [('10', '98.76'), ('7', '0.05'), ('26', '16.83'), ('15', '4.03'), ('13', '0.17')]
# Matching Features: ['radius error', 'mean concave points', 'worst concavity', 'compactness error', 'area error']
# Rule: FEAT_10_LTE_98.76) AND FEAT_7_LTE_0.05) AND FEAT_26_GT_16.83) AND FEAT_5_LTE_694.40) AND FEAT_12_LTE_0.09)
# Extracted Conditions: [('10', '98.76'), ('7', '0.05'), ('26', '16.83'), ('5', '694.40'), ('12', '0.09')]
# Matching Features: ['radius error', 'mean concave points', 'worst concavity', 'mean compactness', 'perimeter error']
# Rule: FEAT_10_LTE_98.76) AND FEAT_7_LTE_0.05) AND FEAT_26_GT_16.83) AND FEAT_5_LTE_694.40) AND FEAT_12_GT_0.09)
# Extracted Conditions: [('10', '98.76'), ('7', '0.05'), ('26', '16.83'), ('5', '694.40'), ('12', '0.09')]
# Matching Features: ['radius error', 'mean concave points', 'worst concavity', 'mean compactness', 'perimeter error']
# Rule: FEAT_10_LTE_98.76) AND FEAT_7_LTE_0.05) AND FEAT_26_GT_16.83) AND FEAT_5_GT_694.40)
# Extracted Conditions: [('10', '98.76'), ('7', '0.05'), ('26', '16.83'), ('5', '694.40')]
# Matching Features: ['radius error', 'mean concave points', 'worst concavity', 'mean compactness']
# Rule: FEAT_10_LTE_98.76) AND FEAT_7_GT_0.05) AND FEAT_21_LTE_0.37) AND FEAT_28_LTE_0.32) AND FEAT_14_LTE_21.53) AND FEAT_29_LTE_29.04) AND FEAT_24_LTE_0.10)
# Extracted Conditions: [('10', '98.76'), ('7', '0.05'), ('21', '0.37'), ('28', '0.32'), ('14', '21.53'), ('29', '29.04'), ('24', '0.10')]
# Matching Features: ['radius error', 'mean concave points', 'worst texture', 'worst symmetry', 'smoothness error', 'worst fractal dimension', 'worst smoothness']
# Rule: FEAT_10_LTE_98.76) AND FEAT_7_GT_0.05) AND FEAT_21_LTE_0.37) AND FEAT_28_LTE_0.32) AND FEAT_14_LTE_21.53) AND FEAT_29_LTE_29.04) AND FEAT_24_GT_0.10) AND FEAT_18_LTE_0.01)
# Extracted Conditions: [('10', '98.76'), ('7', '0.05'), ('21', '0.37'), ('28', '0.32'), ('14', '21.53'), ('29', '29.04'), ('24', '0.10'), ('18', '0.01')]
# Matching Features: ['radius error', 'mean concave points', 'worst texture', 'worst symmetry', 'smoothness error', 'worst fractal dimension', 'worst smoothness', 'symmetry error']
# Rule: FEAT_10_LTE_98.76) AND FEAT_7_GT_0.05) AND FEAT_21_LTE_0.37) AND FEAT_28_LTE_0.32) AND FEAT_14_LTE_21.53) AND FEAT_29_LTE_29.04) AND FEAT_24_GT_0.10) AND FEAT_18_GT_0.01)
# Extracted Conditions: [('10', '98.76'), ('7', '0.05'), ('21', '0.37'), ('28', '0.32'), ('14', '21.53'), ('29', '29.04'), ('24', '0.10'), ('18', '0.01')]
# Matching Features: ['radius error', 'mean concave points', 'worst texture', 'worst symmetry', 'smoothness error', 'worst fractal dimension', 'worst smoothness', 'symmetry error']
# Rule: FEAT_10_LTE_98.76) AND FEAT_7_GT_0.05) AND FEAT_21_LTE_0.37) AND FEAT_28_LTE_0.32) AND FEAT_14_LTE_21.53) AND FEAT_29_GT_29.04)
# Extracted Conditions: [('10', '98.76'), ('7', '0.05'), ('21', '0.37'), ('28', '0.32'), ('14', '21.53'), ('29', '29.04')]
# Matching Features: ['radius error', 'mean concave points', 'worst texture', 'worst symmetry', 'smoothness error', 'worst fractal dimension']
# Rule: FEAT_10_LTE_98.76) AND FEAT_7_GT_0.05) AND FEAT_21_LTE_0.37) AND FEAT_28_LTE_0.32) AND FEAT_14_GT_21.53)
# Extracted Conditions: [('10', '98.76'), ('7', '0.05'), ('21', '0.37'), ('28', '0.32'), ('14', '21.53')]
# Matching Features: ['radius error', 'mean concave points', 'worst texture', 'worst symmetry', 'smoothness error']
# Rule: FEAT_10_LTE_98.76) AND FEAT_7_GT_0.05) AND FEAT_21_LTE_0.37) AND FEAT_28_GT_0.32) AND FEAT_5_LTE_572.90)
# Extracted Conditions: [('10', '98.76'), ('7', '0.05'), ('21', '0.37'), ('28', '0.32'), ('5', '572.90')]
# Matching Features: ['radius error', 'mean concave points', 'worst texture', 'worst symmetry', 'mean compactness']
# Rule: FEAT_10_LTE_98.76) AND FEAT_7_GT_0.05) AND FEAT_21_LTE_0.37) AND FEAT_28_GT_0.32) AND FEAT_5_GT_572.90)
# Extracted Conditions: [('10', '98.76'), ('7', '0.05'), ('21', '0.37'), ('28', '0.32'), ('5', '572.90')]
# Matching Features: ['radius error', 'mean concave points', 'worst texture', 'worst symmetry', 'mean compactness']
# Rule: FEAT_10_LTE_98.76) AND FEAT_7_GT_0.05) AND FEAT_21_GT_0.37) AND FEAT_28_LTE_0.26)
# Extracted Conditions: [('10', '98.76'), ('7', '0.05'), ('21', '0.37'), ('28', '0.26')]
# Matching Features: ['radius error', 'mean concave points', 'worst texture', 'worst symmetry']
# Rule: FEAT_10_LTE_98.76) AND FEAT_7_GT_0.05) AND FEAT_21_GT_0.37) AND FEAT_28_GT_0.26)
# Extracted Conditions: [('10', '98.76'), ('7', '0.05'), ('21', '0.37'), ('28', '0.26')]
# Matching Features: ['radius error', 'mean concave points', 'worst texture', 'worst symmetry']
# Rule: FEAT_10_GT_98.76) AND FEAT_14_LTE_14.10)
# Extracted Conditions: [('10', '98.76'), ('14', '14.10')]
# Matching Features: ['radius error', 'smoothness error']
# Rule: FEAT_10_GT_98.76) AND FEAT_14_GT_14.10) AND FEAT_4_LTE_0.00) AND FEAT_1_LTE_0.02)
# Extracted Conditions: [('10', '98.76'), ('14', '14.10'), ('4', '0.00'), ('1', '0.02')]
# Matching Features: ['radius error', 'smoothness error', 'mean smoothness', 'mean texture']
# Rule: FEAT_10_GT_98.76) AND FEAT_14_GT_14.10) AND FEAT_4_LTE_0.00) AND FEAT_1_GT_0.02)
# Extracted Conditions: [('10', '98.76'), ('14', '14.10'), ('4', '0.00'), ('1', '0.02')]
# Matching Features: ['radius error', 'smoothness error', 'mean smoothness', 'mean texture']
# Rule: FEAT_10_GT_98.76) AND FEAT_14_GT_14.10) AND FEAT_4_GT_0.00)
# Extracted Conditions: [('10', '98.76'), ('14', '14.10'), ('4', '0.00')]
# Matching Features: ['radius error', 'smoothness error', 'mean smoothness']
# Rule: FEAT_8_LTE_0.09) AND FEAT_26_LTE_18.64) AND FEAT_20_LTE_957.45) AND FEAT_6_LTE_0.06) AND FEAT_7_LTE_0.03)
# Extracted Conditions: [('8', '0.09'), ('26', '18.64'), ('20', '957.45'), ('6', '0.06'), ('7', '0.03')]
# Matching Features: ['mean symmetry', 'worst concavity', 'worst radius', 'mean concavity', 'mean concave points']
# Rule: FEAT_8_LTE_0.09) AND FEAT_26_LTE_18.64) AND FEAT_20_LTE_957.45) AND FEAT_6_LTE_0.06) AND FEAT_7_GT_0.03) AND FEAT_20_LTE_669.05)
# Extracted Conditions: [('8', '0.09'), ('26', '18.64'), ('20', '957.45'), ('6', '0.06'), ('7', '0.03'), ('20', '669.05')]
# Matching Features: ['mean symmetry', 'worst concavity', 'worst radius', 'mean concavity', 'mean concave points', 'worst radius']
# Rule: FEAT_8_LTE_0.09) AND FEAT_26_LTE_18.64) AND FEAT_20_LTE_957.45) AND FEAT_6_LTE_0.06) AND FEAT_7_GT_0.03) AND FEAT_20_GT_669.05)
# Extracted Conditions: [('8', '0.09'), ('26', '18.64'), ('20', '957.45'), ('6', '0.06'), ('7', '0.03'), ('20', '669.05')]
# Matching Features: ['mean symmetry', 'worst concavity', 'worst radius', 'mean concavity', 'mean concave points', 'worst radius']
# Rule: FEAT_8_LTE_0.09) AND FEAT_26_LTE_18.64) AND FEAT_20_LTE_957.45) AND FEAT_6_GT_0.06) AND FEAT_25_LTE_113.15)
# Extracted Conditions: [('8', '0.09'), ('26', '18.64'), ('20', '957.45'), ('6', '0.06'), ('25', '113.15')]
# Matching Features: ['mean symmetry', 'worst concavity', 'worst radius', 'mean concavity', 'worst compactness']
# Rule: FEAT_8_LTE_0.09) AND FEAT_26_LTE_18.64) AND FEAT_20_LTE_957.45) AND FEAT_6_GT_0.06) AND FEAT_25_GT_113.15) AND FEAT_27_LTE_0.13)
# Extracted Conditions: [('8', '0.09'), ('26', '18.64'), ('20', '957.45'), ('6', '0.06'), ('25', '113.15'), ('27', '0.13')]
# Matching Features: ['mean symmetry', 'worst concavity', 'worst radius', 'mean concavity', 'worst compactness', 'worst concave points']
# Rule: FEAT_8_LTE_0.09) AND FEAT_26_LTE_18.64) AND FEAT_20_LTE_957.45) AND FEAT_6_GT_0.06) AND FEAT_25_GT_113.15) AND FEAT_27_GT_0.13)
# Extracted Conditions: [('8', '0.09'), ('26', '18.64'), ('20', '957.45'), ('6', '0.06'), ('25', '113.15'), ('27', '0.13')]
# Matching Features: ['mean symmetry', 'worst concavity', 'worst radius', 'mean concavity', 'worst compactness', 'worst concave points']
# Rule: FEAT_8_LTE_0.09) AND FEAT_26_LTE_18.64) AND FEAT_20_GT_957.45) AND FEAT_18_LTE_0.01)
# Extracted Conditions: [('8', '0.09'), ('26', '18.64'), ('20', '957.45'), ('18', '0.01')]
# Matching Features: ['mean symmetry', 'worst concavity', 'worst radius', 'symmetry error']
# Rule: FEAT_8_LTE_0.09) AND FEAT_26_LTE_18.64) AND FEAT_20_GT_957.45) AND FEAT_18_GT_0.01)
# Extracted Conditions: [('8', '0.09'), ('26', '18.64'), ('20', '957.45'), ('18', '0.01')]
# Matching Features: ['mean symmetry', 'worst concavity', 'worst radius', 'symmetry error']
# Rule: FEAT_8_LTE_0.09) AND FEAT_26_GT_18.64)
# Extracted Conditions: [('8', '0.09'), ('26', '18.64')]
# Matching Features: ['mean symmetry', 'worst concavity']
# Rule: FEAT_8_GT_0.09) AND FEAT_25_LTE_102.25) AND FEAT_21_LTE_0.45) AND FEAT_3_LTE_0.03)
# Extracted Conditions: [('8', '0.09'), ('25', '102.25'), ('21', '0.45'), ('3', '0.03')]
# Matching Features: ['mean symmetry', 'worst compactness', 'worst texture', 'mean area']
# Rule: FEAT_8_GT_0.09) AND FEAT_25_LTE_102.25) AND FEAT_21_LTE_0.45) AND FEAT_3_GT_0.03) AND FEAT_22_LTE_0.18)
# Extracted Conditions: [('8', '0.09'), ('25', '102.25'), ('21', '0.45'), ('3', '0.03'), ('22', '0.18')]
# Matching Features: ['mean symmetry', 'worst compactness', 'worst texture', 'mean area', 'worst perimeter']
# Rule: FEAT_8_GT_0.09) AND FEAT_25_LTE_102.25) AND FEAT_21_LTE_0.45) AND FEAT_3_GT_0.03) AND FEAT_22_GT_0.18)
# Extracted Conditions: [('8', '0.09'), ('25', '102.25'), ('21', '0.45'), ('3', '0.03'), ('22', '0.18')]
# Matching Features: ['mean symmetry', 'worst compactness', 'worst texture', 'mean area', 'worst perimeter']
# Rule: FEAT_8_GT_0.09) AND FEAT_25_LTE_102.25) AND FEAT_21_GT_0.45) AND FEAT_19_LTE_1.02)
# Extracted Conditions: [('8', '0.09'), ('25', '102.25'), ('21', '0.45'), ('19', '1.02')]
# Matching Features: ['mean symmetry', 'worst compactness', 'worst texture', 'fractal dimension error']
# Rule: FEAT_8_GT_0.09) AND FEAT_25_LTE_102.25) AND FEAT_21_GT_0.45) AND FEAT_19_GT_1.02)
# Extracted Conditions: [('8', '0.09'), ('25', '102.25'), ('21', '0.45'), ('19', '1.02')]
# Matching Features: ['mean symmetry', 'worst compactness', 'worst texture', 'fractal dimension error']
# Rule: FEAT_8_GT_0.09) AND FEAT_25_GT_102.25) AND FEAT_7_LTE_0.04)
# Extracted Conditions: [('8', '0.09'), ('25', '102.25'), ('7', '0.04')]
# Matching Features: ['mean symmetry', 'worst compactness', 'mean concave points']
# Rule: FEAT_8_GT_0.09) AND FEAT_25_GT_102.25) AND FEAT_7_GT_0.04) AND FEAT_14_LTE_14.12) AND FEAT_14_LTE_12.93)
# Extracted Conditions: [('8', '0.09'), ('25', '102.25'), ('7', '0.04'), ('14', '14.12'), ('14', '12.93')]
# Matching Features: ['mean symmetry', 'worst compactness', 'mean concave points', 'smoothness error', 'smoothness error']
# Rule: FEAT_8_GT_0.09) AND FEAT_25_GT_102.25) AND FEAT_7_GT_0.04) AND FEAT_14_LTE_14.12) AND FEAT_14_GT_12.93)
# Extracted Conditions: [('8', '0.09'), ('25', '102.25'), ('7', '0.04'), ('14', '14.12'), ('14', '12.93')]
# Matching Features: ['mean symmetry', 'worst compactness', 'mean concave points', 'smoothness error', 'smoothness error']
# Rule: FEAT_8_GT_0.09) AND FEAT_25_GT_102.25) AND FEAT_7_GT_0.04) AND FEAT_14_GT_14.12)
# Extracted Conditions: [('8', '0.09'), ('25', '102.25'), ('7', '0.04'), ('14', '14.12')]
# Matching Features: ['mean symmetry', 'worst compactness', 'mean concave points', 'smoothness error']

# %% [markdown]
# ### MILP Optimization of the Surrogate Interpretable Graph of the RF Classifier

# %% [markdown]
# ##### Simple Linear Optimizer

# %%
import networkx as nx
import matplotlib.pyplot as plt
from pulp import LpProblem, LpMaximize, LpVariable, lpSum, LpStatus

# 1. Mapping from encoded feature names to actual feature names
feature_mapping = {f"FEAT_{i}": feature for i, feature in enumerate(X.columns)}

# 2. Define edge weights (using previous code)
edge_weights = {}

# Debug: Check rule extraction and feature matching
for rule_text in encoded_rules:
    # Extract the features and thresholds
    conditions = re.findall(r'FEAT_(\d+)_\w+_([\d\.]+)', rule_text)
    
    # Map FEAT_0, FEAT_1, ... back to actual feature names in the dataset
    features_in_rule = [feature_mapping[f"FEAT_{cond[0]}"] for cond in conditions if f"FEAT_{cond[0]}" in feature_mapping]

    # If features are valid, build the edges
    if len(features_in_rule) > 1:
        for i in range(len(features_in_rule) - 1):
            edge = (features_in_rule[i], features_in_rule[i+1])
            edge_weights[edge] = edge_weights.get(edge, 0) + 1

# 3. Define maximum number of edges to select (surrogate graph size)
max_edges = 15

# 4. Create MILP problem: maximize sum of weights of selected edges subject to selecting <= max_edges.
prob = LpProblem("Surrogate_Graph_Selection", LpMaximize)

# 5. Create a binary variable for each edge in edge_dict
edge_vars = {edge: LpVariable(f"edge_{edge[0]}_{edge[1]}", cat='Binary')
             for edge in edge_weights.keys()}

# 6. Objective: maximize total weight of selected edges
prob += lpSum([edge_weights[edge] * edge_vars[edge] for edge in edge_vars]), "Total_Weight"

# 7. Constraint: number of selected edges <= max_edges
prob += lpSum([edge_vars[edge] for edge in edge_vars]) <= max_edges, "EdgeCountConstraint"

# 8. Solve the MILP problem
prob.solve()

print("MILP Status:", LpStatus[prob.status])

# 9. Extract selected edges from the MILP solution
# 9. Extract selected edges from the MILP solution
selected_edges = [edge for edge in edge_vars if edge_vars[edge].value() == 1]
print("Selected edges for surrogate graph:", selected_edges)


# 10. Build surrogate graph from selected edges
G_surrogate = nx.DiGraph()
for edge in selected_edges:
    G_surrogate.add_edge(edge[0], edge[1], weight=edge_weights[edge])

# 11. Visualize the surrogate graph
plt.figure(figsize=(10, 10))
pos = nx.circular_layout(G_surrogate)
edge_labels = nx.get_edge_attributes(G_surrogate, 'weight')
nx.draw(G_surrogate, pos, with_labels=True, node_size=800, node_color="lightgreen", arrowsize=10)
nx.draw_networkx_edge_labels(G_surrogate, pos, edge_labels=edge_labels)
plt.title("Surrogate Interpretable Graph")
plt.show()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/DubeyA-Dev/miniconda3/envs/taylor/lib/python3.10/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/tk/qh_5gfz51996p7zxwjyl8r140000gp/T/3606c5cc97a1468592f261ef4cc3547c-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/tk/qh_5gfz51996p7zxwjyl8r140000gp/T/3606c5cc97a1468592f261ef4cc3547c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 6 COLUMNS
# At line 599 RHS
# At line 601 BOUNDS
# At line 750 ENDATA
# Problem MODEL has 1 rows, 148 columns and 148 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 235 - 0.00 seconds
# Cgl0004I processed model has 1 rows, 127 columns (127 integer (113 of which binary)) and 127 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -235
# Cbc0038I Cleaned solution of -235
# Cbc0038I Before mini branch and bound, 127 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -235 - took 0.00 seconds
# Cbc0012I Integer solution of -235 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -235, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -235 to -235
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                235.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# MILP Status: Optimal
# Selected edges for surrogate graph: [('worst perimeter', 'smoothness error'), ('worst perimeter', 'worst radius'), ('worst perimeter', 'worst concavity'), ('worst area', 'worst compactness'), ('worst compactness', 'mean concave points'), ('worst perimeter', 'mean compactness'), ('mean radius', 'worst compactness'), ('worst concavity', 'worst perimeter'), ('worst compactness', 'worst symmetry'), ('worst texture', 'radius error'), ('radius error', 'worst concavity'), ('worst concavity', 'mean symmetry'), ('mean concave points', 'worst concavity'), ('texture error', 'worst area'), ('radius error', 'mean concave points')]

# %% [markdown]
# ## Analyzing conuterfactual for each of the tree within the search limit parameters

# %% [markdown]
# **What the Function Does:**
# 1. For each feature, tries to find the smallest perturbation (±step size) needed to flip the model's prediction
# 2. Tests both positive and negative directions for each feature
# 3. Stops searching when either:
#    - Prediction flips (found counterfactual)
#    - Reaches maximum iterations without flipping (no counterfactual)
#
# **Why No Counterfactuals Are Produced:**
# 1. **Model Robustness**: The model might be too confident in its prediction (needs larger perturbations)
# 2. **Feature Interactions**: Real decisions often require coordinated changes in multiple features
# 3. **Search Limitations**:
#    - Step size (0.05) might be too small
#    - Max iterations (50) might be insufficient (max change = 50×0.05 = 2.5 units)
# 4. **Data Distribution**: Changes might need to stay within valid feature ranges
# 5. **Binary Search Limitation**: Only modifies one feature at a time
#
# **Enhanced Version with Visualization and Improvements:**
#
#
# 1. **Probability Tracking**: Monitors class probability evolution instead of just class labels
# 2. **Visualization**: Shows how probabilities evolve with positive/negative perturbations
# 3. **Directional Analysis**: Separate tracking of increase/decrease directions
# 4. **Adaptive Step Size**: Larger default step (0.1) for faster exploration
# 5. **Target Class Specification**: Explicit target class control
# 6. **Diagnostic Plotting**: Reveals:
#    - Probability trajectories
#    - Decision boundary (0.5 line)
#    - Relative feature sensitivity
#
# **Interpretation Guide:**
# 1. **No Counterfactuals Indicate**:
#    - Flat lines: Feature changes don't affect predictions
#    - Non-crossing curves: Changes insufficient to flip class
# 2. **Steep Curves**: Sensitive features that impact predictions
# 3. **Crossing 0.5 Line**: Successful counterfactual found
#
# **Common Reasons for No Results:**
# 1. **Insufficient Perturbation Space**: Try:
# 2. **Need Multi-Feature Changes**: Combine features showing partial probability shifts
# 3. **Model Linearity Issues**: Try non-uniform step sizes or optimization-based methods
# 4. **Data Constraints**: Add range checks for valid feature values

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# def counterfactual_analysis(instance, model, feature_names, step=0.1, max_iter=100, 
#                            target_class=None, plot=True):
#     """
#     Enhanced counterfactual search with probability tracking and visualization
    
#     Returns:
#     - (dict) Counterfactual directions and magnitudes
#     - (matplotlib.figure) Probability evolution plots
#     """
#     instance_df = pd.DataFrame([instance], columns=feature_names)
#     orig_prob = model.predict_proba(instance_df)[0]
#     orig_class = model.predict(instance_df)[0]
#     target_class = 1 - orig_class if target_class is None else target_class
    
#     results = {}
#     prob_curves = {}

#     for feat_idx, feat_name in enumerate(feature_names):
#         perturbations = []
#         probabilities = []
        
#         # Test both directions
#         for direction in [-1, 1]:
#             perturbed = instance.copy()
#             prob_trace = []
            
#             for i in range(max_iter):
#                 perturbed[feat_idx] += direction * step
#                 prob = model.predict_proba(pd.DataFrame([perturbed], 
#                                      columns=feature_names))[0][target_class]
#                 prob_trace.append(prob)
                
#                 if (prob > 0.5) != (orig_prob[target_class] > 0.5):
#                     results[feat_name] = {
#                         'direction': 'decrease' if direction == -1 else 'increase',
#                         'magnitude': (i+1)*step,
#                         'final_prob': prob
#                     }
#                     break
#             else:
#                 prob_trace = [orig_prob[target_class]] * max_iter
            
#             perturbations.append(np.array(prob_trace))
#             probabilities.append(prob_trace)
        
#         prob_curves[feat_name] = (probabilities[0], probabilities[1])

#     if plot:
#         plt.figure(figsize=(12, 6))
#         colors = plt.cm.viridis(np.linspace(0, 1, len(feature_names)))
        
#         for idx, (feat, (neg_probs, pos_probs)) in enumerate(prob_curves.items()):
#             plt.subplot(2, 1, 1)
#             plt.plot(neg_probs, color=colors[idx], linestyle='--', 
#                     label=f'{feat} (-)' if idx == 0 else None)
#             plt.subplot(2, 1, 2)
#             plt.plot(pos_probs, color=colors[idx], linestyle='-',
#                     label=f'{feat} (+)')

#         # Formatting
#         for i in [1, 2]:
#             plt.subplot(2, 1, i)
#             plt.axhline(0.5, color='gray', linestyle=':')
#             plt.ylabel('Class Probability')
#             plt.xlabel('Iteration')
#             plt.title('Negative Perturbations' if i == 1 else 'Positive Perturbations')
#             plt.grid(alpha=0.3)
#             if i == 1: plt.legend(ncol=3, bbox_to_anchor=(1, 1.2))

#         plt.tight_layout()
#         plt.show()

#     return results

# # Usage
# instance = X.iloc[1].values
# cf_results = counterfactual_analysis(instance, rf, list(X.columns), 
#                    step=0.1, max_iter=1000)

# # Print results
# print("Counterfactual Analysis Report:")
# for feat, data in cf_results.items():
#     print(f"{feat}:")
#     print(f"  Required {data['direction']} of {data['magnitude']:.2f}")
#     print(f"  Final probability: {data['final_prob']:.2%}")
#     print("-"*40)

# %% [markdown]
# ## Counterfactual for each tree (aggregate analysis) of the RF Classifier

# %% [markdown]
# **Key Features:**
# 1. **Per-Tree Analysis**: Evaluates counterfactual effectiveness for each individual decision tree
# 2. **Four Diagnostic Visualizations**:
#    - Success rate heatmap across features
#    - Perturbation magnitude distribution
#    - Direction consistency plot
#    - Decision boundary projection for top feature
# 3. **Aggregate Statistics**:
#    - Success rates across the ensemble
#    - Required perturbation magnitudes
#    - Direction consistency metrics
#
# **Interpretation Guide:**
# 1. **No Counterfactuals Possible When**:
#    - Success rate heatmap shows all low values (0-0.2)
#    - Perturbation magnitude plot shows sparse/no points
#    - Decision boundary projection shows instance far from boundary
#
# 2. **Key Insights**:
#    - Features with high success rates are good candidate for intervention
#    - Consistent direction across trees indicates robust relationships
#    - Large required deltas suggest feature scaling issues or model robustness
#
# This analysis helps understand why counterfactuals might be hard to find by:
# - Revealing feature-specific effectiveness across the ensemble
# - Showing required intervention magnitudes
# - Visualizing decision boundaries for critical features
# - Identifying directional consistency in required perturbations

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.inspection import DecisionBoundaryDisplay

def ensemble_counterfactual_analysis(instance, rf_model, feature_names, 
                                    step=0.5, max_iter=500, target_class=None):
    """
    Advanced counterfactual analysis across Random Forest subtrees
    Returns:
    - (dict) Aggregate counterfactual statistics per feature
    - (dict) Individual tree counterfactual data
    - (matplotlib.figure) Visualizations
    """
    # Initialize data structures
    n_trees = len(rf_model.estimators_)
    n_features = len(feature_names)
    tree_data = []
    aggregate_results = {feat: {'deltas': [], 'success_rate': 0} 
                        for feat in feature_names}
    
    # Create progress bar for tree analysis
    with tqdm(total=n_trees, desc="Analyzing Subtrees") as pbar:
        for tree_idx, tree in enumerate(rf_model.estimators_):
            # Get original prediction from this subtree
            orig_pred = tree.predict(instance.reshape(1, -1))[0]
            target = 1 - orig_pred if target_class is None else target_class
            
            tree_results = {}
            
            # Analyze each feature
            for feat_idx, feat_name in enumerate(feature_names):
                found_cf = False
                # Try both perturbation directions
                for direction in [-1, 1]:
                    perturbed = instance.copy()
                    for i in range(max_iter):
                        perturbed[feat_idx] += direction * step * (i+1)
                        new_pred = tree.predict(perturbed.reshape(1, -1))[0]
                        if new_pred == target:
                            tree_results[feat_name] = {
                                'delta': direction * step * (i+1),
                                'iterations': i+1,
                                'direction': 'decrease' if direction == -1 else 'increase'
                            }
                            aggregate_results[feat_name]['deltas'].append(direction * step * (i+1))
                            found_cf = True
                            break
                    if found_cf:
                        break
                if not found_cf:
                    tree_results[feat_name] = {'delta': np.nan, 'iterations': max_iter}
            
            tree_data.append(tree_results)
            pbar.update(1)
    
    # Calculate success rates
    for feat in aggregate_results:
        successes = len([d for d in aggregate_results[feat]['deltas'] if not np.isnan(d)])
        aggregate_results[feat]['success_rate'] = successes / n_trees
    
    # Generate visualizations
    plt.figure(figsize=(30, 28))
    
    # 1. Feature Importance Heatmap
    plt.subplot(2, 2, 1)
    success_rates = [aggregate_results[feat]['success_rate'] for feat in feature_names]
    plt.imshow(np.array(success_rates).reshape(1, -1), cmap='viridis', aspect='auto')
    plt.colorbar(label='Success Rate')
    plt.yticks([])
    plt.xticks(np.arange(len(feature_names)), feature_names, rotation=90)
    plt.title('Counterfactual Success Rate Across Trees')
    
    # 2. Delta Distribution Swarm Plot
    plt.subplot(2, 2, 2)
    all_deltas = []
    for feat in feature_names:
        deltas = [d for d in aggregate_results[feat]['deltas'] if not np.isnan(d)]
        jitter = np.random.normal(loc=0, scale=0.1, size=len(deltas))
        plt.scatter(np.arange(len(deltas)) + jitter, deltas, 
                    alpha=0.3, label=feat)
    plt.axhline(0, color='gray', linestyle='--')
    plt.ylabel('Required Delta')
    plt.xlabel('Feature Index')
    plt.title('Perturbation Magnitude Distribution')
    
    # 3. Direction Consistency Plot
    plt.subplot(2, 2, 3)
    direction_counts = {feat: {'increase': 0, 'decrease': 0} 
                       for feat in feature_names}
    for tree in tree_data:
        for feat, res in tree.items():
            if 'direction' in res:
                direction_counts[feat][res['direction']] += 1
                
    width = 0.4
    for idx, feat in enumerate(feature_names):
        plt.bar(idx - width/2, direction_counts[feat]['increase'], 
               width=width, color='green')
        plt.bar(idx + width/2, direction_counts[feat]['decrease'], 
               width=width, color='red')
    plt.xticks(np.arange(len(feature_names)), feature_names, rotation=90)
    plt.ylabel('Count')
    plt.title('Direction Consistency Across Trees')
    plt.legend(['Increase', 'Decrease'])
    
    # 4. Decision Boundary Projection
    plt.subplot(2, 2, 4)
    top_feature = sorted(feature_names, 
                        key=lambda x: aggregate_results[x]['success_rate'])[-1]
    feat_idx = feature_names.index(top_feature)
    
    # Generate probability curve for top feature
    feat_values = np.linspace(instance[feat_idx] - 3*step*max_iter,
                            instance[feat_idx] + 3*step*max_iter, 100)
    probabilities = []
    
    for val in feat_values:
        modified = instance.copy()
        modified[feat_idx] = val
        # Get average probability across all trees
        avg_prob = np.mean([tree.predict_proba(modified.reshape(1, -1))[0][target_class] 
                          for tree in rf_model.estimators_])
        probabilities.append(avg_prob)
    
    plt.plot(feat_values, probabilities, color='navy', lw=2)
    plt.axvline(instance[feat_idx], color='red', linestyle='--', label='Original Value')
    plt.axhline(0.5, color='gray', linestyle=':', label='Decision Threshold')
    plt.xlabel(top_feature)
    plt.ylabel('Average Class Probability')
    plt.title(f'Probability Landscape for {top_feature}')
    plt.legend()
    
    plt.tight_layout()
    return aggregate_results, tree_data

# %%
# # Assuming:
# # - rf is your trained RandomForestClassifier
# # - X is your feature matrix
# # - instance is your sample to analyze (numpy array)

# agg_results, tree_data = ensemble_counterfactual_analysis(
#     instance=X.iloc[10].values,
#     rf_model=rf,
#     feature_names=list(X.columns),
#     step=0.2,
#     max_iter=500
# )

# %% [markdown]
# #### This also enables directional consistency evaluations

# %%
# First get the global target class
instance = X.iloc[20].values
forest_pred = rf.predict(instance.reshape(1, -1))[0]
target_class = 1 - forest_pred  # Flip the prediction

agg_results, tree_data = ensemble_counterfactual_analysis(
    instance=instance,
    rf_model=rf,
    feature_names=list(X.columns),
    step=0.2,
    max_iter=50,
    target_class=target_class  # Explicit target class
)
# Out:
# /Users/DubeyA-Dev/miniconda3/envs/taylor/lib/python3.10/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# Analyzing Subtrees: 100%|██████████| 10/10 [00:01<00:00,  5.42it/s]

# %% [markdown]
# ---
#
# ### **1. Core Methodological Components Explained**
#
# #### **A. Per-Tree Analysis**
# - **What it means**: The analysis evaluates counterfactual effectiveness _individually_ for every decision tree in the random forest. Each tree acts as a "mini-model" with its own decision logic.
# - **Why it matters**:
#   - Identifies features that are universally important vs. those only significant in subsets of trees
#   - Reveals the diversity of decision logic within the ensemble
#   - Helps distinguish between *robust patterns* (agreed by most trees) and *idiosyncratic patterns* (specific to individual trees)
#
# ---
#
# #### **B. Four Diagnostic Visualizations**
# 1. **Success Rate Heatmap**
#    - **Purpose**: Shows the percentage of trees where perturbing a feature flipped the prediction
#    - **Interpretation**:
#      - Bright colors = High success rates (e.g., "mean radius" flips predictions in 80% of trees)
#      - Dark colors = Low success rates (e.g., "texture" only affects 10% of trees)
#    - **Analogy**: A "voting system" showing which features are most influential across the ensemble
#
# 2. **Perturbation Magnitude Distribution**
#    - **Purpose**: Visualizes the range of changes needed to flip predictions
#    - **Key Patterns**:
#      - Tight cluster = Consistent perturbation size across trees (e.g., "radius" always requires ~0.5 unit change)
#      - Wide spread = Context-dependent effectiveness (e.g., "area" needs 0.2-3.0 units depending on the tree)
#    - **Critical Insight**: Features with small required changes are "leverage points" for interventions
#
# 3. **Direction Consistency Plot**
#    - **Purpose**: Quantifies whether features require consistent increase/decrease across trees
#    - **Example**:
#      - "Concavity": 90% of trees require decreasing this feature
#      - "Smoothness": 50% increase / 50% decrease (no consensus)
#    - **Implications**: Consistent directions indicate stable relationships between features and outcomes
#
# 4. **Decision Boundary Projection**
#    - **Purpose**: Illustrates how the top feature's values relate to class probabilities
#    - **Key Observations**:
#      - Steep slope = Small changes dramatically affect predictions
#      - Flat region = Feature changes have minimal impact
#      - Distance from boundary = How "deep" the instance is in its predicted class
#
# ---
#
# #### **C. Aggregate Statistics**
# 1. **Success Rates**:
#    - "75% success rate for radius" = 3/4 trees would flip prediction if radius is perturbed
#    - Low rates (<20%) suggest the feature is either:
#      - Irrelevant to the classification
#      - Requires coordinated changes with other features
#
# 2. **Required Perturbation Magnitudes**:
#    - Mean/median values indicate "typical" intervention size
#    - Large standard deviation implies tree-to-tree variability in feature sensitivity
#
# 3. **Direction Consistency**:
#    - "85% consistency for decreasing radius" = Strong consensus on relationship direction
#    - 50/50 split = Ambiguous/noise in the feature's role
#
# ---
#
# ### **2. Interpretation Guide Deep Dive**
#
# #### **A. No Counterfactuals Detected**
# - **Scenario**: All features show success rates <20%, sparse perturbation points, and distant decision boundaries
# - **Implications**:
#   1. **Model Robustness**: The prediction is stable against single-feature perturbations
#   2. **Data Characteristics**:
#      - The instance is far from class boundaries in feature space
#      - True decision boundaries may be multi-dimensional (require combined feature changes)
#   3. **Practical Impact**:
#      - Single-feature interventions may be insufficient
#      - Need to consider *minimum viable combination* of changes
#
# ---
#
# #### **B. Key Insights**
# 1. **High Success Rate Features**
#    - **Example**: "Radius" with 80% success rate
#    - **Actionable Insight**: Medical diagnosis - Focus on reducing tumor radius
#    - **Technical Implication**: The feature is central to the model's decision logic
#
# 2. **Directional Consistency**
#    - **Example**: 90% of trees require decreasing "concavity"
#    - **Domain Significance**: Confirms biological understanding (less concave tumors are benign)
#    - **Validation**: Matches medical literature, increasing trust in the model
#
# 3. **Large Required Perturbations**
#    - **Example**: "Area" needing >5-unit changes
#    - **Possible Causes**:
#      - The feature is scaled poorly (e.g., range=0-1000 vs. 0-1 for others)
#      - The model uses it only in extreme cases (threshold effect)
#    - **Solution Path**:
#      - Re-examine feature engineering
#      - Check for nonlinear relationships (log-transform?)
#
# ---
#
# ### **3. Why This Matters for Explainability**
# 1. **Model Diagnostics**:
#    - Reveals whether the model uses features in medically/biologically plausible ways
#    - Detects over-reliance on non-actionable features (e.g., "patient ID")
#
# 2. **Actionable Interventions**:
#    - Identifies features where small changes yield prediction flips (practical for real-world use)
#    - Warns against futile single-feature interventions when success rates are low
#
# 3. **Trust & Validation**:
#    - Directional consistency with domain knowledge increases model credibility
#    - Inconsistencies flag potential data leakage or artifacts
#
# ---
#
# ### **Real-World Analogy: Medical Diagnosis**
# Imagine a tumor classifier where:
# - **High Success Rate**: "Radius" (easy to measure, clearly malignant if large)
# - **Directional Consistency**: All doctors agree "larger = worse"
# - **Large Deltas**: "Texture" requires extreme changes to matter (rare edge cases)
#
# This analysis helps clinicians:
# 1. Focus on measurable, impactful features
# 2. Avoid wasting time on ambiguous characteristics
# 3. Understand when combined factors must be addressed
#
# By linking model behavior to domain reality, it bridges the gap between ML outputs and practical decision-making.

# %% [markdown]
# ## First version of counterfactual analysis for RF Classifier

# %%
# # 6. Advanced Counterfactual Generation for Local Explanation
# def counterfactual_search(instance, model, feature_names, step=0.05, max_iter=50):
#     orig_pred = model.predict(pd.DataFrame([instance], columns=feature_names))[0]
#     counterfactuals = {}
#     for idx, feat in enumerate(feature_names):
#         modified = instance.copy()
#         for direction in [1, -1]:
#             temp_instance = modified.copy()
#             for i in range(max_iter):
#                 temp_instance[idx] += direction * step
#                 new_pred = model.predict(pd.DataFrame([temp_instance], columns=feature_names))[0]
#                 if new_pred != orig_pred:
#                     counterfactuals[feat] = (direction * step * (i+1), new_pred)
#                     break
#             else:
#                 counterfactuals[feat] = (None, orig_pred)
#     return counterfactuals

# instance = X.iloc[1].values
# y_label = y[1]
# cf_results = counterfactual_search(instance, rf, list(X.columns))
# print("\nCounterfactual adjustments to flip prediction:")
# for feat, (change, new_pred) in cf_results.items():
#     if change is not None:
#         print(f" - {feat}: adjust by {change:.2f} to yield prediction {new_pred}")
#     else:
#         print(f" - {feat}: no flip found within search limits.")

# %%
# 7. Explanation Aggregation and Visualization using Parallel Sets
def rules_to_dataframe(rule_texts, max_conditions=5):
    rows = []
    for rule in rule_texts:
        conditions = re.findall(r'\([^)]+\)', rule)
        row = conditions[:max_conditions] + ['None'] * (max_conditions - len(conditions))
        rows.append(row)
    cols = [f'Condition {i+1}' for i in range(max_conditions)]
    return pd.DataFrame(rows, columns=cols)

df_rules = rules_to_dataframe(all_rule_texts, max_conditions=5)

# %%
# To ensure the length of 'y' matches the number of rows in df_rules,
# let's create a mapping of rule to the majority class label of the trees
def get_majority_class_for_rule(rule):
    rule_idx = all_rule_texts.index(rule)
    # Get predictions from each tree in the ensemble
    predictions = [est.predict([X.iloc[rule_idx]])[0] for est in rf.estimators_]
    # Return the majority class
    return np.bincount(predictions).argmax()

# Assign the majority class of each rule
rule_classes = [get_majority_class_for_rule(rule) for rule in all_rule_texts]

# Sort the categories manually before plotting
for col in df_rules.columns:
    df_rules[col] = pd.Categorical(df_rules[col], categories=sorted(df_rules[col].unique()), ordered=True)

# %% [markdown]
# ##### Add aggreggated decision paths and conditions and combine different thresholds from the same feature to create a decision rule

# %%
import pandas as pd
import re

def rules_to_dataframe(rule_texts, max_conditions=5):
    """
    Converts rule texts into a dataframe where each condition in the rule is placed in a separate column.
    
    Parameters:
    rule_texts (list): List of rule texts.
    max_conditions (int): Maximum number of conditions to extract from each rule.
    
    Returns:
    pd.DataFrame: DataFrame with each condition in a separate column.
    """
    rows = []
    for rule in rule_texts:
        # Extract conditions from the rule (assuming they are in parentheses)
        conditions = re.findall(r'\([^)]+\)', rule)
        # Fill missing conditions with 'None' to ensure consistent columns
        row = conditions[:max_conditions] + ['None'] * (max_conditions - len(conditions))
        rows.append(row)
    
    # Create column names based on the maximum number of conditions
    cols = [f'Condition {i+1}' for i in range(max_conditions)]
    return pd.DataFrame(rows, columns=cols)

# %%
df_class_0
# Out:
#                         Condition 1                  Condition 2  \
# 0    (worst concave points <= 0.14)      (mean texture <= 21.31)
# 1    (worst concave points <= 0.14)      (mean texture <= 21.31)
# 2    (worst concave points <= 0.14)      (mean texture <= 21.31)
# 3    (worst concave points <= 0.14)      (mean texture <= 21.31)
# 4    (worst concave points <= 0.14)      (mean texture <= 21.31)
# ..                              ...                          ...
# 99          (mean concavity > 0.09)  (worst perimeter <= 102.25)
# 100         (mean concavity > 0.09)   (worst perimeter > 102.25)
# 101         (mean concavity > 0.09)   (worst perimeter > 102.25)
# 102         (mean concavity > 0.09)   (worst perimeter > 102.25)
# 103         (mean concavity > 0.09)   (worst perimeter > 102.25)
#
#                        Condition 3                Condition 4  \
# 0           (worst area <= 947.60)  (perimeter error <= 4.03)
# 1           (worst area <= 947.60)  (perimeter error <= 4.03)
# 2           (worst area <= 947.60)  (perimeter error <= 4.03)
# 3           (worst area <= 947.60)   (perimeter error > 4.03)
# 4           (worst area <= 947.60)   (perimeter error > 4.03)
# ..                             ...                        ...
# 99      (worst compactness > 0.45)    (texture error <= 1.02)
# 100  (mean concave points <= 0.04)                       None
# 101   (mean concave points > 0.04)    (mean texture <= 14.12)
# 102   (mean concave points > 0.04)    (mean texture <= 14.12)
# 103   (mean concave points > 0.04)     (mean texture > 14.12)
#
#                      Condition 5
# 0    (worst compactness <= 0.35)
# 1     (worst compactness > 0.35)
# 2     (worst compactness > 0.35)
# 3        (mean symmetry <= 0.17)
# 4         (mean symmetry > 0.17)
# ..                           ...
# 99                          None
# 100                         None
# 101      (mean texture <= 12.93)
# 102       (mean texture > 12.93)
# 103                         None
#
# [104 rows x 5 columns]

# %%
# Step 1: Calculate rule_classes for each rule
def get_majority_class_for_rule(rule):
    rule_idx = all_rule_texts.index(rule)
    # Get predictions from each tree in the ensemble
    predictions = [est.predict([X.iloc[rule_idx]])[0] for est in rf.estimators_]
    # Return the majority class
    return np.bincount(predictions).argmax()

# Generate rule classes
rule_classes = [get_majority_class_for_rule(rule) for rule in all_rule_texts]

# Step 2: Extract indices of rules that predict class 1 and 0
rules_class_0 = [rule for rule, rule_class in zip(all_rule_texts, rule_classes) if rule_class == 0]
rules_class_1 = [rule for rule, rule_class in zip(all_rule_texts, rule_classes) if rule_class == 1]

# Step 3: Convert the rules for class 0 and 1 into dataframes
df_class_0 = rules_to_dataframe(rules_class_0, max_conditions=5)
df_class_1 = rules_to_dataframe(rules_class_1, max_conditions=5)

# Visualize the decision making for class 0
fig_class_0 = px.parallel_categories(
    df_class_0,
    dimensions=df_class_0.columns,
    title="Parallel Coordinates for Class 0 Predictions"
)
fig_class_0.show()

# Visualize the decision making for class 1
fig_class_1 = px.parallel_categories(
    df_class_1,
    dimensions=df_class_1.columns,
    title="Parallel Coordinates for Class 1 Predictions"
)
fig_class_1.show()

# %%
import pandas as pd

def summarize_rules(df):
    """
    Summarizes the rules in a DataFrame by combining duplicate conditions within each feature.
    
    Args:
        df (pd.DataFrame): Input DataFrame with rules for a label.
        
    Returns:
        str: Summarized rule combining unique conditions per feature.
    """
    summarized_rules = []
    for feature in df.columns:
        # Extract unique non-empty conditions for the feature
        conditions = df[feature].dropna().unique()
        if len(conditions) > 0:
            # Join conditions with OR for the current feature
            feature_rule = f"({' OR '.join(conditions)})"
            summarized_rules.append(f"{feature} {feature_rule}")
    # Combine all features with AND

    return ' AND '.join(summarized_rules)

# # Example DataFrames for Label 1 and Label 2
# label1_df = pd.DataFrame({
#     'Feature1': ['>5', '>3', ''],
#     'Feature2': ['<3', '', '=10'],
#     'Feature3': ['=2', '=5', ''],
#     'Feature4': ['', '!=4', ''],
#     'Feature5': ['<=10', '<5', '']
# })

# label2_df = pd.DataFrame({
#     'Feature1': ['<10', '>5', ''],
#     'Feature2': ['>=20', '', '=15'],
#     'Feature3': ['=3', '=8', ''],
#     'Feature4': ['', '!=2', ''],
#     'Feature5': ['>20', '>=15', '']
# })

# Summarize rules for each label
summarized_label1 = summarize_rules(df_class_0)
summarized_label2 = summarize_rules(df_class_1)

print("Summarized Rules for Label 1:")
print(summarized_label1)
print("\nSummarized Rules for Label 2:")
print(summarized_label2)
# Out:
# Summarized Rules for Label 1:
# Condition 1 ((worst concave points <= 0.14) OR (worst concave points > 0.14) OR (worst concavity <= 0.26) OR (worst concavity > 0.26) OR (worst radius <= 16.80) OR (worst radius > 16.80) OR (area error <= 34.85) OR (area error > 34.85) OR (worst compactness <= 0.28) OR (worst compactness > 0.28) OR (worst perimeter <= 105.15) OR (worst perimeter > 105.15) OR (mean radius <= 14.98) OR (mean radius > 14.98) OR (mean perimeter <= 98.76) OR (mean perimeter > 98.76) OR (mean concavity <= 0.09) OR (mean concavity > 0.09)) AND Condition 2 ((mean texture <= 21.31) OR (mean texture > 21.31) OR (worst area <= 492.25) OR (worst area > 492.25) OR (worst concave points <= 0.16) OR (worst concave points > 0.16) OR (worst perimeter <= 100.59) OR (worst perimeter > 100.59) OR (mean area <= 694.10) OR (mean area > 694.10) OR (worst radius <= 16.29) OR (worst concave points <= 0.14) OR (worst concave points > 0.14) OR (mean texture <= 15.82) OR (mean texture > 15.82) OR (worst perimeter <= 104.10) OR (worst perimeter > 104.10) OR (mean concave points <= 0.05) OR (mean concave points > 0.05) OR (mean perimeter <= 97.92) OR (worst symmetry <= 0.41) OR (worst symmetry > 0.41) OR (worst concavity <= 0.36) OR (worst concavity <= 0.22) OR (mean texture > 14.10) OR (worst radius <= 18.64) OR (worst radius > 18.64) OR (worst perimeter <= 102.25) OR (worst perimeter > 102.25)) AND Condition 3 ((worst area <= 947.60) OR (worst area > 947.60) OR (worst perimeter <= 101.30) OR (worst perimeter > 101.30) OR None OR (perimeter error <= 1.54) OR (perimeter error > 1.54) OR (worst area <= 1058.00) OR (worst area > 1058.00) OR (worst concave points <= 0.18) OR (worst concave points > 0.18) OR (mean concave points <= 0.04) OR (mean concave points > 0.04) OR (worst area <= 727.10) OR (worst area > 727.10) OR (worst texture > 19.74) OR (worst fractal dimension <= 0.12) OR (radius error <= 0.64) OR (radius error > 0.64) OR (mean smoothness <= 0.12) OR (mean smoothness > 0.12) OR (mean fractal dimension > 0.06) OR (mean symmetry <= 0.15) OR (worst symmetry <= 0.50) OR (worst concave points <= 0.14) OR (worst concave points > 0.14) OR (perimeter error <= 4.12) OR (worst texture <= 19.03) OR (worst radius <= 16.88) OR (worst radius <= 16.82) OR (worst radius > 16.82) OR (worst radius <= 15.39) OR (worst radius > 15.39) OR (worst concave points <= 0.13) OR (worst concave points > 0.13) OR (worst area <= 957.45) OR (worst area > 957.45) OR (mean texture <= 16.53) OR (perimeter error > 2.56) OR (mean smoothness > 0.09) OR (worst radius <= 16.83) OR (worst radius > 16.83) OR (worst compactness <= 0.37) OR (worst compactness > 0.37) OR (fractal dimension error <= 0.00) OR (fractal dimension error > 0.00) OR (worst compactness <= 0.45) OR (worst compactness > 0.45)) AND Condition 4 ((perimeter error <= 4.03) OR (perimeter error > 4.03) OR (worst concavity <= 0.19) OR (worst concavity > 0.19) OR (mean smoothness <= 0.09) OR (mean smoothness > 0.09) OR (worst radius <= 16.80) OR (worst radius > 16.80) OR None OR (mean compactness <= 0.10) OR (worst concave points <= 0.11) OR (worst concave points > 0.11) OR (worst texture <= 33.61) OR (worst texture > 33.61) OR (concave points error <= 0.01) OR (concave points error > 0.01) OR (mean area <= 656.50) OR (mean area > 656.50) OR (area error <= 48.98) OR (area error > 48.98) OR (worst texture <= 29.68) OR (worst texture > 29.68) OR (texture error > 1.44) OR (compactness error > 0.02) OR (worst perimeter <= 102.10) OR (worst perimeter > 102.10) OR (worst texture <= 27.22) OR (mean symmetry <= 0.15) OR (mean area <= 532.60) OR (mean area > 532.60) OR (mean texture <= 22.26) OR (mean perimeter > 85.10) OR (worst smoothness <= 0.14) OR (worst area <= 952.80) OR (worst area > 952.80) OR (mean concavity <= 0.14) OR (mean texture <= 20.30) OR (area error <= 16.20) OR (area error > 16.20) OR (concavity error <= 0.06) OR (texture error <= 0.98) OR (texture error > 0.98) OR (mean radius <= 16.77) OR (mean radius > 16.77) OR (mean radius > 1 ...
#
# Summarized Rules for Label 2:
# Condition 1 ((worst concave points > 0.14) OR (worst concavity <= 0.26) OR (worst concavity > 0.26) OR (worst concave points <= 0.14) OR (worst radius <= 16.80) OR (worst radius > 16.80) OR (area error <= 34.85) OR (area error > 34.85) OR (worst compactness <= 0.28) OR (worst compactness > 0.28) OR (worst perimeter <= 105.15) OR (worst perimeter > 105.15) OR (mean radius <= 14.98) OR (mean radius > 14.98) OR (mean perimeter <= 98.76) OR (mean perimeter > 98.76) OR (mean concavity <= 0.09) OR (mean concavity > 0.09)) AND Condition 2 ((worst area > 492.25) OR (worst concave points <= 0.16) OR (worst perimeter > 100.59) OR (mean area <= 694.10) OR (mean area > 694.10) OR (worst radius <= 16.29) OR (worst radius > 16.29) OR (worst concave points <= 0.14) OR (worst concave points > 0.14) OR (mean texture <= 15.82) OR (mean texture > 15.82) OR (worst perimeter <= 104.10) OR (worst perimeter > 104.10) OR (mean concave points <= 0.05) OR (mean concave points > 0.05) OR (mean perimeter <= 97.92) OR (mean perimeter > 97.92) OR (worst symmetry <= 0.41) OR (worst concavity <= 0.36) OR (worst concavity > 0.36) OR (worst concavity <= 0.22) OR (worst concavity > 0.22) OR (mean texture <= 14.10) OR (mean texture > 14.10) OR (worst radius <= 18.64) OR (worst perimeter <= 102.25)) AND Condition 3 ((perimeter error > 1.54) OR (worst area <= 1058.00) OR (mean concave points > 0.04) OR (worst area > 727.10) OR (worst texture <= 19.74) OR (worst texture > 19.74) OR (worst fractal dimension <= 0.12) OR (worst fractal dimension > 0.12) OR (worst concave points <= 0.15) OR (worst concave points > 0.15) OR (radius error <= 0.64) OR (radius error > 0.64) OR (mean smoothness <= 0.12) OR (mean fractal dimension <= 0.06) OR (mean symmetry <= 0.15) OR (mean symmetry > 0.15) OR (worst symmetry <= 0.50) OR (worst symmetry > 0.50) OR (worst concave points <= 0.14) OR (worst concave points > 0.14) OR (perimeter error <= 4.12) OR (perimeter error > 4.12) OR (worst texture > 19.03) OR (worst radius <= 16.88) OR (worst radius > 16.88) OR (worst texture <= 21.14) OR (worst texture > 21.14) OR (worst radius <= 15.39) OR (worst radius > 15.39) OR (worst concave points > 0.13) OR (worst area <= 957.45) OR (worst area > 957.45) OR (mean texture <= 16.53) OR (mean texture > 16.53) OR (perimeter error <= 2.56) OR (perimeter error > 2.56) OR (worst area <= 493.45) OR (worst area > 493.45) OR (mean smoothness <= 0.09) OR (worst perimeter <= 111.10) OR (worst perimeter > 111.10) OR (worst radius <= 16.83) OR (worst radius > 16.83) OR (worst compactness <= 0.37) OR (worst compactness > 0.37) OR None OR (fractal dimension error <= 0.00) OR (worst compactness <= 0.45) OR (worst compactness > 0.45)) AND Condition 4 ((mean compactness > 0.10) OR (worst concave points <= 0.11) OR (mean area <= 656.50) OR (worst texture <= 29.68) OR (worst texture > 29.68) OR None OR (texture error <= 1.44) OR (compactness error <= 0.02) OR (radius error <= 0.43) OR (radius error > 0.43) OR (worst perimeter > 102.10) OR (mean smoothness > 0.09) OR (worst texture <= 27.22) OR (worst texture > 27.22) OR (mean symmetry > 0.15) OR (mean area <= 532.60) OR (mean area > 532.60) OR (mean texture <= 22.26) OR (mean texture > 22.26) OR (mean perimeter <= 85.10) OR (worst smoothness > 0.14) OR (concave points error <= 0.01) OR (concave points error > 0.01) OR (mean concavity <= 0.14) OR (mean concavity > 0.14) OR (worst concavity <= 0.22) OR (worst concavity > 0.22) OR (mean texture > 20.30) OR (area error > 16.20) OR (concavity error <= 0.06) OR (concavity error > 0.06) OR (texture error > 0.98) OR (mean radius <= 16.77) OR (mean radius > 16.77) OR (mean radius <= 15.88) OR (smoothness error <= 0.01) OR (smoothness error > 0.01) OR (worst texture <= 25.94) OR (worst texture > 25.94) OR (concavity error <= 0.03) OR (concavity error > 0.03) OR (radius error <= 0.24) OR (radius error > 0.24) OR (perimeter error <= 4.03) OR (perimeter error > 4.03) OR (mean area <= 694.40) OR (worst symmetry <= 0.32) OR (worst ...

# %%
import pandas as pd

def summarize_feature_conditions(df):
    """
    Create a dictionary of summarized conditions for each feature
    
    Args:
        df (pd.DataFrame): Input DataFrame with rules for a label
        
    Returns:
        dict: Feature-condition pairs with OR-combined values
    """
    summary = {}
    for feature in df.columns:
        conditions = df[feature].dropna().unique()
        summary[feature] = ' OR '.join(conditions) if len(conditions) > 0 else ''
    return summary

# Create summary dictionaries for each label
label1_summary = summarize_feature_conditions(df_class_0)
label2_summary = summarize_feature_conditions(df_class_1)

# Create final DataFrame
summary_df = pd.DataFrame([label1_summary, label2_summary], 
                         index=['Label 1', 'Label 2'])

# Transpose to get features as columns and labels as rows
summary_df = summary_df.transpose()

print("Summarized Conditions DataFrame:")
print(summary_df)
# Out:
# Summarized Conditions DataFrame:
#                                                        Label 1  \
# Condition 1  (worst concave points <= 0.14) OR (worst conca...
# Condition 2  (mean texture <= 21.31) OR (mean texture > 21....
# Condition 3  (worst area <= 947.60) OR (worst area > 947.60...
# Condition 4  (perimeter error <= 4.03) OR (perimeter error ...
# Condition 5  (worst compactness <= 0.35) OR (worst compactn...
#
#                                                        Label 2
# Condition 1  (worst concave points > 0.14) OR (worst concav...
# Condition 2  (worst area > 492.25) OR (worst concave points...
# Condition 3  (perimeter error > 1.54) OR (worst area <= 105...
# Condition 4  (mean compactness > 0.10) OR (worst concave po...
# Condition 5  None OR (worst radius <= 17.02) OR (mean perim...

# %% [markdown]
# ## To-do : Add heatmap for rules for heirarchial rule visualization of ensembles

# %%
# Local Explanation: Filter rules that the given instance satisfies
def get_local_rules(instance, model, feature_names, threshold_margin=0.5):
    local_rules = []
    pattern = re.compile(r'\((.*?)\s*(<=|>)\s*([\d\.]+)\)')
    for rule in all_rule_texts:
        matches = pattern.findall(rule)
        satisfied = True
        for feat, op, thresh in matches:
            thresh_val = float(thresh)
            feat_index = list(feature_names).index(feat.strip())
            value = instance[feat_index]
            if op == "<=":
                if not (value <= thresh_val + threshold_margin):
                    satisfied = False
                    break
            elif op == ">":
                if not (value > thresh_val - threshold_margin):
                    satisfied = False
                    break
        if satisfied:
            local_rules.append(rule)
    return local_rules

# %%
local_rule_texts = get_local_rules(instance, rf, X.columns)
df_local = rules_to_dataframe(local_rule_texts, max_conditions=5)
# Local Parallel Sets Visualization
fig_local = px.parallel_categories(
    df_local,
    dimensions=df_local.columns,
    # color="class",  # Use the class label of the selected instance
    color_continuous_scale=px.colors.sequential.Plasma,
    title="Local Parallel Sets of Rules for the Selected Instance"
)
# fig_local.update_traces(categoryorders={col: "array" for col in df_local.columns})
fig_local.update_layout(
    margin=dict(t=50, b=50, l=50, r=50),
    autosize=True
)

fig_local.update_layout(width = 1500, height = 800)
fig_local.show()
